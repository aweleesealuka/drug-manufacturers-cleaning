# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys

# %matplotlib inline

# %%
df = pd.read_excel(r".\drug2017-2021.xlsx")
df.head()
# Out:
#                            PRODUCT NAME   NAFDAC  \
# 0  ALBENDAZOLE                           B4-5427
# 1  LEVAMISOLE                            04-4163
# 2  IBUPROFEN                             A4-3786
# 3  AMOXICILLIN SODIUM BP                 B4-5264
# 4  LINCOMYCIN HYDROCHLORIDE MONOHYDRATE  B4-5262
#
#                             BRAND  \
# 0  G-ABZOLE TABLETS
# 1  RETRAX TABLETS
# 2  IBUMED SUSPENSION
# 3  KRISMOX 500MG FOR INJECTION BP
# 4  LINCOKRIS CAPSULES
#
#                                                                                                                                                                                                                                                                                                                                     ACTIVE INGREDIENT  \
# ...

# %%
df.shape
# Out:
# (6112, 16)

# %%
df.nunique()
# Out:
# PRODUCT NAME               5630
# NAFDAC                     6044
# BRAND                      4445
# ACTIVE INGREDIENT          2817
# PHARM CLASS                413
# ROUTE OF ADMINISTRATION    39
# STRENGTH                   1873
# DOSAGE FORM                118
# MARKETING STATUS           3
# APPROVED INDICATION        2645
# NAME OF APPLICANT          1801
# COUNTRY OF APPLICANT       1
# NAME OF MANUFACTURER       1145
# COUNTRY OF MANUFACTURER    60
# APPROVED DATE              73
# EXPIRY DATE                79
# dtype: int64

# %%
pd.set_option("display.max_rows", None)
pd.set_option("display.max_colwidth", -1)

# %%
np.set_printoptions(threshold=sys.maxsize)

# %%
df["NAME OF MANUFACTURER"].unique()
# Out:
# array(['           GUILIN PHARMACEUTICAL CO., LTD.',
#        '  ECOMED PHARMA LIMITED', '  SHANXI XINYITONG PHARM CO. LTD',
#        ' \tFIDSON HEALTHCARE PLC', ' AKUMS DRUGS & PHARMACEUTICALS LTD. ',
#        ' BAYER WEIMAR GMBH UND CO. KG. DOBEREINERSTRASSE 20, 99427 WEIMAR, GERMANY.',
#        ' CORAL LABORATORIES LTD ',
#        ' CSPC ZHONGNUO PHARMACEUTICAL(SHIJIAZHUANG) CO. LTD.',
#        ' EMZOR PHARMACEUTICAL INDUSTRIES LIMITED',
#        ' GLOBELA PHARMA PVT, LTD', ' GUILIN PHARMACEUTICAL CO., LTD.',
#        ' GUILIN PHARMACEUTICAL CO.,LTD. ', ' HOVID BHD.',
#        ' HUBEI KANGZHENG PHARM . CO., LTD.', ' INNOVA CAPTAB PVT. LTD',
#        ' JIANGSU RUINIAN QIANJI PHARMACEUTICAL CO., LTD',
#        ' JIANGSU RUINIAN QUIANJIN PHARMACEUTICAL CO., LTD',
#        ' JIANGXI  XIERKANGTAI  PHARMACEUTICAL CO., LTD,',
#        ' LESANTO LABORATORIES', ' LINCOLN PHARMACEUTICALS LTD',
#        ' M/S OLIVE HEALTHCARE, 197/2, ATHIYAWAD, DABHEL VILLAGE, DAMAN - 396 210, INDIA.',
# ...

# %%
df["NAME OF MANUFACTURER"].isna().sum()
# Out:
# 3

# %%
dict_list = []

# %%
#Create a dictionary of guilin variations
guilin = df[df["NAME OF MANUFACTURER"].str.contains("Guilin", na=False, case=False)]["NAME OF MANUFACTURER"]
guilin_dict = {"GUILIN PHARMACEUTICAL CO., LTD.": guilin.unique().tolist()}
dict_list.append(guilin_dict)

#Replace with correct variation for guilin
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("Guilin", case=False), "GUILIN PHARMACEUTICAL CO., LTD.", df["NAME OF MANUFACTURER"])

# %%
#Create a dictionary of ecomed
ecomed = df[df["NAME OF MANUFACTURER"].str.contains("Ecomed", na=False, case=False)]["NAME OF MANUFACTURER"]
ecomed_dict = {"ECOMED PHARMA LIMITED": ecomed.unique().tolist()}
dict_list.append(ecomed_dict)

#Replace with correct variation for ecomed
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("Ecomed", case=False), "ECOMED PHARMA LIMITED", df["NAME OF MANUFACTURER"])

# %%
shanxi_x = df[df["NAME OF MANUFACTURER"].str.contains("Shanxi Xinyitong", na=False, case=False)]["NAME OF MANUFACTURER"]
shanxi_x_dict = {"SHANXI XINYITONG PHARM CO. LTD": shanxi_x.unique().tolist()}
dict_list.append(shanxi_x_dict)

#Replace with correct variation for shanxi_x
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("Shanxi Xinyitong", case=False), "SHANXI XINYITONG PHARM CO. LTD", df["NAME OF MANUFACTURER"])

# %%
shanxi_s = df[df["NAME OF MANUFACTURER"].str.contains("Shanxi S", na=False, case=False)]["NAME OF MANUFACTURER"]
shanxi_s_dict = {"SHANXI SHUGUANG PHARMACEUTICAL CO. LTD":shanxi_s.unique().tolist()}
dict_list.append(shanxi_s_dict)

#Replace with correct variation for shanxi_s
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("Shanxi S", case=False), "SHANXI SHUGUANG PHARMACEUTICAL CO. LTD", df["NAME OF MANUFACTURER"])

# %%
#" ".join("  SHANXI  XINYITONG PHARM CO. LTD".split())

# %%
shanxi_z = df[df["NAME OF MANUFACTURER"].str.contains("Shanxi Zhongbao|SHANXI ZHONGBAO SHUGUANG", na=False, case=False)]["NAME OF MANUFACTURER"]
shanxi_z_dict = {"SHANXI ZHONGBAO SHUGUANG PHARM CO LTD": shanxi_z.unique().tolist()}
dict_list.append(shanxi_z_dict)

#Replace with correct variation for shanxi_z
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("Shanxi Zhongbao|SHANXI ZHONGBAO SHUGUANG", case=False), "SHANXI ZHONGBAO SHUGUANG PHARM CO LTD", df["NAME OF MANUFACTURER"])

# %%
fidson = df[df["NAME OF MANUFACTURER"].str.contains("Fidson", na=False, case=False)]["NAME OF MANUFACTURER"]
fidson_dict = {"FIDSON HEALTHCARE PLC": fidson.unique().tolist()}
dict_list.append(fidson_dict)

#Replace with correct variation for fidson
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("Fidson", case=False), "FIDSON HEALTHCARE PLC", df["NAME OF MANUFACTURER"])

# %%
akums = df[df["NAME OF MANUFACTURER"].str.contains("Akums", na=False, case=False)]["NAME OF MANUFACTURER"]
akums_dict = {"AKUMS DRUGS & PHARMACEUTICALS LTD": akums.unique().tolist()}
dict_list.append(akums_dict)

#Replace with correct variation for akums
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("Akums", case=False), "AKUMS DRUGS & PHARMACEUTICALS LTD", df["NAME OF MANUFACTURER"])

# %%
bayer = df[df["NAME OF MANUFACTURER"].str.contains("bayer", na=False, case=False)]["NAME OF MANUFACTURER"]
bayer_dict = {"BAYER PHARMACEUTICALS": bayer.unique().tolist()}
dict_list.append(bayer_dict)

#Replace with correct variation for bayer
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("bayer weimar", case=False), "BAYER PHARMACEUTICALS", df["NAME OF MANUFACTURER"])

# %%
coral = df[df["NAME OF MANUFACTURER"].str.contains("coral", na=False, case=False)]["NAME OF MANUFACTURER"]
coral_dict = {"CORAL LABORATORIES LTD": coral.unique().tolist()}
dict_list.append(coral_dict)

#Replace with correct variation for coral
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("coral", case=False), "CORAL LABORATORIES LTD", df["NAME OF MANUFACTURER"])

# %%
cspc_z = df[df["NAME OF MANUFACTURER"].str.contains("cspc z|cspc  z", na=False, case=False)]["NAME OF MANUFACTURER"]
cspc_z_dict = {"CSPC ZHONGNUO PHARMACEUTICAL (SHIJIAZHUANG) CO. LTD.": cspc_z.unique().tolist()}
dict_list.append(cspc_z_dict)

#Replace with correct variation for cspc_z
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("cspc z|cspc  z", case=False), "CSPC ZHONGNUO PHARMACEUTICAL (SHIJIAZHUANG) CO. LTD.", df["NAME OF MANUFACTURER"])

# %%
df["NAME OF MANUFACTURER"].unique()
# Out:
# array(['GUILIN PHARMACEUTICAL CO., LTD.', 'ECOMED PHARMA LIMITED',
#        'SHANXI XINYITONG PHARM CO. LTD', 'FIDSON HEALTHCARE PLC',
#        'AKUMS DRUGS & PHARMACEUTICALS LTD', 'BAYER PHARMACEUTICALS',
#        'CORAL LABORATORIES LTD',
#        'CSPC ZHONGNUO PHARMACEUTICAL (SHIJIAZHUANG) CO. LTD.',
#        ' EMZOR PHARMACEUTICAL INDUSTRIES LIMITED',
#        ' GLOBELA PHARMA PVT, LTD', ' HOVID BHD.',
#        ' HUBEI KANGZHENG PHARM . CO., LTD.', ' INNOVA CAPTAB PVT. LTD',
#        ' JIANGSU RUINIAN QIANJI PHARMACEUTICAL CO., LTD',
#        ' JIANGSU RUINIAN QUIANJIN PHARMACEUTICAL CO., LTD',
#        ' JIANGXI  XIERKANGTAI  PHARMACEUTICAL CO., LTD,',
#        ' LESANTO LABORATORIES', ' LINCOLN PHARMACEUTICALS LTD',
#        ' M/S OLIVE HEALTHCARE, 197/2, ATHIYAWAD, DABHEL VILLAGE, DAMAN - 396 210, INDIA.',
#        ' M/S SYNCOM FORMULATIONS ( INDIA) LIMITED, ',
#        ' MAKCUR LABORATORIES LIMITED', ' MARS REMEDIES PVT LTD',
# ...

# %%
emzor = df[df["NAME OF MANUFACTURER"].str.contains("emzor", na=False, case=False)]["NAME OF MANUFACTURER"]
emzor_dict = {"EMZOR PHARMACEUTICALS INDUSTRIES LIMITED": emzor.unique().tolist()}
dict_list.append(emzor_dict)

#Replace with correct variation for emzor
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("emzor", case=False), "EMZOR PHARMACEUTICALS INDUSTRIES LIMITED", df["NAME OF MANUFACTURER"])

# %%
globela = df[df["NAME OF MANUFACTURER"].str.contains("globela|globella", na=False, case=False)]["NAME OF MANUFACTURER"]
globela_dict = {"GLOBELA PHARMA PVT. LTD.": globela.unique().tolist()}
dict_list.append(globela_dict)

#Replace with correct variation for globela
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("globela|globella", case=False), "GLOBELA PHARMA PVT. LTD.", df["NAME OF MANUFACTURER"])

# %%
hovid = df[df["NAME OF MANUFACTURER"].str.contains("hovid", na=False, case=False)]["NAME OF MANUFACTURER"]
hovid_dict = {"HOVID BHD.":hovid.unique().tolist()}
dict_list.append(hovid_dict)

#Replace with correct variation for hovid
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("hovid", case=False), "HOVID BHD.", df["NAME OF MANUFACTURER"])

# %%
hubei = df[((df["NAME OF MANUFACTURER"].str.contains("hubei tian", na=False, case=False)) & (df["NAME OF MANUFACTURER"].str.contains("Tianjin", case=False) == False))]["NAME OF MANUFACTURER"]
hubei_dict = {"HUBEI TIANYAO PHARM CO LTD": hubei.unique().tolist()}
dict_list.append(hubei_dict)

#Replace with correct variation for hubei tian
df["NAME OF MANUFACTURER"] = np.where(((df["NAME OF MANUFACTURER"].str.contains("hubei tian", na=False, case=False)) & (df["NAME OF MANUFACTURER"].str.contains("Tianjin", case=False) == False)), "HUBEI TIANYAO PHARM CO LTD", df["NAME OF MANUFACTURER"])

# %%
innova = df[df["NAME OF MANUFACTURER"].str.contains("innova", na=False, case=False)]["NAME OF MANUFACTURER"]
innova_dict = {"INNOVA CAPTAB PVT LTD": innova.unique().tolist()}
dict_list.append(innova_dict)

#Replace with correct variation for innova
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("innova", case=False), "INNOVA CAPTAB PVT LTD", df["NAME OF MANUFACTURER"])

# %%
jiangsu_r = df[df["NAME OF MANUFACTURER"].str.contains("jiangsu r", na=False, case=False)]["NAME OF MANUFACTURER"]
jiangsu_r_dict = {"JIANGSU RUINIAN QIANJIN PHARMACEUTICALS CO., LTD": jiangsu_r.unique().tolist()}
dict_list.append(jiangsu_r_dict)

#Replace with correct variation for jiangsu_r
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("jiangsu r", case=False), "JIANGSU RUINIAN QIANJIN PHARMACEUTICALS CO., LTD", df["NAME OF MANUFACTURER"])

# %%
jiangxi = df[df["NAME OF MANUFACTURER"].str.contains("jiangxi", na=False, case=False)]["NAME OF MANUFACTURER"]
jiangxi_dict = {"JIANGXI XIER KANGTAI PHARMACEUTICAL CO. LTD": jiangxi.unique().tolist()}
dict_list.append(jiangxi_dict)

#Replace with correct variation for jiangxi
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("jiangxi", case=False), "JIANGXI XIER KANGTAI PHARMACEUTICAL CO. LTD", df["NAME OF MANUFACTURER"])

# %%
lesanto = df[df["NAME OF MANUFACTURER"].str.contains("lesanto", na=False, case=False)]["NAME OF MANUFACTURER"]
lesanto_dict = {"LESANTO LABORATORIES": lesanto.unique().tolist()}
dict_list.append(lesanto_dict)

#Replace with correct variation for lesanto
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("lesanto", case=False), "LESANTO LABORATORIES", df["NAME OF MANUFACTURER"])

# %%
lincoln = df[df["NAME OF MANUFACTURER"].str.contains("lincoln", na=False, case=False)]["NAME OF MANUFACTURER"]
lincoln_dict = {"LINCOLN PHARMACEUTICALS LTD": lincoln.unique().tolist()}
dict_list.append(lincoln_dict)

#Replace with correct variation for lincoln
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("lincoln", case=False), "LINCOLN PHARMACEUTICALS LTD", df["NAME OF MANUFACTURER"])

# %%
df["NAME OF MANUFACTURER"].unique()
# Out:
# array(['GUILIN PHARMACEUTICAL CO., LTD.', 'ECOMED PHARMA LIMITED',
#        'SHANXI XINYITONG PHARM CO. LTD', 'FIDSON HEALTHCARE PLC',
#        'AKUMS DRUGS & PHARMACEUTICALS LTD', 'BAYER PHARMACEUTICALS',
#        'CORAL LABORATORIES LTD',
#        'CSPC ZHONGNUO PHARMACEUTICAL (SHIJIAZHUANG) CO. LTD.',
#        'EMZOR PHARMACEUTICALS INDUSTRIES LIMITED',
#        'GLOBELA PHARMA PVT. LTD.', 'HOVID BHD.',
#        ' HUBEI KANGZHENG PHARM . CO., LTD.', 'INNOVA CAPTAB PVT LTD',
#        'JIANGSU RUINIAN QIANJIN PHARMACEUTICALS CO., LTD',
#        'JIANGXI XIER KANGTAI PHARMACEUTICAL CO. LTD',
#        'LESANTO LABORATORIES', 'LINCOLN PHARMACEUTICALS LTD',
#        ' M/S OLIVE HEALTHCARE, 197/2, ATHIYAWAD, DABHEL VILLAGE, DAMAN - 396 210, INDIA.',
#        ' M/S SYNCOM FORMULATIONS ( INDIA) LIMITED, ',
#        ' MAKCUR LABORATORIES LIMITED', ' MARS REMEDIES PVT LTD',
#        ' MCCOY PHARMA PVT CO. LTD', ' MCW HEALTHCARE PVT. LTD.',
# ...

# %%
olive = df[df["NAME OF MANUFACTURER"].str.contains("olive", na=False, case=False)]["NAME OF MANUFACTURER"]
olive_dict = {"OLIVE HEALTHCARE": olive.unique().tolist()}
dict_list.append(olive_dict)

#Replace with correct variation for olive
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("olive", case=False), "OLIVE HEALTHCARE", df["NAME OF MANUFACTURER"])

# %%
syncom = df[df["NAME OF MANUFACTURER"].str.contains("syncom", na=False, case=False)]["NAME OF MANUFACTURER"]
syncom_dict = {"SYNCOM FORMULATIONS (INDIA) LTD": syncom.unique().tolist()}
dict_list.append(syncom_dict)

#Replace with correct variation for syncom
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("syncom", case=False), "SYNCOM FORMULATIONS (INDIA) LTD", df["NAME OF MANUFACTURER"])

# %%
makcur = df[df["NAME OF MANUFACTURER"].str.contains("makcur|mackur", na=False, case=False)]["NAME OF MANUFACTURER"]
makcur_dict = {"MAKCUR LABORATORIES LIMITED": makcur.unique().tolist()}
dict_list.append(makcur_dict)

#Replace with correct variation for makcur
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("makcur|mackur", case=False), "MAKCUR LABORATORIES LIMITED", df["NAME OF MANUFACTURER"])

# %%
mars = df[df["NAME OF MANUFACTURER"].str.contains("mars", na=False, case=False)]["NAME OF MANUFACTURER"]
mars_dict = {"MARS REMEDIES PVT LTD": mars.unique().tolist()}
dict_list.append(mars_dict)

#Replace with correct variation for mars
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("mars", case=False), "MARS REMEDIES PVT LTD", df["NAME OF MANUFACTURER"])

# %%
mccoy = df[df["NAME OF MANUFACTURER"].str.contains("mccoy", na=False, case=False)]["NAME OF MANUFACTURER"]
mccoy_dict = {"McCOY PHARMA PVT LTD": mccoy.unique().tolist()}
dict_list.append(mccoy_dict)

#Replace with correct variation for mccoy
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("mccoy", case=False), "McCOY PHARMA PVT LTD", df["NAME OF MANUFACTURER"])

# %%
mcw = df[df["NAME OF MANUFACTURER"].str.contains("mcw", na=False, case=False)]["NAME OF MANUFACTURER"]
mcw_dict = {"MCW HEALTHCARE PVT LTD": mcw.unique().tolist()}
dict_list.append(mcw_dict)

#Replace with correct variation for mcw
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("mcw", case=False), "MCW HEALTHCARE PVT LTD", df["NAME OF MANUFACTURER"])

# %%
nitin = df[df["NAME OF MANUFACTURER"].str.contains("nitin", na=False, case=False)]["NAME OF MANUFACTURER"]
nitin_dict = {"NITIN LIFESCIENCES LTD.": nitin.unique().tolist()}
dict_list.append(nitin_dict)

#Replace with correct variation for nitin
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("nitin", case=False), "NITIN LIFESCIENCES LTD.", df["NAME OF MANUFACTURER"])

# %%
osaka = df[df["NAME OF MANUFACTURER"].str.contains("osaka", na=False, case=False)]["NAME OF MANUFACTURER"]
osaka_dict = {"OSAKA PHARMACEUTICALS PVT. LTD.": osaka.unique().tolist()}
dict_list.append(osaka_dict)

#Replace with correct variation for osaka
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("osaka", case=False), "OSAKA PHARMACEUTICALS PVT. LTD.", df["NAME OF MANUFACTURER"])

# %%
reyoung = df[df["NAME OF MANUFACTURER"].str.contains("reyoung", na=False, case=False)]["NAME OF MANUFACTURER"]
reyoung.unique()
reyoung_dict = {"REYOUNG PHARMACEUTICAL CO. LTD": reyoung.unique().tolist()}
dict_list.append(reyoung_dict)

#Replace with correct variation for reyoung
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("reyoung", case=False), "REYOUNG PHARMACEUTICAL CO. LTD", df["NAME OF MANUFACTURER"])

# %%
stallion = df[df["NAME OF MANUFACTURER"].str.contains("stallion", na=False, case=False)]["NAME OF MANUFACTURER"]
stallion_dict = {"STALLION LABORATORIES PVT. LTD": stallion.unique().tolist()}
dict_list.append(stallion_dict)

#Replace with correct variation for stallion
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("stallion", case=False), "STALLION LABORATORIES PVT. LTD", df["NAME OF MANUFACTURER"])

# %%
sun = df[df["NAME OF MANUFACTURER"].str.contains("sun pharma", na=False, case=False)]["NAME OF MANUFACTURER"]
sun_dict = {"SUN PHARMACEUTICAL IND. LTD": sun.unique().tolist()}
dict_list.append(sun_dict)

#Replace with correct variation for sun
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("sun", case=False), "SUN PHARMACEUTICAL IND. LTD", df["NAME OF MANUFACTURER"])

# %%
unijules = df[df["NAME OF MANUFACTURER"].str.contains("unijules", na=False, case=False)]["NAME OF MANUFACTURER"]
unijules_dict = {"UNIJULES LIFE SCIENCES LTD.": unijules.unique().tolist()}
dict_list.append(unijules_dict)

#Replace with correct variation for unijules
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("unijules", case=False), "UNIJULES LIFE SCIENCES LTD.", df["NAME OF MANUFACTURER"])

# %%
vs = df[((df["NAME OF MANUFACTURER"].str.contains("v.s int", na=False, case=False)) | (df["NAME OF MANUFACTURER"].str.contains("v.s. int", na=False, case=False)))]["NAME OF MANUFACTURER"]
vs_dict = {"V.S. INTERNATIONAL PVT. LTD": vs.unique().tolist()}
dict_list.append(vs_dict)

#Replace with correct variation for vs
df["NAME OF MANUFACTURER"] = np.where(((df["NAME OF MANUFACTURER"].str.contains("v.s int", na=False, case=False)) | (df["NAME OF MANUFACTURER"].str.contains("v.s. int", na=False, case=False))), "V.S. INTERNATIONAL PVT. LTD", df["NAME OF MANUFACTURER"])

# %%
zhejhiang_dnd = df[df["NAME OF MANUFACTURER"].str.contains("zhejiang dnd", na=False, case=False)]["NAME OF MANUFACTURER"]
zhejhiang_dnd_dict = {"ZHEJIANG DND PHARMACEUTICAL CO. LTD.": zhejhiang_dnd.unique().tolist()}
dict_list.append(zhejhiang_dnd_dict)

#Replace with correct variation for zhejhiang_dnd
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("zhejhiang dnd", case=False), "ZHEJIANG DND PHARMACEUTICAL CO. LTD.", df["NAME OF MANUFACTURER"])

# %%
macleods = df[df["NAME OF MANUFACTURER"].str.contains("macleods", na=False, case=False)]["NAME OF MANUFACTURER"]
macleods_dict = {"MACLEODS PHARMACEUTICALS LTD": macleods.unique().tolist()}
dict_list.append(macleods_dict)

#Replace with correct variation for macleods
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("macleods", case=False), "MACLEODS PHARMACEUTICALS LTD", df["NAME OF MANUFACTURER"])

# %%
df["NAME OF MANUFACTURER"].unique()
# Out:
# array(['GUILIN PHARMACEUTICAL CO., LTD.', 'ECOMED PHARMA LIMITED',
#        'SHANXI XINYITONG PHARM CO. LTD', 'FIDSON HEALTHCARE PLC',
#        'AKUMS DRUGS & PHARMACEUTICALS LTD', 'BAYER PHARMACEUTICALS',
#        'CORAL LABORATORIES LTD',
#        'CSPC ZHONGNUO PHARMACEUTICAL (SHIJIAZHUANG) CO. LTD.',
#        'EMZOR PHARMACEUTICALS INDUSTRIES LIMITED',
#        'GLOBELA PHARMA PVT. LTD.', 'HOVID BHD.',
#        ' HUBEI KANGZHENG PHARM . CO., LTD.', 'INNOVA CAPTAB PVT LTD',
#        'JIANGSU RUINIAN QIANJIN PHARMACEUTICALS CO., LTD',
#        'JIANGXI XIER KANGTAI PHARMACEUTICAL CO. LTD',
#        'LESANTO LABORATORIES', 'LINCOLN PHARMACEUTICALS LTD',
#        'OLIVE HEALTHCARE', 'SYNCOM FORMULATIONS (INDIA) LTD',
#        'MAKCUR LABORATORIES LIMITED', 'MARS REMEDIES PVT LTD',
#        'McCOY PHARMA PVT LTD', 'MCW HEALTHCARE PVT LTD',
#        'NITIN LIFESCIENCES LTD.', 'OSAKA PHARMACEUTICALS PVT. LTD.',
# ...

# %%
aj = df[df["NAME OF MANUFACTURER"].str.contains("A & J", na=False, case=False)]["NAME OF MANUFACTURER"]
aj_dict = {"A & J PHARMACEUTICAL NIGERIA LIMITED": aj.unique().tolist()}
dict_list.append(aj_dict)

#Replace with correct variation for aj
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("A & J", case=False), "A & J PHARMACEUTICAL NIGERIA LIMITED", df["NAME OF MANUFACTURER"])

# %%
ac_drugs = df[df["NAME OF MANUFACTURER"].str.contains("AC DRUGS|A C DRUGS", na=False, case=False)]["NAME OF MANUFACTURER"]
ac_drugs_dict = {"AC DRUGS LTD": ac_drugs.unique().tolist()}
dict_list.append(ac_drugs_dict)

#Replace with correct variation for ac drugs
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("AC DRUGS| A C DRUGS", na=False, case=False), "A & J PHARMACEUTICAL NIGERIA LIMITED", df["NAME OF MANUFACTURER"])

# %%
a_natter = df[df["NAME OF MANUFACTURER"].str.contains("A. Natter", na=False, case=False)]["NAME OF MANUFACTURER"]
a_natter_dict = {"A. NATTERMAN & CIE": a_natter.unique().tolist()}
dict_list.append(a_natter_dict)

#Replace with correct variation for a_natter
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("A. Natter", case=False), "A. NATTERMAN & CIE", df["NAME OF MANUFACTURER"])

# %%
abaris = df[df["NAME OF MANUFACTURER"].str.contains("abaris", na=False, case=False)]["NAME OF MANUFACTURER"]
abaris_dict = {"ABARIS HEALTHCARE PVT LTD": abaris.unique().tolist()}
dict_list.append(abaris_dict)

#Replace with correct variation for abaris
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("abaris", case=False), "ABARIS HEALTHCARE PVT LTD", df["NAME OF MANUFACTURER"])

# %%
abbott = df[df["NAME OF MANUFACTURER"].str.contains("abbot", na=False, case=False)]["NAME OF MANUFACTURER"]
abbott_dict = {"ABBOTT BIOLOGICALS": abbott.unique().tolist()}
dict_list.append(abbott_dict)

#Replace with correct variation for abbott
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("abbot", case=False), "ABBOTT BIOLOGICALSS", df["NAME OF MANUFACTURER"])

# %%
abbvie = df[df["NAME OF MANUFACTURER"].str.contains("abbvie", na=False, case=False)]["NAME OF MANUFACTURER"]
abbvie_dict = {"ABBVIE INC.": abbvie.unique().tolist()}
dict_list.append(abbvie_dict)

#Replace with correct variation for abbvie
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("abbvie", case=False), "ABBVIE INC.", df["NAME OF MANUFACTURER"])

# %%
accord = df[df["NAME OF MANUFACTURER"].str.contains("accord", na=False, case=False)]["NAME OF MANUFACTURER"]
accord_dict = {"ACCORD UK LTD": accord.unique().tolist()}
dict_list.append(accord_dict)

#Replace with correct variation for accord
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("accord", case=False), "ACCORD UK LTD", df["NAME OF MANUFACTURER"])

# %%
df["NAME OF MANUFACTURER"].unique()
# Out:
# array(['GUILIN PHARMACEUTICAL CO., LTD.', 'ECOMED PHARMA LIMITED',
#        'SHANXI XINYITONG PHARM CO. LTD', 'FIDSON HEALTHCARE PLC',
#        'AKUMS DRUGS & PHARMACEUTICALS LTD', 'BAYER PHARMACEUTICALS',
#        'CORAL LABORATORIES LTD',
#        'CSPC ZHONGNUO PHARMACEUTICAL (SHIJIAZHUANG) CO. LTD.',
#        'EMZOR PHARMACEUTICALS INDUSTRIES LIMITED',
#        'GLOBELA PHARMA PVT. LTD.', 'HOVID BHD.',
#        ' HUBEI KANGZHENG PHARM . CO., LTD.', 'INNOVA CAPTAB PVT LTD',
#        'JIANGSU RUINIAN QIANJIN PHARMACEUTICALS CO., LTD',
#        'JIANGXI XIER KANGTAI PHARMACEUTICAL CO. LTD',
#        'LESANTO LABORATORIES', 'LINCOLN PHARMACEUTICALS LTD',
#        'OLIVE HEALTHCARE', 'SYNCOM FORMULATIONS (INDIA) LTD',
#        'MAKCUR LABORATORIES LIMITED', 'MARS REMEDIES PVT LTD',
#        'McCOY PHARMA PVT LTD', 'MCW HEALTHCARE PVT LTD',
#        'NITIN LIFESCIENCES LTD.', 'OSAKA PHARMACEUTICALS PVT. LTD.',
# ...

# %%
acino = df[df["NAME OF MANUFACTURER"].str.contains("acino", na=False, case=False)]["NAME OF MANUFACTURER"]
acino_dict = {"ACINO PHARMA AG": acino.unique().tolist()}
dict_list.append(acino_dict)

#Replace with correct variation for acino
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("acino", case=False), "ACINO PHARMA AG", df["NAME OF MANUFACTURER"])

# %%
acme = df[df["NAME OF MANUFACTURER"].str.contains("acme", na=False, case=False)]["NAME OF MANUFACTURER"]
acme_dict = {"ACME FORMULATION PVT LTD": acme.unique().tolist()}
dict_list.append(acme_dict)

#Replace with correct variation for acme
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("acme", case=False), "ACME FORMULATION PVT LTD", df["NAME OF MANUFACTURER"])

# %%
acromax = df[df["NAME OF MANUFACTURER"].str.contains("acromax", na=False, case=False)]["NAME OF MANUFACTURER"]
acromax_dict = {"ACROMAX DOMINICANA S.A": acromax.unique().tolist()}
dict_list.append(acromax_dict)

#Replace with correct variation for acromax
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("acromax", case=False), "ACROMAX DOMINICANA S.A", df["NAME OF MANUFACTURER"])

# %%
aculife = df[df["NAME OF MANUFACTURER"].str.contains("aculife", na=False, case=False)]["NAME OF MANUFACTURER"]
aculife_dict = {"ACULIFE HEALTHCARE PVT. LTD": aculife.unique().tolist()}
dict_list.append(aculife_dict)

#Replace with correct variation for aculife
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("aculife", case=False), "ACULIFE HEALTHCARE PVT. LTD", df["NAME OF MANUFACTURER"])

# %%
adler = df[df["NAME OF MANUFACTURER"].str.contains("adler", na=False, case=False)]["NAME OF MANUFACTURER"]
adler_dict = {"ADLER PRODUCTS LTD.": adler.unique().tolist()}
dict_list.append(adler_dict)

#Replace with correct variation for adler
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("adler", case=False), "ADLER PRODUCTS LTD.", df["NAME OF MANUFACTURER"])

# %%
adley = df[df["NAME OF MANUFACTURER"].str.contains("adley", na=False, case=False)]["NAME OF MANUFACTURER"]
adley_dict = {"ADLEY FORMULATIONS": adley.unique().tolist()}
dict_list.append(adley_dict)

#Replace with correct variation for adley
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("adley", case=False), "ADLEY FORMULATIONS", df["NAME OF MANUFACTURER"])

# %%
admac = df[df["NAME OF MANUFACTURER"].str.contains("admac", na=False, case=False)]["NAME OF MANUFACTURER"]
admac_dict = {"ADMAC LIFESCIENCE": admac.unique().tolist()}
dict_list.append(admac_dict)

#Replace with correct variation for admac
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("admac", case=False), "ADMAC LIFESCIENCE", df["NAME OF MANUFACTURER"])

# %%
adore = df[df["NAME OF MANUFACTURER"].str.contains("adore", na=False, case=False)]["NAME OF MANUFACTURER"]
adore_dict = {"ADORE PHARMACEUTICAL PVT LTD": adore.unique().tolist()}
dict_list.append(adore_dict)

#Replace with correct variation for adore
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("adore", case=False), "ADORE PHARMACEUTICAL PVT LTD", df["NAME OF MANUFACTURER"])

# %%
advance_p = df[df["NAME OF MANUFACTURER"].str.contains("advance pharm", na=False, case=False)]["NAME OF MANUFACTURER"]
advance_p_dict = {"ADVANCE PHARMA GMBH & CO": advance_p.unique().tolist()}
dict_list.append(advance_p_dict)

#Replace with correct variation for advance_p
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("advance pharm", case=False), "ADVANCE PHARMA GMBH & CO", df["NAME OF MANUFACTURER"])

# %%
advanced = df[df["NAME OF MANUFACTURER"].str.contains("advanced", na=False, case=False)]["NAME OF MANUFACTURER"]
advanced_dict = {"ADVANCED CHEMICAL  INDUSTRIES LIMITED": advanced.unique().tolist()}
dict_list.append(advanced_dict)

#Replace with correct variation for advanced
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("advanced", case=False), "ADVANCED CHEMICAL  INDUSTRIES LIMITED", df["NAME OF MANUFACTURER"])

# %%
df["NAME OF MANUFACTURER"].unique()
# Out:
# array(['GUILIN PHARMACEUTICAL CO., LTD.', 'ECOMED PHARMA LIMITED',
#        'SHANXI XINYITONG PHARM CO. LTD', 'FIDSON HEALTHCARE PLC',
#        'AKUMS DRUGS & PHARMACEUTICALS LTD', 'BAYER PHARMACEUTICALS',
#        'CORAL LABORATORIES LTD',
#        'CSPC ZHONGNUO PHARMACEUTICAL (SHIJIAZHUANG) CO. LTD.',
#        'EMZOR PHARMACEUTICALS INDUSTRIES LIMITED',
#        'GLOBELA PHARMA PVT. LTD.', 'HOVID BHD.',
#        ' HUBEI KANGZHENG PHARM . CO., LTD.', 'INNOVA CAPTAB PVT LTD',
#        'JIANGSU RUINIAN QIANJIN PHARMACEUTICALS CO., LTD',
#        'JIANGXI XIER KANGTAI PHARMACEUTICAL CO. LTD',
#        'LESANTO LABORATORIES', 'LINCOLN PHARMACEUTICALS LTD',
#        'OLIVE HEALTHCARE', 'SYNCOM FORMULATIONS (INDIA) LTD',
#        'MAKCUR LABORATORIES LIMITED', 'MARS REMEDIES PVT LTD',
#        'McCOY PHARMA PVT LTD', 'MCW HEALTHCARE PVT LTD',
#        'NITIN LIFESCIENCES LTD.', 'OSAKA PHARMACEUTICALS PVT. LTD.',
# ...

# %%
aero = df[df["NAME OF MANUFACTURER"].str.contains("aero", na=False, case=False)]["NAME OF MANUFACTURER"]
aero_dict = {"AEROPHARM GMBH": aero.unique().tolist()}
dict_list.append(aero_dict)

#Replace with correct variation for aero
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("aero", case=False), "AEROPHARM GMBH", df["NAME OF MANUFACTURER"])

# %%
aesica = df[df["NAME OF MANUFACTURER"].str.contains("aesica", na=False, case=False)]["NAME OF MANUFACTURER"]
aesica_dict = {"AESICA QUEENBOROUGH LTD": aesica.unique().tolist()}
dict_list.append(aesica_dict)

#Replace with correct variation for aesica
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("aesica", case=False), "AESICA QUEENBOROUGH LTD", df["NAME OF MANUFACTURER"])

# %%
afrab = df[df["NAME OF MANUFACTURER"].str.contains("afrab", na=False, case=False)]["NAME OF MANUFACTURER"]
afrab_dict = {"AFRAB CHEM LTD": afrab.unique().tolist()}
dict_list.append(afrab_dict)

#Replace with correct variation for afrab
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("afrab", case=False), "AFRAB CHEM LTD", df["NAME OF MANUFACTURER"])

# %%
afromed = df[df["NAME OF MANUFACTURER"].str.contains("afromed", na=False, case=False)]["NAME OF MANUFACTURER"]
afromed_dict = {"AFROMED INDUSTRIES LTD.": afromed.unique().tolist()}
dict_list.append(afromed_dict)

#Replace with correct variation for afromed
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("afromed", case=False), "AFROMED INDUSTRIES LTD.", df["NAME OF MANUFACTURER"])

# %%
agary = df[df["NAME OF MANUFACTURER"].str.contains("agary", na=False, case=False)]["NAME OF MANUFACTURER"]
agary_dict = {"AGARY PHARMACEUTICAL LIMITED": agary.unique().tolist()}
dict_list.append(agary_dict)

#Replace with correct variation for agary
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("agary", case=False), "AGARY PHARMACEUTICAL LIMITED", df["NAME OF MANUFACTURER"])

# %%
aglowmed = df[df["NAME OF MANUFACTURER"].str.contains("aglowmed", na=False, case=False)]["NAME OF MANUFACTURER"]
aglowmed_dict = {"AGLOWMED LIMITED": aglowmed.unique().tolist()}
dict_list.append(aglowmed_dict)

#Replace with correct variation for aglowmed
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("aglowmed", case=False), "AGLOWMED LIMITED", df["NAME OF MANUFACTURER"])

# %%
ahlcon = df[df["NAME OF MANUFACTURER"].str.contains("ahlcon", na=False, case=False)]["NAME OF MANUFACTURER"]
ahlcon_dict = {"AHLCON PARENTERALS (INDIA) LIMITED": ahlcon.unique().tolist()}
dict_list.append(ahlcon_dict)

#Replace with correct variation for ahlcon
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("ahlcon", case=False), "AHLCON PARENTERALS (INDIA) LIMITED", df["NAME OF MANUFACTURER"])

# %%
aishwarya = df[df["NAME OF MANUFACTURER"].str.contains("aishwarya", na=False, case=False)]["NAME OF MANUFACTURER"]
aishwarya_dict = {"AISHWARYA LIFESCIENCES": aishwarya.unique().tolist()}
dict_list.append(aishwarya_dict)

#Replace with correct variation for aishwarya
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("aishwarya", case=False), "AISHWARYA LIFESCIENCES", df["NAME OF MANUFACTURER"])

# %%
ajanta = df[df["NAME OF MANUFACTURER"].str.contains("ajanta", na=False, case=False)]["NAME OF MANUFACTURER"]
ajanta_dict = {"AJANTA PHARMA LIMITED": ajanta.unique().tolist()}
dict_list.append(ajanta_dict)

#Replace with correct variation for ajanta
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("ajanta", case=False), "AJANTA PHARMA LIMITED", df["NAME OF MANUFACTURER"])

# %%
akorn = df[df["NAME OF MANUFACTURER"].str.contains("akorn", na=False, case=False)]["NAME OF MANUFACTURER"]
akorn_dict = {"AKORN INC.": akorn.unique().tolist()}
dict_list.append(akorn_dict)

#Replace with correct variation for akorn
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("akorn", case=False), "AKORN INC.", df["NAME OF MANUFACTURER"])

# %%
df["NAME OF MANUFACTURER"].unique()
# Out:
# array(['GUILIN PHARMACEUTICAL CO., LTD.', 'ECOMED PHARMA LIMITED',
#        'SHANXI XINYITONG PHARM CO. LTD', 'FIDSON HEALTHCARE PLC',
#        'AKUMS DRUGS & PHARMACEUTICALS LTD', 'BAYER PHARMACEUTICALS',
#        'CORAL LABORATORIES LTD',
#        'CSPC ZHONGNUO PHARMACEUTICAL (SHIJIAZHUANG) CO. LTD.',
#        'EMZOR PHARMACEUTICALS INDUSTRIES LIMITED',
#        'GLOBELA PHARMA PVT. LTD.', 'HOVID BHD.',
#        ' HUBEI KANGZHENG PHARM . CO., LTD.', 'INNOVA CAPTAB PVT LTD',
#        'JIANGSU RUINIAN QIANJIN PHARMACEUTICALS CO., LTD',
#        'JIANGXI XIER KANGTAI PHARMACEUTICAL CO. LTD',
#        'LESANTO LABORATORIES', 'LINCOLN PHARMACEUTICALS LTD',
#        'OLIVE HEALTHCARE', 'SYNCOM FORMULATIONS (INDIA) LTD',
#        'MAKCUR LABORATORIES LIMITED', 'MARS REMEDIES PVT LTD',
#        'McCOY PHARMA PVT LTD', 'MCW HEALTHCARE PVT LTD',
#        'NITIN LIFESCIENCES LTD.', 'OSAKA PHARMACEUTICALS PVT. LTD.',
# ...

# %%
akriti = df[df["NAME OF MANUFACTURER"].str.contains("akriti", na=False, case=False)]["NAME OF MANUFACTURER"]
akriti_dict = {"AKRITI PHARMACEUTICALS PVT LTD.": akriti.unique().tolist()}
dict_list.append(akriti_dict)

#Replace with correct variation for akriti
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("akriti", case=False), "AKRITI PHARMACEUTICALS PVT LTD.", df["NAME OF MANUFACTURER"])

# %%
alben = df[df["NAME OF MANUFACTURER"].str.contains("alben", na=False, case=False)]["NAME OF MANUFACTURER"]
alben_dict = {"ALBEN HEALTHCARE INDUSTRIES LIMITED": alben.unique().tolist()}
dict_list.append(alben_dict)

#Replace with correct variation for alben
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("alben", case=False), "ALBEN HEALTHCARE INDUSTRIES LIMITED", df["NAME OF MANUFACTURER"])

# %%
alchemy = df[df["NAME OF MANUFACTURER"].str.contains("alchemy", na=False, case=False)]["NAME OF MANUFACTURER"]
alchemy_dict = {"ALCHEMY MEDICINE PVT LTD": alchemy.unique().tolist()}
dict_list.append(alchemy_dict)

#Replace with correct variation for alchemy
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("alchemy", case=False), "ALCHEMY MEDICINE PVT LTD", df["NAME OF MANUFACTURER"])

# %%
alcon_c = df[df["NAME OF MANUFACTURER"].str.contains("alcon-c", na=False, case=False)]["NAME OF MANUFACTURER"]
alcon_c_dict = {"ALCON-COUVREUR": alcon_c.unique().tolist()}
dict_list.append(alcon_c_dict)

#Replace with correct variation for alcon_c
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("alcon_c", case=False), "ALCON-COUVREUR", df["NAME OF MANUFACTURER"])

# %%
alpa = df[df["NAME OF MANUFACTURER"].str.contains("alpa", na=False, case=False)]["NAME OF MANUFACTURER"]
alpa_dict = {"ALPA LABORATORIES LTD.": alpa.unique().tolist()}
dict_list.append(alpa_dict)

#Replace with correct variation for alpa
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("alpa", case=False), "ALPA LABORATORIES LTD.", df["NAME OF MANUFACTURER"])

# %%
amanta = df[df["NAME OF MANUFACTURER"].str.contains("amanta", na=False, case=False)]["NAME OF MANUFACTURER"]
amanta_dict = {"AMANTA HEALTHCARE LTD.": amanta.unique().tolist()}
dict_list.append(amanta_dict)

#Replace with correct variation for amanta
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("amanta", case=False), "AMANTA HEALTHCARE LTD.", df["NAME OF MANUFACTURER"])

# %%
ambix = df[df["NAME OF MANUFACTURER"].str.contains("ambix", na=False, case=False)]["NAME OF MANUFACTURER"]
ambix_dict = {"AMBIX HEALTHCARE LLP.": ambix.unique().tolist()}
dict_list.append(ambix_dict)

#Replace with correct variation for ambix
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("ambix", case=False), "AMBIX HEALTHCARE LLP", df["NAME OF MANUFACTURER"])

# %%
amriya = df[df["NAME OF MANUFACTURER"].str.contains("amriya", na=False, case=False)]["NAME OF MANUFACTURER"]
amriya_dict = {"AMRIYA PHARMACEUTICALS INDUSTRIES": amriya.unique().tolist()}
dict_list.append(amriya_dict)

#Replace with correct variation for amriya
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("amriya", case=False), "AMRIYA PHARMACEUTICALS INDUSTRIES", df["NAME OF MANUFACTURER"])

# %%
anhui_c = df[df["NAME OF MANUFACTURER"].str.contains("anhui chengshi", na=False, case=False)]["NAME OF MANUFACTURER"]
anhui_c_dict = {"ANHUI CHENGSHI PHARMACEUTICAL CO. LTD": anhui_c.unique().tolist()}
dict_list.append(anhui_c_dict)

#Replace with correct variation for anhui_c
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("anhui chengshi", case=False), "ANHUI CHENGSHI PHARMACEUTICAL CO. LTD", df["NAME OF MANUFACTURER"])

# %%
anhui_n = df[df["NAME OF MANUFACTURER"].str.contains("anhui nuhu", na=False, case=False)]["NAME OF MANUFACTURER"]
anhui_n_dict = {"ANHUI NUHU PHARM CO LTD": anhui_n.unique().tolist()}
dict_list.append(anhui_n_dict)

#Replace with correct variation for anhui_n
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("anhui chengshi", case=False), "ANHUI NUHU PHARM CO LTD", df["NAME OF MANUFACTURER"])

# %%
df["NAME OF MANUFACTURER"].unique()
# Out:
# array(['GUILIN PHARMACEUTICAL CO., LTD.', 'ECOMED PHARMA LIMITED',
#        'SHANXI XINYITONG PHARM CO. LTD', 'FIDSON HEALTHCARE PLC',
#        'AKUMS DRUGS & PHARMACEUTICALS LTD', 'BAYER PHARMACEUTICALS',
#        'CORAL LABORATORIES LTD',
#        'CSPC ZHONGNUO PHARMACEUTICAL (SHIJIAZHUANG) CO. LTD.',
#        'EMZOR PHARMACEUTICALS INDUSTRIES LIMITED',
#        'GLOBELA PHARMA PVT. LTD.', 'HOVID BHD.',
#        ' HUBEI KANGZHENG PHARM . CO., LTD.', 'INNOVA CAPTAB PVT LTD',
#        'JIANGSU RUINIAN QIANJIN PHARMACEUTICALS CO., LTD',
#        'JIANGXI XIER KANGTAI PHARMACEUTICAL CO. LTD',
#        'LESANTO LABORATORIES', 'LINCOLN PHARMACEUTICALS LTD',
#        'OLIVE HEALTHCARE', 'SYNCOM FORMULATIONS (INDIA) LTD',
#        'MAKCUR LABORATORIES LIMITED', 'MARS REMEDIES PVT LTD',
#        'McCOY PHARMA PVT LTD', 'MCW HEALTHCARE PVT LTD',
#        'NITIN LIFESCIENCES LTD.', 'OSAKA PHARMACEUTICALS PVT. LTD.',
# ...

# %%
anpharm = df[df["NAME OF MANUFACTURER"].str.contains("anpharm", na=False, case=False)]["NAME OF MANUFACTURER"]
anpharm_dict = {"ANPHARM PRZEDSIEBIORSTWO FARMACEUTYCZNE": anpharm.unique().tolist()}
dict_list.append(anpharm_dict)

#Replace with correct variation for anpharm
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("anpharm", case=False), "ANPHARM PRZEDSIEBIORSTWO FARMACEUTYCZNE", df["NAME OF MANUFACTURER"])

# %%
antila = df[df["NAME OF MANUFACTURER"].str.contains("antilla|antila", na=False, case=False)]["NAME OF MANUFACTURER"]
antila_dict = {"ANTILA LIFESCIENCES PVT LTD": antila.unique().tolist()}
dict_list.append(antila_dict)

#Replace with correct variation for antila
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("antila", case=False), "ANTILLA LIFESCIENCES PVT LTD", df["NAME OF MANUFACTURER"])

# %%
apacco = df[df["NAME OF MANUFACTURER"].str.contains("apacco", na=False, case=False)]["NAME OF MANUFACTURER"]
apacco_dict = {"APACCO PHARMA NIG. LTD": apacco.unique().tolist()}
dict_list.append(apacco_dict)

#Replace with correct variation for apacco
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("apacco", case=False), "APACCO PHARMA NIG. LTD", df["NAME OF MANUFACTURER"])

# %%
apex_f = df[df["NAME OF MANUFACTURER"].str.contains("apex f", na=False, case=False)]["NAME OF MANUFACTURER"]
apex_f_dict = {"APEX FORMULATION PVT LTD": apex_f.unique().tolist()}
dict_list.append(apex_f_dict)

#Replace with correct variation for apex_f
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("apex f", case=False), "APEX FORMULATION PVT LTD", df["NAME OF MANUFACTURER"])

# %%
apex_l = df[df["NAME OF MANUFACTURER"].str.contains("apex l", na=False, case=False)]["NAME OF MANUFACTURER"]
apex_l_dict = {"APEX LABORATORIES PVT LIMITED": apex_l.unique().tolist()}
dict_list.append(apex_l_dict)

#Replace with correct variation for apex_l
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("apex l", case=False), "APEX LABORATORIES PVT LIMITED", df["NAME OF MANUFACTURER"])

# %%
apex_p = df[df["NAME OF MANUFACTURER"].str.contains("apex p", na=False, case=False)]["NAME OF MANUFACTURER"]
apex_p_dict = {"APEX PHARMA PRIVATE LTD.": apex_p.unique().tolist()}
dict_list.append(apex_p_dict)

#Replace with correct variation for apex_p
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("apex p", case=False), "APEX PHARMA PRIVATE LTD.", df["NAME OF MANUFACTURER"])

# %%
apollo = df[df["NAME OF MANUFACTURER"].str.contains("apollo ", na=False, case=False)]["NAME OF MANUFACTURER"]
apollo_dict = {"APOLLO PHARMA": apollo.unique().tolist()}
dict_list.append(apollo_dict)

#Replace with correct variation for apollo
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("apollo", case=False), "APOLLO PHARMA", df["NAME OF MANUFACTURER"])

# %%
aqua = df[df["NAME OF MANUFACTURER"].str.contains("aqua vitoe", na=False, case=False)]["NAME OF MANUFACTURER"]
aqua_dict = {"AQUA VITOE LABORATORIES": aqua.unique().tolist()}
dict_list.append(aqua_dict)

#Replace with correct variation for aqua
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("aqua vitoe", case=False), "AQUA VITOE LABORATORIES", df["NAME OF MANUFACTURER"])

# %%
archy = df[df["NAME OF MANUFACTURER"].str.contains("archy", na=False, case=False)]["NAME OF MANUFACTURER"]
archy_dict = {"ARCHY PHARMACEUTICAL LTD": archy.unique().tolist()}
dict_list.append(archy_dict)

#Replace with correct variation for archy
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("archy", case=False), "ARCHY PHARMACEUTICAL LTD", df["NAME OF MANUFACTURER"])

# %%
 
ardeypharm = df[df["NAME OF MANUFACTURER"].str.contains("ardeypharm", na=False, case=False)]["NAME OF MANUFACTURER"]
ardeypharm_dict = {"ARDEYPHARM GMBH": ardeypharm.unique().tolist()}
dict_list.append(ardeypharm_dict)

#Replace with correct variation for ardeypharm
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("ardeypharm", case=False), "ARDEYPHARM GMBH", df["NAME OF MANUFACTURER"])

# %%
aristopharma = df[df["NAME OF MANUFACTURER"].str.contains("aristopharma", na=False, case=False)]["NAME OF MANUFACTURER"]
aristopharma_dict = {"ARISTOPHARMA LIMITED": aristopharma.unique().tolist()}
dict_list.append(aristopharma_dict)

#Replace with correct variation for aristopharma
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("aristopharma", case=False), "ARISTOPHARMA LIMITED", df["NAME OF MANUFACTURER"])

# %%
artesan = df[df["NAME OF MANUFACTURER"].str.contains("artesan", na=False, case=False)]["NAME OF MANUFACTURER"]
artesan_dict = {"ARTESAN PHARMA GMBH & CO.": artesan.unique().tolist()}
dict_list.append(artesan_dict)

#Replace with correct variation for artesan
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("artesan", case=False), "ARTESAN PHARMA GMBH & CO.", df["NAME OF MANUFACTURER"])

# %%
arwan = df[df["NAME OF MANUFACTURER"].str.contains("arwan", na=False, case=False)]["NAME OF MANUFACTURER"]
arwan_dict = {"ARWAN PHARMACEUTICAL INDUSTRIES": arwan.unique().tolist()}
dict_list.append(arwan_dict)

#Replace with correct variation for arwan
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("arwan", case=False), "ARWAN PHARMACEUTICAL INDUSTRIES", df["NAME OF MANUFACTURER"])

# %%
asad = df[df["NAME OF MANUFACTURER"].str.contains("asad", na=False, case=False)]["NAME OF MANUFACTURER"]
asad_dict = {"ASAD PHARMACEUTICALS LIMITED": asad.unique().tolist()}
dict_list.append(asad_dict)

#Replace with correct variation for asad
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("asad", case=False), "ASAD PHARMACEUTICALS LIMITED", df["NAME OF MANUFACTURER"])

# %%
ashford = df[df["NAME OF MANUFACTURER"].str.contains("ashford", na=False, case=False)]["NAME OF MANUFACTURER"]
ashford_dict = {"ASHFORD LABORATORIES LTD": ashford.unique().tolist()}
dict_list.append(ashford_dict)

#Replace with correct variation for ashford
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("ashford", case=False), "ASHFORD LABORATORIES LTD", df["NAME OF MANUFACTURER"])

# %%
df["NAME OF MANUFACTURER"].unique()
# Out:
# array(['GUILIN PHARMACEUTICAL CO., LTD.', 'ECOMED PHARMA LIMITED',
#        'SHANXI XINYITONG PHARM CO. LTD', 'FIDSON HEALTHCARE PLC',
#        'AKUMS DRUGS & PHARMACEUTICALS LTD', 'BAYER PHARMACEUTICALS',
#        'CORAL LABORATORIES LTD',
#        'CSPC ZHONGNUO PHARMACEUTICAL (SHIJIAZHUANG) CO. LTD.',
#        'EMZOR PHARMACEUTICALS INDUSTRIES LIMITED',
#        'GLOBELA PHARMA PVT. LTD.', 'HOVID BHD.',
#        ' HUBEI KANGZHENG PHARM . CO., LTD.', 'INNOVA CAPTAB PVT LTD',
#        'JIANGSU RUINIAN QIANJIN PHARMACEUTICALS CO., LTD',
#        'JIANGXI XIER KANGTAI PHARMACEUTICAL CO. LTD',
#        'LESANTO LABORATORIES', 'LINCOLN PHARMACEUTICALS LTD',
#        'OLIVE HEALTHCARE', 'SYNCOM FORMULATIONS (INDIA) LTD',
#        'MAKCUR LABORATORIES LIMITED', 'MARS REMEDIES PVT LTD',
#        'McCOY PHARMA PVT LTD', 'MCW HEALTHCARE PVT LTD',
#        'NITIN LIFESCIENCES LTD.', 'OSAKA PHARMACEUTICALS PVT. LTD.',
# ...

# %%
asoj = df[df["NAME OF MANUFACTURER"].str.contains("asoj", na=False, case=False)]["NAME OF MANUFACTURER"]
asoj_dict = {"ASOJ SOFT CAPS PVT LTD": asoj.unique().tolist()}
dict_list.append(asoj_dict)

#Replace with correct variation for asoj
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("asoj", case=False), "ASOJ SOFT CAPS PVT LTD", df["NAME OF MANUFACTURER"])

# %%
aspiro = df[df["NAME OF MANUFACTURER"].str.contains("aspiro", na=False, case=False)]["NAME OF MANUFACTURER"]
aspiro_dict = {"ASPIRO PHARMA LIMITED": aspiro.unique().tolist()}
dict_list.append(aspiro_dict)

#Replace with correct variation for aspiro
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("aspiro", case=False), "ASPIRO PHARMA LIMITED", df["NAME OF MANUFACTURER"])

# %%
associated = df[df["NAME OF MANUFACTURER"].str.contains("associated", na=False, case=False)]["NAME OF MANUFACTURER"]
associated_dict = {"ASSOCIATED BIOTECH": associated.unique().tolist()}
dict_list.append(associated_dict)

#Replace with correct variation for associated
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("associated", case=False), "ASSOCIATED BIOTECH", df["NAME OF MANUFACTURER"])

# %%
astamed = df[df["NAME OF MANUFACTURER"].str.contains("astamed", na=False, case=False)]["NAME OF MANUFACTURER"]
astamed_dict = {"ASTAMED HEALTHCARE PVT LTD": astamed.unique().tolist()}
dict_list.append(astamed_dict)

#Replace with correct variation for astamed
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("astamed", case=False), "ASTAMED HEALTHCARE PVT LTD", df["NAME OF MANUFACTURER"])

# %%
astrazeneca = df[df["NAME OF MANUFACTURER"].str.contains("astrazeneca", na=False, case=False)]["NAME OF MANUFACTURER"]
astrazeneca_dict = {"ASTRAZENECA UK LIMITED": astrazeneca.unique().tolist()}
dict_list.append(astrazeneca_dict)

#Replace with correct variation for astrazeneca
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("astrazeneca", case=False), "ASTRAZENECA UK LIMITED", df["NAME OF MANUFACTURER"])

# %%
atoz = df[df["NAME OF MANUFACTURER"].str.contains("atoz", na=False, case=False)]["NAME OF MANUFACTURER"]
atoz_dict = {"ATOZ PHARMACEUTICALS PVT LTD": atoz.unique().tolist()}
dict_list.append(atoz_dict)

#Replace with correct variation for atoz
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("atoz", case=False), "ATOZ PHARMACEUTICALS PVT LTD", df["NAME OF MANUFACTURER"])

# %%
aurobindo = df[df["NAME OF MANUFACTURER"].str.contains("aurobindo", na=False, case=False)]["NAME OF MANUFACTURER"]
aurobindo_dict = {"AUROBINDO PHARMA LTD": aurobindo.unique().tolist()}
dict_list.append(aurobindo_dict)

#Replace with correct variation for aurobindo
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("aurobindo", case=False), "AUROBINDO PHARMA LTD", df["NAME OF MANUFACTURER"])

# %%
aurochem = df[df["NAME OF MANUFACTURER"].str.contains("aurochem", na=False, case=False)]["NAME OF MANUFACTURER"]
aurochem_dict = {"AUROCHEM LABORATORIES PVT LTD": aurochem.unique().tolist()}
dict_list.append(aurochem_dict)

#Replace with correct variation for aurochem
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("aurochem", case=False), "AUROCHEM LABORATORIES PVT LTD", df["NAME OF MANUFACTURER"])

# %%
auscel = df[df["NAME OF MANUFACTURER"].str.contains("auscel", na=False, case=False)]["NAME OF MANUFACTURER"]
auscel_dict = {"AUSCEL LABORATORIES LIMITED": auscel.unique().tolist()}
dict_list.append(auscel_dict)

#Replace with correct variation for auscel
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("auscel", case=False), "AUSCEL LABORATORIES LIMITED", df["NAME OF MANUFACTURER"])

# %%
avro = df[df["NAME OF MANUFACTURER"].str.contains("avro", na=False, case=False)]["NAME OF MANUFACTURER"]
avro_dict = {"AVRO PHARMA LIMITED": avro.unique().tolist()}
dict_list.append(avro_dict)

#Replace with correct variation for avro
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("avro", case=False), "AVRO PHARMA LIMITED", df["NAME OF MANUFACTURER"])

# %%
axa = df[df["NAME OF MANUFACTURER"].str.contains("axa", na=False, case=False)]["NAME OF MANUFACTURER"]
axa_dict = {"AXA PARENTERALS LTD": axa.unique().tolist()}
dict_list.append(axa_dict)

#Replace with correct variation for axa
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("axa", case=False), "AXA PARENTERALS LTD", df["NAME OF MANUFACTURER"])

# %%
ayrton = df[df["NAME OF MANUFACTURER"].str.contains("ayrton", na=False, case=False)]["NAME OF MANUFACTURER"]
ayrton_dict = {"AYRTON SAUNDERS LIMITED": ayrton.unique().tolist()}
dict_list.append(ayrton_dict)

#Replace with correct variation for ayrton
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("ayrton", case=False), "AYRTON SAUNDERS LIMITED", df["NAME OF MANUFACTURER"])

# %%
df["NAME OF MANUFACTURER"].unique()
# Out:
# array(['GUILIN PHARMACEUTICAL CO., LTD.', 'ECOMED PHARMA LIMITED',
#        'SHANXI XINYITONG PHARM CO. LTD', 'FIDSON HEALTHCARE PLC',
#        'AKUMS DRUGS & PHARMACEUTICALS LTD', 'BAYER PHARMACEUTICALS',
#        'CORAL LABORATORIES LTD',
#        'CSPC ZHONGNUO PHARMACEUTICAL (SHIJIAZHUANG) CO. LTD.',
#        'EMZOR PHARMACEUTICALS INDUSTRIES LIMITED',
#        'GLOBELA PHARMA PVT. LTD.', 'HOVID BHD.',
#        ' HUBEI KANGZHENG PHARM . CO., LTD.', 'INNOVA CAPTAB PVT LTD',
#        'JIANGSU RUINIAN QIANJIN PHARMACEUTICALS CO., LTD',
#        'JIANGXI XIER KANGTAI PHARMACEUTICAL CO. LTD',
#        'LESANTO LABORATORIES', 'LINCOLN PHARMACEUTICALS LTD',
#        'OLIVE HEALTHCARE', 'SYNCOM FORMULATIONS (INDIA) LTD',
#        'MAKCUR LABORATORIES LIMITED', 'MARS REMEDIES PVT LTD',
#        'McCOY PHARMA PVT LTD', 'MCW HEALTHCARE PVT LTD',
#        'NITIN LIFESCIENCES LTD.', 'OSAKA PHARMACEUTICALS PVT. LTD.',
# ...

# %%
braun = df[df["NAME OF MANUFACTURER"].str.contains("braun", na=False, case=False)]["NAME OF MANUFACTURER"]
braun_dict = {"B. BRAUN MEDICAL": braun.unique().tolist()}
dict_list.append(braun_dict)

#Replace with correct variation for braun
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("braun", case=False), "B. BRAUN MEDICAL", df["NAME OF MANUFACTURER"])

# %%
baader = df[df["NAME OF MANUFACTURER"].str.contains("baader", na=False, case=False)]["NAME OF MANUFACTURER"]
baader_dict = {"BAADER SCHULZ LABORATORIES": baader.unique().tolist()}
dict_list.append(baader_dict)

#Replace with correct variation for baader
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("baader", case=False), "BAADER SCHULZ LABORATORIES", df["NAME OF MANUFACTURER"])

# %%
bactolac = df[df["NAME OF MANUFACTURER"].str.contains("bactolac", na=False, case=False)]["NAME OF MANUFACTURER"]
bactolac_dict = {"BACTOLAC PHARMACEUTICAL INC.": bactolac.unique().tolist()}
dict_list.append(bactolac_dict)

#Replace with correct variation for bactolac
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("bactolac", case=False), "BACTOLAC PHARMACEUTICAL INC.", df["NAME OF MANUFACTURER"])

# %%
bafna = df[df["NAME OF MANUFACTURER"].str.contains("bafna", na=False, case=False)]["NAME OF MANUFACTURER"]
bafna_dict = {"BAFNA PHARMACEUTICALS LTD": bafna.unique().tolist()}
dict_list.append(bafna_dict)

#Replace with correct variation for bafna
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("bafna", case=False), "BAFNA PHARMACEUTICALS LTD", df["NAME OF MANUFACTURER"])

# %%
bal = df[df["NAME OF MANUFACTURER"].str.contains("bal pharma l", na=False, case=False)]["NAME OF MANUFACTURER"]
bal_dict = {"BAL PHARMA LTD": bal.unique().tolist()}
dict_list.append(bal_dict)

#Replace with correct variation for bal
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("bal pharma l", case=False), "BAL PHARMA LTD", df["NAME OF MANUFACTURER"])

# %%
balkanphama = df[df["NAME OF MANUFACTURER"].str.contains("balkanphama", na=False, case=False)]["NAME OF MANUFACTURER"]
balkanphama_dict = {"BALKANPHAMA DUPNISTA": balkanphama.unique().tolist()}
dict_list.append(balkanphama_dict)

#Replace with correct variation for balkanphama
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("balkanphama", case=False), "BALKANPHAMA DUPNISTA", df["NAME OF MANUFACTURER"])

# %%
barka = df[df["NAME OF MANUFACTURER"].str.contains("barka", na=False, case=False)]["NAME OF MANUFACTURER"]
barka_dict = {"BARKA PHARMACEUTICAL COMPANY LIMITED": barka.unique().tolist()}
dict_list.append(barka_dict)

#Replace with correct variation for barka
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("barka", case=False), "BARKA PHARMACEUTICAL COMPANY LIMITED", df["NAME OF MANUFACTURER"])

# %%
baroque = df[((df["NAME OF MANUFACTURER"].str.contains("baroque", na=False, case=False)) & (df["NAME OF MANUFACTURER"].str.contains("evans", na=False, case=False)==False))]["NAME OF MANUFACTURER"]
baroque_dict = {"BAROQUE PHARMACEUTICALS PVT. LTD.": baroque.unique().tolist()}
dict_list.append(baroque_dict)

#Replace with correct variation for baroque
df["NAME OF MANUFACTURER"] = np.where((((df["NAME OF MANUFACTURER"].str.contains("baroque", na=False, case=False)) & (df["NAME OF MANUFACTURER"].str.contains("evans", na=False, case=False)==False))), "BAROQUE PHARMACEUTICALS PVT. LTD.", df["NAME OF MANUFACTURER"])

# %%
baxter = df[df["NAME OF MANUFACTURER"].str.contains("baxter", na=False, case=False)]["NAME OF MANUFACTURER"]
baxter_dict = {"BAXTER PHARMACEUTICALS PVT. LTD.": baxter.unique().tolist()}
dict_list.append(baxter_dict)

#Replace with correct variation for baxter
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("baxter", case=False), "BAXTER PHARMACEUTICALS PVT. LTD.", df["NAME OF MANUFACTURER"])

# %%
bcn = df[df["NAME OF MANUFACTURER"].str.contains("bcn", na=False, case=False)]["NAME OF MANUFACTURER"]
bcn_dict = {"BCN PLC": bcn.unique().tolist()}
dict_list.append(bcn_dict)

#Replace with correct variation for bcn
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("bcn", case=False), "BCN PLC", df["NAME OF MANUFACTURER"])

# %%
bdh = df[df["NAME OF MANUFACTURER"].str.contains("bdh", na=False, case=False)]["NAME OF MANUFACTURER"]
bdh_dict = {"BDH INDUSTRIES LTD.": bdh.unique().tolist()}
dict_list.append(bdh_dict)

#Replace with correct variation for bdh
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("bdh", case=False), "BDH INDUSTRIES LTD.", df["NAME OF MANUFACTURER"])

# %%
bdr = df[df["NAME OF MANUFACTURER"].str.contains("bdr", na=False, case=False)]["NAME OF MANUFACTURER"]
bdr_dict = {"BDR PHARM INT'L PVT LTD": bdr.unique().tolist()}
dict_list.append(bdr_dict)

#Replace with correct variation for bdr
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("bdr", case=False), "BDR PHARM INT'L PVT LTD", df["NAME OF MANUFACTURER"])

# %%
df["NAME OF MANUFACTURER"].unique()
# Out:
# array(['GUILIN PHARMACEUTICAL CO., LTD.', 'ECOMED PHARMA LIMITED',
#        'SHANXI XINYITONG PHARM CO. LTD', 'FIDSON HEALTHCARE PLC',
#        'AKUMS DRUGS & PHARMACEUTICALS LTD', 'BAYER PHARMACEUTICALS',
#        'CORAL LABORATORIES LTD',
#        'CSPC ZHONGNUO PHARMACEUTICAL (SHIJIAZHUANG) CO. LTD.',
#        'EMZOR PHARMACEUTICALS INDUSTRIES LIMITED',
#        'GLOBELA PHARMA PVT. LTD.', 'HOVID BHD.',
#        ' HUBEI KANGZHENG PHARM . CO., LTD.', 'INNOVA CAPTAB PVT LTD',
#        'JIANGSU RUINIAN QIANJIN PHARMACEUTICALS CO., LTD',
#        'JIANGXI XIER KANGTAI PHARMACEUTICAL CO. LTD',
#        'LESANTO LABORATORIES', 'LINCOLN PHARMACEUTICALS LTD',
#        'OLIVE HEALTHCARE', 'SYNCOM FORMULATIONS (INDIA) LTD',
#        'MAKCUR LABORATORIES LIMITED', 'MARS REMEDIES PVT LTD',
#        'McCOY PHARMA PVT LTD', 'MCW HEALTHCARE PVT LTD',
#        'NITIN LIFESCIENCES LTD.', 'OSAKA PHARMACEUTICALS PVT. LTD.',
# ...

# %%
beenie = df[df["NAME OF MANUFACTURER"].str.contains("beenie", na=False, case=False)]["NAME OF MANUFACTURER"]
beenie_dict = {"BEENIE INDUSTRIES LIMITED": beenie.unique().tolist()}
dict_list.append(beenie_dict)

#Replace with correct variation for beenie
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("beenie", case=False), "BEENIE INDUSTRIES LIMITED", df["NAME OF MANUFACTURER"])

# %%
bell = df[df["NAME OF MANUFACTURER"].str.contains("bell sons", na=False, case=False)]["NAME OF MANUFACTURER"]
bell_dict = {"BELL SONS & CO. (DRUGGIST) LTD.": bell.unique().tolist()}
dict_list.append(bell_dict)

#Replace with correct variation for bell
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("bell sons", case=False), "BELL SONS & CO. (DRUGGIST) LTD.", df["NAME OF MANUFACTURER"])

# %%
bentos = df[df["NAME OF MANUFACTURER"].str.contains("bentos", na=False, case=False)]["NAME OF MANUFACTURER"]
bentos_dict = {"BENTOS PHARMACEUTICAL PRODUCTS LIMITED": bentos.unique().tolist()}
dict_list.append(bentos_dict)

#Replace with correct variation for bentos
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("bentos", case=False), "BENTOS PHARMACEUTICAL PRODUCTS LIMITED", df["NAME OF MANUFACTURER"])

# %%
beta = df[df["NAME OF MANUFACTURER"].str.contains("beta health", na=False, case=False)]["NAME OF MANUFACTURER"]
beta_dict = {"BETA HEALTHCARE INT'L LTD": beta.unique().tolist()}
dict_list.append(beta_dict)

#Replace with correct variation for beta
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("beta", case=False), "BETA HEALTHCARE INT'L LTD", df["NAME OF MANUFACTURER"])

# %%
beximco = df[df["NAME OF MANUFACTURER"].str.contains("beximco", na=False, case=False)]["NAME OF MANUFACTURER"]
beximco_dict = {"BEXIMCO PHARMACEUTICALS LIMITED": beximco.unique().tolist()}
dict_list.append(beximco_dict)

#Replace with correct variation for beximco
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("beximco", case=False), "BEXIMCO PHARMACEUTICALS LIMITED", df["NAME OF MANUFACTURER"])

# %%
bharat_p = df[df["NAME OF MANUFACTURER"].str.contains("bharat p", na=False, case=False)]["NAME OF MANUFACTURER"]
bharat_p_dict = {"BHARAT PARENTERALS LTD": bharat_p.unique().tolist()}
dict_list.append(bharat_p_dict)

#Replace with correct variation for bharat_p
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("bharat p", case=False), "BHARAT PARENTERALS LTD", df["NAME OF MANUFACTURER"])

# %%
bharat_s = df[df["NAME OF MANUFACTURER"].str.contains("bharat s", na=False, case=False)]["NAME OF MANUFACTURER"]
bharat_s_dict = {"BHARAT SERUMS AND VACCINES LTD": bharat_s.unique().tolist()}
dict_list.append(bharat_s_dict)

#Replace with correct variation for bharat_s
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("bharat s", case=False), "BHARAT SERUMS AND VACCINES LTD", df["NAME OF MANUFACTURER"])

# %%
biomedical = df[df["NAME OF MANUFACTURER"].str.contains("biomedical", na=False, case=False)]["NAME OF MANUFACTURER"]
biomedical_dict = {"BIOMEDICAL LTD": biomedical.unique().tolist()}
dict_list.append(biomedical_dict)

#Replace with correct variation for biomedical
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("biomedical", case=False), "BIOMEDICAL LTD", df["NAME OF MANUFACTURER"])

# %%
biopharma = df[df["NAME OF MANUFACTURER"].str.contains("biopharma n", na=False, case=False)]["NAME OF MANUFACTURER"]
biopharma_dict = {"BIOPHARMA NIG LTD": biopharma.unique().tolist()}
dict_list.append(biopharma_dict)

#Replace with correct variation for biopharma
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("biopharma", case=False), "BIOPHARMA NIG LTD", df["NAME OF MANUFACTURER"])

# %%
bioraj = df[df["NAME OF MANUFACTURER"].str.contains("bioraj", na=False, case=False)]["NAME OF MANUFACTURER"]
bioraj_dict = {"BIORAJ PHARMACEUTICALS LTD": bioraj.unique().tolist()}
dict_list.append(bioraj_dict)

#Replace with correct variation for bioraj
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("bioraj", case=False), "BIORAJ PHARMACEUTICALS LTD", df["NAME OF MANUFACTURER"])

# %%
df["NAME OF MANUFACTURER"].unique()
# Out:
# array(['GUILIN PHARMACEUTICAL CO., LTD.', 'ECOMED PHARMA LIMITED',
#        'SHANXI XINYITONG PHARM CO. LTD', 'FIDSON HEALTHCARE PLC',
#        'AKUMS DRUGS & PHARMACEUTICALS LTD', 'BAYER PHARMACEUTICALS',
#        'CORAL LABORATORIES LTD',
#        'CSPC ZHONGNUO PHARMACEUTICAL (SHIJIAZHUANG) CO. LTD.',
#        'EMZOR PHARMACEUTICALS INDUSTRIES LIMITED',
#        'GLOBELA PHARMA PVT. LTD.', 'HOVID BHD.',
#        ' HUBEI KANGZHENG PHARM . CO., LTD.', 'INNOVA CAPTAB PVT LTD',
#        'JIANGSU RUINIAN QIANJIN PHARMACEUTICALS CO., LTD',
#        'JIANGXI XIER KANGTAI PHARMACEUTICAL CO. LTD',
#        'LESANTO LABORATORIES', 'LINCOLN PHARMACEUTICALS LTD',
#        'OLIVE HEALTHCARE', 'SYNCOM FORMULATIONS (INDIA) LTD',
#        'MAKCUR LABORATORIES LIMITED', 'MARS REMEDIES PVT LTD',
#        'McCOY PHARMA PVT LTD', 'MCW HEALTHCARE PVT LTD',
#        'NITIN LIFESCIENCES LTD.', 'OSAKA PHARMACEUTICALS PVT. LTD.',
# ...

# %%
blacktrend = df[df["NAME OF MANUFACTURER"].str.contains("blacktrend", na=False, case=False)]["NAME OF MANUFACTURER"]
blacktrend_dict = {"BLACKTREND INTL LTD": blacktrend.unique().tolist()}

dict_list.append(blacktrend_dict)

#Replace with correct variation for blacktrend
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("blacktrend"), "BLACKTREND INTL LTD", df["NAME OF MANUFACTURER"])

# %%
bliss = df[(df["NAME OF MANUFACTURER"].str.contains("bliss", na=False, case=False)) & (df["NAME OF MANUFACTURER"].str.contains("GVS", na=False, case=False))]["NAME OF MANUFACTURER"]
bliss_dict = {"BLISS GVS PHARMA LTD.": bliss.unique().tolist()}
dict_list.append(bliss_dict)

#Replace with correct variation for bliss
df["NAME OF MANUFACTURER"] = np.where(((df["NAME OF MANUFACTURER"].str.contains("bliss", na=False, case=False)) & (df["NAME OF MANUFACTURER"].str.contains("GVS", na=False, case=False))), "BLISS GVS PHARMA LTD.", df["NAME OF MANUFACTURER"])

# %%
blueworld = df[df["NAME OF MANUFACTURER"].str.contains("bluewo", na=False, case=False)]["NAME OF MANUFACTURER"]
blueworld_dict = {"BLUEWORLD PHARMACEUTICALS, FOODS AND COSMETICS LIMITED": blueworld.unique().tolist()}
dict_list.append(blueworld_dict)

#Replace with correct variation for blueworld
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("blueworld", case=False), "BLUEWORLD PHARMACEUTICALS, FOODS AND COSMETICS LIMITED", df["NAME OF MANUFACTURER"])

# %%
boehringer = df[df["NAME OF MANUFACTURER"].str.contains("boehringer", na=False, case=False)]["NAME OF MANUFACTURER"]
boehringer_dict = {"BOEHRINGER INGELHEIM PHARMA GMBH & CO": boehringer.unique().tolist()}
dict_list.append(boehringer_dict)

#Replace with correct variation for boehringer
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("boehringer", na=False, case=False), "BOEHRINGER INGELHEIM PHARMA GMBH & CO", df["NAME OF MANUFACTURER"])

# %%
bond = df[(df["NAME OF MANUFACTURER"].str.contains("bond", na=False, case=False)) & (df["NAME OF MANUFACTURER"].str.contains("jiangsu", na=False, case=False)==False)]["NAME OF MANUFACTURER"]
bond_dict = {"BOND CHEMICAL INDUSTRIES LTD": bond.unique().tolist()}
dict_list.append(bond_dict)

#Replace with correct variation for bond
df["NAME OF MANUFACTURER"] = np.where(((df["NAME OF MANUFACTURER"].str.contains("bond", na=False, case=False)) & (df["NAME OF MANUFACTURER"].str.contains("jiangsu", na=False, case=False)==False)), "BOND CHEMICAL INDUSTRIES LTD", df["NAME OF MANUFACTURER"])

# %%
boryung = df[df["NAME OF MANUFACTURER"].str.contains("boryung", na=False, case=False)]["NAME OF MANUFACTURER"]
boryung_dict = {"BORYUNG PHARM CO. LTD.": boryung.unique().tolist()}
dict_list.append(boryung_dict)

#Replace with correct variation for boryung
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("boryung", case=False), "BORYUNG PHARM CO. LTD.", df["NAME OF MANUFACTURER"])

# %%
bradford = df[df["NAME OF MANUFACTURER"].str.contains("bradford", na=False, case=False)]["NAME OF MANUFACTURER"]
bradford_dict = {"BRADFORD PHARMACEUTICALS LTD": bradford.unique().tolist()}
dict_list.append(bradford_dict)

#Replace with correct variation for bradford
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("bradford", case=False), "BRADFORD PHARMACEUTICALS LTD", df["NAME OF MANUFACTURER"])

# %%
brawn = df[df["NAME OF MANUFACTURER"].str.contains("brawn", na=False, case=False)]["NAME OF MANUFACTURER"]
brawn_dict = {"BRAWN LABORATORIES LIMITED": brawn.unique().tolist()}
dict_list.append(brawn_dict)

#Replace with correct variation for brawn
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("brawn", case=False), "BRAWN LABORATORIES LIMITED", df["NAME OF MANUFACTURER"])

# %%
bristol = df[df["NAME OF MANUFACTURER"].str.contains("bristol", na=False, case=False)]["NAME OF MANUFACTURER"]
bristol_dict = {"BRISTOL-MYERS SQUIBB MANUFACTURING COMPANY": bristol.unique().tolist()}
dict_list.append(bristol_dict)

#Replace with correct variation for bristol
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("bristol", case=False), "BRISTOL-MYERS SQUIBB MANUFACTURING COMPANY", df["NAME OF MANUFACTURER"])

# %%
briyosis = df[df["NAME OF MANUFACTURER"].str.contains("briyosis", na=False, case=False)]["NAME OF MANUFACTURER"]
briyosis_dict = {"BRIYOSIS SOFT CAPS PVT LTD": briyosis.unique().tolist()}
dict_list.append(briyosis_dict)

#Replace with correct variation for briyosis
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("briyosis", case=False), "BRIYOSIS SOFT CAPS PVT LTD", df["NAME OF MANUFACTURER"])

# %%
df["NAME OF MANUFACTURER"].unique()
# Out:
# array(['GUILIN PHARMACEUTICAL CO., LTD.', 'ECOMED PHARMA LIMITED',
#        'SHANXI XINYITONG PHARM CO. LTD', 'FIDSON HEALTHCARE PLC',
#        'AKUMS DRUGS & PHARMACEUTICALS LTD', 'BAYER PHARMACEUTICALS',
#        'CORAL LABORATORIES LTD',
#        'CSPC ZHONGNUO PHARMACEUTICAL (SHIJIAZHUANG) CO. LTD.',
#        'EMZOR PHARMACEUTICALS INDUSTRIES LIMITED',
#        'GLOBELA PHARMA PVT. LTD.', 'HOVID BHD.',
#        ' HUBEI KANGZHENG PHARM . CO., LTD.', 'INNOVA CAPTAB PVT LTD',
#        'JIANGSU RUINIAN QIANJIN PHARMACEUTICALS CO., LTD',
#        'JIANGXI XIER KANGTAI PHARMACEUTICAL CO. LTD',
#        'LESANTO LABORATORIES', 'LINCOLN PHARMACEUTICALS LTD',
#        'OLIVE HEALTHCARE', 'SYNCOM FORMULATIONS (INDIA) LTD',
#        'MAKCUR LABORATORIES LIMITED', 'MARS REMEDIES PVT LTD',
#        'McCOY PHARMA PVT LTD', 'MCW HEALTHCARE PVT LTD',
#        'NITIN LIFESCIENCES LTD.', 'OSAKA PHARMACEUTICALS PVT. LTD.',
# ...

# %%
brookes = df[df["NAME OF MANUFACTURER"].str.contains("brookes", na=False, case=False)]["NAME OF MANUFACTURER"]
brookes_dict = {"BROOKES PHARMA PRIVATE LIMITED": brookes.unique().tolist()}
dict_list.append(brookes_dict)

#Replace with correct variation for brookes
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("brookes", case=False), "BROOKES PHARMA PRIVATE LIMITED", df["NAME OF MANUFACTURER"])

# %%
brooks = df[df["NAME OF MANUFACTURER"].str.contains("brooks", na=False, case=False)]["NAME OF MANUFACTURER"]
brooks_dict = {"BROOKS LABORATORIES LIMITED": brooks.unique().tolist()}
dict_list.append(brooks_dict)

#Replace with correct variation for brooks
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("brooks", case=False), "BROOKS LABORATORIES LIMITED", df["NAME OF MANUFACTURER"])

# %%
brussels = df[df["NAME OF MANUFACTURER"].str.contains("brussels", na=False, case=False)]["NAME OF MANUFACTURER"]
brussels_dict = {"BRUSSELS LABORATORIES PVT. LTD.": brussels.unique().tolist()}
dict_list.append(brussels_dict)

#Replace with correct variation for brussels
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("brussels", case=False), "BRUSSELS LABORATORIES PVT. LTD.", df["NAME OF MANUFACTURER"])

# %%
cachet = df[df["NAME OF MANUFACTURER"].str.contains("cachet|catchet", na=False, case=False)]["NAME OF MANUFACTURER"]
cachet_dict = {"CACHET PHARMACEUTICALS PVT LTD": cachet.unique().tolist()}
dict_list.append(cachet_dict)

#Replace with correct variation for cachet
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("cachet|catchet", case=False), "CACHET PHARMACEUTICALS PVT LTD", df["NAME OF MANUFACTURER"])

# %%
cadila = df[df["NAME OF MANUFACTURER"].str.contains("cadila", na=False, case=False)]["NAME OF MANUFACTURER"]
cadila_dict = {"CADILA PHARMACEUTICALS LTD": cadila.unique().tolist()}
dict_list.append(cadila_dict)

#Replace with correct variation for cadila
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("cadila", case=False), "CADILA PHARMACEUTICALS LTD", df["NAME OF MANUFACTURER"])

# %%
cambridge = df[df["NAME OF MANUFACTURER"].str.contains("cambridge", na=False, case=False)]["NAME OF MANUFACTURER"]
cambridge_dict = {"CAMBRIDGE HEALTHCARE LTD": cambridge.unique().tolist()}
dict_list.append(cambridge_dict)

#Replace with correct variation for cambridge
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("cambridge", case=False), "CAMBRIDGE HEALTHCARE LTD", df["NAME OF MANUFACTURER"])

# %%
campharm = df[df["NAME OF MANUFACTURER"].str.contains("campharm", na=False, case=False)]["NAME OF MANUFACTURER"]
campharm_dict = {"CAMPHARM PRODUCTS LIMITED": campharm.unique().tolist()}
dict_list.append(campharm_dict)

#Replace with correct variation for campharm
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("campharm", case=False), "CAMPHARM PRODUCTS LIMITED", df["NAME OF MANUFACTURER"])

# %%
cardinal = df[df["NAME OF MANUFACTURER"].str.contains("cardinal", na=False, case=False)]["NAME OF MANUFACTURER"]
cardinal_dict = {"CARDINAL DRUGS LIMITED": cardinal.unique().tolist()}
dict_list.append(cardinal_dict)

#Replace with correct variation for cardinal
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("cardinal", case=False), "CARDINAL DRUGS LIMITED", df["NAME OF MANUFACTURER"])

# %%
catalent = df[df["NAME OF MANUFACTURER"].str.contains("catalent", na=False, case=False)]["NAME OF MANUFACTURER"]
catalent_dict = {"CATALENT": catalent.unique().tolist()}
dict_list.append(catalent_dict)

#Replace with correct variation for catalent
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("catalent", case=False), "CATALENT", df["NAME OF MANUFACTURER"])

# %%
df["NAME OF MANUFACTURER"].unique()
# Out:
# array(['GUILIN PHARMACEUTICAL CO., LTD.', 'ECOMED PHARMA LIMITED',
#        'SHANXI XINYITONG PHARM CO. LTD', 'FIDSON HEALTHCARE PLC',
#        'AKUMS DRUGS & PHARMACEUTICALS LTD', 'BAYER PHARMACEUTICALS',
#        'CORAL LABORATORIES LTD',
#        'CSPC ZHONGNUO PHARMACEUTICAL (SHIJIAZHUANG) CO. LTD.',
#        'EMZOR PHARMACEUTICALS INDUSTRIES LIMITED',
#        'GLOBELA PHARMA PVT. LTD.', 'HOVID BHD.',
#        ' HUBEI KANGZHENG PHARM . CO., LTD.', 'INNOVA CAPTAB PVT LTD',
#        'JIANGSU RUINIAN QIANJIN PHARMACEUTICALS CO., LTD',
#        'JIANGXI XIER KANGTAI PHARMACEUTICAL CO. LTD',
#        'LESANTO LABORATORIES', 'LINCOLN PHARMACEUTICALS LTD',
#        'OLIVE HEALTHCARE', 'SYNCOM FORMULATIONS (INDIA) LTD',
#        'MAKCUR LABORATORIES LIMITED', 'MARS REMEDIES PVT LTD',
#        'McCOY PHARMA PVT LTD', 'MCW HEALTHCARE PVT LTD',
#        'NITIN LIFESCIENCES LTD.', 'OSAKA PHARMACEUTICALS PVT. LTD.',
# ...

# %%
cechem = df[df["NAME OF MANUFACTURER"].str.contains("ce-chem", na=False, case=False)]["NAME OF MANUFACTURER"]
cechem_dict = {"CE-CHEM PHARM PVT LTD": cechem.unique().tolist()}
dict_list.append(cechem_dict)

#Replace with correct variation for cechem
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("ce-chem", case=False), "CE-CHEM PHARM PVT LTD", df["NAME OF MANUFACTURER"])

# %%
celogen = df[df["NAME OF MANUFACTURER"].str.contains("celogen", na=False, case=False)]["NAME OF MANUFACTURER"]
celogen_dict = {"CELOGEN GENERICS PVT LTD": celogen.unique().tolist()}
dict_list.append(celogen_dict)

#Replace with correct variation for celogen
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("celogen", case=False), "CELOGEN GENERICS PVT LTD", df["NAME OF MANUFACTURER"])

# %%
celon = df[df["NAME OF MANUFACTURER"].str.contains("celon", na=False, case=False)]["NAME OF MANUFACTURER"]
celon_dict = {"CELON LABORATORIES PVT LTD": celon.unique().tolist()}
dict_list.append(celon_dict)

#Replace with correct variation for celon
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("celon", case=False), "CELON LABORATORIES PVT LTD", df["NAME OF MANUFACTURER"])

# %%
cenexi = df[df["NAME OF MANUFACTURER"].str.contains("cenexi", na=False, case=False)]["NAME OF MANUFACTURER"]
cenexi_dict = {"CENEXI": cenexi.unique().tolist()}
dict_list.append(cenexi_dict)

#Replace with correct variation for cenexi
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("cenexi", case=False), "CENEXI", df["NAME OF MANUFACTURER"])

# %%
centaur = df[df["NAME OF MANUFACTURER"].str.contains("centaur", na=False, case=False)]["NAME OF MANUFACTURER"]
centaur_dict = {"CENTAUR PHARMACEUTICALS PVT LTD.": centaur.unique().tolist()}
dict_list.append(centaur_dict)

#Replace with correct variation for centaur
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("centaur", case=False), "CENTAUR PHARMACEUTICALS PVT LTD.", df["NAME OF MANUFACTURER"])

# %%
centurion = df[df["NAME OF MANUFACTURER"].str.contains("centurion", na=False, case=False)]["NAME OF MANUFACTURER"]
centurion_dict = {"CENTURION LABORATORIES": centurion.unique().tolist()}
dict_list.append(centurion_dict)

#Replace with correct variation for centurion
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("centurion", case=False), "CENTURION LABORATORIES", df["NAME OF MANUFACTURER"])

# %%
chemiron = df[df["NAME OF MANUFACTURER"].str.contains("chemiron", na=False, case=False)]["NAME OF MANUFACTURER"]
chemiron_dict = {"CHEMIRON CARE LTD.": chemiron.unique().tolist()}
dict_list.append(chemiron_dict)

#Replace with correct variation for chemiron
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("chemiron", case=False), "CHEMIRON CARE LTD.", df["NAME OF MANUFACTURER"])

# %%
chemo = df[df["NAME OF MANUFACTURER"].str.contains("chemo", na=False, case=False)]["NAME OF MANUFACTURER"]
chemo_dict = {"CHEMO PHARMA LABORATORIES LTD": chemo.unique().tolist()}
dict_list.append(chemo_dict)

#Replace with correct variation for chemo
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("chemo", case=False), "CHEMO PHARMA LABORATORIES LTD", df["NAME OF MANUFACTURER"])

# %%
chi = df[df["NAME OF MANUFACTURER"].str.contains("chi pharm", na=False, case=False)]["NAME OF MANUFACTURER"]
chi_dict = {"CHI PHARM LTD": chi.unique().tolist()}
dict_list.append(chi_dict)

#Replace with correct variation for chi
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("chi pharm", case=False), "CHI PHARM LTD", df["NAME OF MANUFACTURER"])

# %%
chiros = df[df["NAME OF MANUFACTURER"].str.contains("chiros", na=False, case=False)]["NAME OF MANUFACTURER"]
chiros_dict = {"CHIROS PHARMA": chiros.unique().tolist()}
dict_list.append(chiros_dict)

#Replace with correct variation for chiros
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("chiros", case=False), "CHIROS PHARMA", df["NAME OF MANUFACTURER"])

# %%
cilag = df[df["NAME OF MANUFACTURER"].str.contains("cilag ag", na=False, case=False)]["NAME OF MANUFACTURER"]
cilag_dict = {"CILAG AG": cilag.unique().tolist()}
dict_list.append(cilag_dict)

#Replace with correct variation for cilag
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("cilag ag", case=False), "CILAG AG", df["NAME OF MANUFACTURER"])

# %%
cipla = df[(df["NAME OF MANUFACTURER"].str.contains("cipl", na=False, case=False)) & (df["NAME OF MANUFACTURER"].str.contains("principle", na=False, case=False)==False)]["NAME OF MANUFACTURER"]
cipla_dict = {"CIPLA QUALITY CHEMICAL INDUSTRIES LIMITED": cipla.unique().tolist()}
dict_list.append(cipla_dict)

#Replace with correct variation for cipla
df["NAME OF MANUFACTURER"] = np.where(((df["NAME OF MANUFACTURER"].str.contains("cipl", na=False, case=False)) & (df["NAME OF MANUFACTURER"].str.contains("principle", na=False, case=False)==False)), "CIPLA QUALITY CHEMICAL INDUSTRIES LIMITED", df["NAME OF MANUFACTURER"])

# %%
ciron = df[df["NAME OF MANUFACTURER"].str.contains("ciron", na=False, case=False)]["NAME OF MANUFACTURER"]
ciron_dict = {"CIRON DRUGS AND PHARMACEUTICALS PVT. LTD": ciron.unique().tolist()}
dict_list.append(ciron_dict)

#Replace with correct variation for ciron
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("ciron", case=False), "CIRON DRUGS AND PHARMACEUTICALS PVT. LTD", df["NAME OF MANUFACTURER"])

# %%
cisen = df[df["NAME OF MANUFACTURER"].str.contains("cisen", na=False, case=False)]["NAME OF MANUFACTURER"]
cisen_dict = {"CISEN PHARMACEUTICAL CO. LIMITED": cisen.unique().tolist()}
dict_list.append(cisen_dict)

#Replace with correct variation for cisen
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("cisen", case=False), "CISEN PHARMACEUTICAL CO. LIMITED", df["NAME OF MANUFACTURER"])

# %%
clarion = df[df["NAME OF MANUFACTURER"].str.contains("clarion", na=False, case=False)]["NAME OF MANUFACTURER"]
clarion_dict = {"CLARION INDIA": clarion.unique().tolist()}
dict_list.append(clarion_dict)

#Replace with correct variation for clarion
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("clarion", case=False), "CLARION INDIA", df["NAME OF MANUFACTURER"])

# %%
colep = df[df["NAME OF MANUFACTURER"].str.contains("colep", na=False, case=False)]["NAME OF MANUFACTURER"]
colep_dict = {"COLEP LAUPHEIM GMBH & CO.": colep.unique().tolist()}
dict_list.append(colep_dict)

#Replace with correct variation for colep
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("colep", case=False), "COLEP LAUPHEIM GMBH & CO.", df["NAME OF MANUFACTURER"])

# %%
comed = df[df["NAME OF MANUFACTURER"].str.contains("comed chem", na=False, case=False)]["NAME OF MANUFACTURER"]
comed_dict = {"COMED CHEMICALS LTD.": comed.unique().tolist()}
dict_list.append(comed_dict)

#Replace with correct variation for comed
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("comed chem", case=False), "COMED CHEMICALS LTD.", df["NAME OF MANUFACTURER"])

# %%
contract = df[df["NAME OF MANUFACTURER"].str.contains("contract", na=False, case=False)]["NAME OF MANUFACTURER"]
contract_dict = {"CONTRACT MANUFACTURING & PACKAGING SERVICES PTY LTD": contract.unique().tolist()}
dict_list.append(contract_dict)

#Replace with correct variation for contract
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("contract", case=False), "CONTRACT MANUFACTURING & PACKAGING SERVICES PTY LTD", df["NAME OF MANUFACTURER"])

# %%
cooper = df[df["NAME OF MANUFACTURER"].str.contains("cooper", na=False, case=False)]["NAME OF MANUFACTURER"]
cooper_dict = {"COOPER PHARMA LTD": cooper.unique().tolist()}
dict_list.append(cooper_dict)

#Replace with correct variation for cooper
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("cooper", case=False), "COOPER PHARMA LTD", df["NAME OF MANUFACTURER"])

# %%
corden = df[df["NAME OF MANUFACTURER"].str.contains("corden", na=False, case=False)]["NAME OF MANUFACTURER"]
corden_dict = {"CORDEN PHARMA": corden.unique().tolist()}
dict_list.append(corden_dict)

#Replace with correct variation for corden
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("corden", case=False), "CORDEN PHARMA", df["NAME OF MANUFACTURER"])

# %%
cormart = df[df["NAME OF MANUFACTURER"].str.contains("cormart", na=False, case=False)]["NAME OF MANUFACTURER"]
cormart_dict = {"CORMART NIG LTD": cormart.unique().tolist()}
dict_list.append(cormart_dict)

#Replace with correct variation for cormart
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("cormart", case=False), "CORMART NIG LTD", df["NAME OF MANUFACTURER"])

# %%
df["NAME OF MANUFACTURER"].unique()
# Out:
# array(['GUILIN PHARMACEUTICAL CO., LTD.', 'ECOMED PHARMA LIMITED',
#        'SHANXI XINYITONG PHARM CO. LTD', 'FIDSON HEALTHCARE PLC',
#        'AKUMS DRUGS & PHARMACEUTICALS LTD', 'BAYER PHARMACEUTICALS',
#        'CORAL LABORATORIES LTD',
#        'CSPC ZHONGNUO PHARMACEUTICAL (SHIJIAZHUANG) CO. LTD.',
#        'EMZOR PHARMACEUTICALS INDUSTRIES LIMITED',
#        'GLOBELA PHARMA PVT. LTD.', 'HOVID BHD.',
#        ' HUBEI KANGZHENG PHARM . CO., LTD.', 'INNOVA CAPTAB PVT LTD',
#        'JIANGSU RUINIAN QIANJIN PHARMACEUTICALS CO., LTD',
#        'JIANGXI XIER KANGTAI PHARMACEUTICAL CO. LTD',
#        'LESANTO LABORATORIES', 'LINCOLN PHARMACEUTICALS LTD',
#        'OLIVE HEALTHCARE', 'SYNCOM FORMULATIONS (INDIA) LTD',
#        'MAKCUR LABORATORIES LIMITED', 'MARS REMEDIES PVT LTD',
#        'McCOY PHARMA PVT LTD', 'MCW HEALTHCARE PVT LTD',
#        'NITIN LIFESCIENCES LTD.', 'OSAKA PHARMACEUTICALS PVT. LTD.',
# ...

# %%
corona = df[df["NAME OF MANUFACTURER"].str.contains("corona", na=False, case=False)]["NAME OF MANUFACTURER"]
corona_dict = {"CORONA REMEDIES PVT LTD": corona.unique().tolist()}
dict_list.append(corona_dict)

#Replace with correct variation for corona
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("corona", case=False), "CORONA REMEDIES PVT LTD", df["NAME OF MANUFACTURER"])

# %%
cris = df[df["NAME OF MANUFACTURER"].str.contains("cris", na=False, case=False)]["NAME OF MANUFACTURER"]
cris_dict = {"CRIS PHARMA (INDIA) LTD": cris.unique().tolist()}
dict_list.append(cris_dict)

#Replace with correct variation for cris
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("cris", case=False), "CRIS PHARMA (INDIA) LTD", df["NAME OF MANUFACTURER"])

# %%
cspc_q = df[df["NAME OF MANUFACTURER"].str.contains("cspc q", na=False, case=False)]["NAME OF MANUFACTURER"]
cspc_q_dict = {"CSPC QUYI PHARMA CO. LTD.": cspc_q.unique().tolist()}
dict_list.append(cspc_q_dict)

#Replace with correct variation for cspc_q
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("cspc q", case=False), "CSPC QUYI PHARMA CO. LTD.", df["NAME OF MANUFACTURER"])

# %%
cure_q = df[df["NAME OF MANUFACTURER"].str.contains("cure quick", na=False, case=False)]["NAME OF MANUFACTURER"]
cure_q_dict = {"CURE QUICK PHARMACEUTICALS": cure_q.unique().tolist()}
dict_list.append(cure_q_dict)

#Replace with correct variation for cure_q
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("cure quick", case=False), "CURE QUICK PHARMACEUTICALS", df["NAME OF MANUFACTURER"])

# %%
curetech = df[df["NAME OF MANUFACTURER"].str.contains("curetech", na=False, case=False)]["NAME OF MANUFACTURER"]
curetech_dict = {"CURETECH SKINCARE": curetech.unique().tolist()}
dict_list.append(curetech_dict)

#Replace with correct variation for curetech
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("curetech", case=False), "CURETECH SKINCARE", df["NAME OF MANUFACTURER"])

# %%
ddd = df[df["NAME OF MANUFACTURER"].str.contains("d.d.d", na=False, case=False)]["NAME OF MANUFACTURER"]
ddd_dict = {"D.D.D. LTD.": ddd.unique().tolist()}
dict_list.append(ddd_dict)

#Replace with correct variation for ddd
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("ddd", case=False), "D.D.D. LTD.", df["NAME OF MANUFACTURER"])

# %%
daily = df[df["NAME OF MANUFACTURER"].str.contains("daily", na=False, case=False)]["NAME OF MANUFACTURER"]
daily_dict = {"DAILY NEED INDUSTRIES LTD": daily.unique().tolist()}
dict_list.append(daily_dict)

#Replace with correct variation for daily 
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("daily", case=False), "DAILY NEED INDUSTRIES LTD", df["NAME OF MANUFACTURER"])

# %%
damazo = df[df["NAME OF MANUFACTURER"].str.contains("damazo", na=False, case=False)]["NAME OF MANUFACTURER"]
damazo_dict = {"DAMAZO PHARMACEUTICAL INDUSTRIES (W.A) LIMITED": damazo.unique().tolist()}
dict_list.append(damazo_dict)

#Replace with correct variation for damazo 
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("damazo", case=False), "DAMAZO PHARMACEUTICAL INDUSTRIES (W.A) LIMITED", df["NAME OF MANUFACTURER"])

# %%
dana = df[df["NAME OF MANUFACTURER"].str.contains("dana pharm", na=False, case=False)]["NAME OF MANUFACTURER"]
dana_dict = {"DANA PHARMACEUTICALS LTD.": dana.unique().tolist()}
dict_list.append(dana_dict)

#Replace with correct variation for dana
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("dana pharm", case=False), "DANA PHARMACEUTICALS LTD.", df["NAME OF MANUFACTURER"])

# %%
danadams = df[df["NAME OF MANUFACTURER"].str.contains("danadams", na=False, case=False)]["NAME OF MANUFACTURER"]
danadams_dict = {"DANADAMS PHARMACEUTICALS LTD": danadams.unique().tolist()}
dict_list.append(danadams_dict)

#Replace with correct variation for danadams
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("danadams", case=False), "DANADAMS PHARMACEUTICALS LTD", df["NAME OF MANUFACTURER"])

# %%
deshalom = df[df["NAME OF MANUFACTURER"].str.contains("de shalom|de-shalom", na=False, case=False)]["NAME OF MANUFACTURER"]
deshalom_dict = {"DE SHALOM PHARM LAB NIG LTD": deshalom.unique().tolist()}
dict_list.append(deshalom_dict)

#Replace with correct variation for deshalom
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("de shalom|de-shalom", case=False), "DE SHALOM PHARM LAB NIG LTD", df["NAME OF MANUFACTURER"])

# %%
delpharm = df[df["NAME OF MANUFACTURER"].str.contains("delpharm", na=False, case=False)]["NAME OF MANUFACTURER"]
delpharm_dict = {"DELPHARM": delpharm.unique().tolist()}
dict_list.append(delpharm_dict)

#Replace with correct variation for delpharm
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("delpharm", case=False), "DELPHARM", df["NAME OF MANUFACTURER"])

# %%
delta = df[df["NAME OF MANUFACTURER"].str.contains("delta", na=False, case=False)]["NAME OF MANUFACTURER"]
delta_dict = {"DELTA PHARMA LIMITED": delta.unique().tolist()}
dict_list.append(delta_dict)

#Replace with correct variation for delta
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("delta", case=False), "DELTA PHARMA LIMITED", df["NAME OF MANUFACTURER"])

# %%
df["NAME OF MANUFACTURER"].unique()
# Out:
# array(['GUILIN PHARMACEUTICAL CO., LTD.', 'ECOMED PHARMA LIMITED',
#        'SHANXI XINYITONG PHARM CO. LTD', 'FIDSON HEALTHCARE PLC',
#        'AKUMS DRUGS & PHARMACEUTICALS LTD', 'BAYER PHARMACEUTICALS',
#        'CORAL LABORATORIES LTD',
#        'CSPC ZHONGNUO PHARMACEUTICAL (SHIJIAZHUANG) CO. LTD.',
#        'EMZOR PHARMACEUTICALS INDUSTRIES LIMITED',
#        'GLOBELA PHARMA PVT. LTD.', 'HOVID BHD.',
#        ' HUBEI KANGZHENG PHARM . CO., LTD.', 'INNOVA CAPTAB PVT LTD',
#        'JIANGSU RUINIAN QIANJIN PHARMACEUTICALS CO., LTD',
#        'JIANGXI XIER KANGTAI PHARMACEUTICAL CO. LTD',
#        'LESANTO LABORATORIES', 'LINCOLN PHARMACEUTICALS LTD',
#        'OLIVE HEALTHCARE', 'SYNCOM FORMULATIONS (INDIA) LTD',
#        'MAKCUR LABORATORIES LIMITED', 'MARS REMEDIES PVT LTD',
#        'McCOY PHARMA PVT LTD', 'MCW HEALTHCARE PVT LTD',
#        'NITIN LIFESCIENCES LTD.', 'OSAKA PHARMACEUTICALS PVT. LTD.',
# ...

# %%
denk = df[df["NAME OF MANUFACTURER"].str.contains("denk", na=False, case=False)]["NAME OF MANUFACTURER"]
denk_dict = {"DENK PHARMA GMBH & CO. KG": denk.unique().tolist()}
dict_list.append(denk_dict)

#Replace with correct variation for denk
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("denk", case=False), "DENK PHARMA GMBH & CO. KG", df["NAME OF MANUFACTURER"])

# %%
dexcel = df[df["NAME OF MANUFACTURER"].str.contains("dexcel", na=False, case=False)]["NAME OF MANUFACTURER"]
dexcel_dict = {"DEXCEL PHARMA LTD": dexcel.unique().tolist()}
dict_list.append(dexcel_dict)

#Replace with correct variation for dexcel
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("dexcel", case=False), "DEXCEL PHARMA LTD", df["NAME OF MANUFACTURER"])

# %%
dfl = df[df["NAME OF MANUFACTURER"].str.contains("dfl", na=False, case=False)]["NAME OF MANUFACTURER"]
dfl_dict = {"DFL INDUSTRIA E COMERCIO S.A.": dfl.unique().tolist()}
dict_list.append(dfl_dict)

#Replace with correct variation for dfl
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("dfl", case=False), "DFL INDUSTRIA E COMERCIO S.A.", df["NAME OF MANUFACTURER"])

# %%
dhg = df[df["NAME OF MANUFACTURER"].str.contains("dhg", na=False, case=False)]["NAME OF MANUFACTURER"]
dhg_dict = {"DHG PHARMACEUTICAL ONE-MEMBER COMPANY LIMITED": dhg.unique().tolist()}
dict_list.append(dhg_dict)

#Replace with correct variation for dhg
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("dhg", case=False), "DHG PHARMACEUTICAL ONE-MEMBER COMPANY LIMITED", df["NAME OF MANUFACTURER"])

# %%
diamond = df[df["NAME OF MANUFACTURER"].str.contains("diamond", na=False, case=False)]["NAME OF MANUFACTURER"]
diamond_dict = {"DIAMOND PHARMA": diamond.unique().tolist()}
dict_list.append(diamond_dict)

#Replace with correct variation for diamond
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("diamond", case=False), "DIAMOND PHARMA", df["NAME OF MANUFACTURER"])

# %%
divine_e = df[df["NAME OF MANUFACTURER"].str.contains("divine e", na=False, case=False)]["NAME OF MANUFACTURER"]
divine_e_dict = {"DIVINE ESSENTIALS FORMULATIONS LTD": divine_e.unique().tolist()}
dict_list.append(divine_e_dict)

#Replace with correct variation for divine_e
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("divine e", case=False), "DIVINE ESSENTIALS FORMULATIONS LTD", df["NAME OF MANUFACTURER"])

# %%
divine = df[df["NAME OF MANUFACTURER"].str.contains("divine lab", na=False, case=False)]["NAME OF MANUFACTURER"]
divine_dict = {"DIVINE LABORATORIES PVT LTD": divine.unique().tolist()}
dict_list.append(divine_dict)

#Replace with correct variation for divine
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("divine lab", case=False), "DIVINE LABORATORIES PVT LTD", df["NAME OF MANUFACTURER"])

# %%
docerad = df[df["NAME OF MANUFACTURER"].str.contains("docerad", na=False, case=False)]["NAME OF MANUFACTURER"]
docerad_dict = {"DOCERAD CONSULTANCY SERVICES LTD": docerad.unique().tolist()}
dict_list.append(docerad_dict)

#Replace with correct variation for docerad
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("docerad", case=False), "DOCERAD CONSULTANCY SERVICES LTD", df["NAME OF MANUFACTURER"])

# %%
dortmund = df[df["NAME OF MANUFACTURER"].str.contains("dortmund", na=False, case=False)]["NAME OF MANUFACTURER"]
dortmund_dict = {"DORTMUND LABORATORIES PVT. LTD.": dortmund.unique().tolist()}
dict_list.append(dortmund_dict)

#Replace with correct variation for dortmund
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("dortmund", case=False), "DORTMUND LABORATORIES PVT. LTD.", df["NAME OF MANUFACTURER"])

# %%
dragenopharm = df[df["NAME OF MANUFACTURER"].str.contains("dragenopharm", na=False, case=False)]["NAME OF MANUFACTURER"]
dragenopharm_dict = {"DRAGENOPHARM APOTHEKER PUESCHL GMBH": dragenopharm.unique().tolist()}
dict_list.append(dragenopharm_dict)

#Replace with correct variation for dragenopharm
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("dragenopharm", case=False), "DRAGENOPHARM APOTHEKER PUESCHL GMBH", df["NAME OF MANUFACTURER"])

# %%
drug = df[df["NAME OF MANUFACTURER"].str.contains("drug int", na=False, case=False)]["NAME OF MANUFACTURER"]
drug_dict = {"DRUG INTERNATIONAL LTD": drug.unique().tolist()}
dict_list.append(drug_dict)

#Replace with correct variation for drug
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("drug int", case=False), "DRUG INTERNATIONAL LTD", df["NAME OF MANUFACTURER"])

# %%
drugfield = df[df["NAME OF MANUFACTURER"].str.contains("drugfield", na=False, case=False)]["NAME OF MANUFACTURER"]
drugfield_dict = {"DRUGFIELD PHARMACEUTICALS LIMITED": drugfield.unique().tolist()}
dict_list.append(drugfield_dict)

#Replace with correct variation for drugfield
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("drugfield", case=False), "DRUGFIELD PHARMACEUTICALS LIMITED", df["NAME OF MANUFACTURER"])

# %%
dupen = df[df["NAME OF MANUFACTURER"].str.contains("dupen", na=False, case=False)]["NAME OF MANUFACTURER"]
dupen_dict = {"DUPEN LABORATORIES PVT. LTD.": dupen.unique().tolist()}
dict_list.append(dupen_dict)

#Replace with correct variation for dupen
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("dupen", case=False), "DUPEN LABORATORIES PVT. LTD.", df["NAME OF MANUFACTURER"])

# %%
df["NAME OF MANUFACTURER"].unique()
# Out:
# array(['GUILIN PHARMACEUTICAL CO., LTD.', 'ECOMED PHARMA LIMITED',
#        'SHANXI XINYITONG PHARM CO. LTD', 'FIDSON HEALTHCARE PLC',
#        'AKUMS DRUGS & PHARMACEUTICALS LTD', 'BAYER PHARMACEUTICALS',
#        'CORAL LABORATORIES LTD',
#        'CSPC ZHONGNUO PHARMACEUTICAL (SHIJIAZHUANG) CO. LTD.',
#        'EMZOR PHARMACEUTICALS INDUSTRIES LIMITED',
#        'GLOBELA PHARMA PVT. LTD.', 'HOVID BHD.',
#        ' HUBEI KANGZHENG PHARM . CO., LTD.', 'INNOVA CAPTAB PVT LTD',
#        'JIANGSU RUINIAN QIANJIN PHARMACEUTICALS CO., LTD',
#        'JIANGXI XIER KANGTAI PHARMACEUTICAL CO. LTD',
#        'LESANTO LABORATORIES', 'LINCOLN PHARMACEUTICALS LTD',
#        'OLIVE HEALTHCARE', 'SYNCOM FORMULATIONS (INDIA) LTD',
#        'MAKCUR LABORATORIES LIMITED', 'MARS REMEDIES PVT LTD',
#        'McCOY PHARMA PVT LTD', 'MCW HEALTHCARE PVT LTD',
#        'NITIN LIFESCIENCES LTD.', 'OSAKA PHARMACEUTICALS PVT. LTD.',
# ...

# %%
ebewe = df[df["NAME OF MANUFACTURER"].str.contains("ebewe", na=False, case=False)]["NAME OF MANUFACTURER"]
ebewe_dict = {"EBEWE PHARMA GMBH NFG KG": ebewe.unique().tolist()}
dict_list.append(ebewe_dict)

#Replace with correct variation for ebewe
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("ebewe", case=False), "EBEWE PHARMA GMBH NFG KG", df["NAME OF MANUFACTURER"])

# %%
eckhart = df[df["NAME OF MANUFACTURER"].str.contains("eckhart", na=False, case=False)]["NAME OF MANUFACTURER"]
eckhart_dict = {"ECKHART CORPORATION": eckhart.unique().tolist()}
dict_list.append(eckhart_dict)

#Replace with correct variation for eckhart
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("eckhart", case=False), "ECKHART CORPORATION", df["NAME OF MANUFACTURER"])

# %%
edo = df[df["NAME OF MANUFACTURER"].str.contains("edo pharm", na=False, case=False)]["NAME OF MANUFACTURER"]
edo_dict = {"EDO PHARM LTD": edo.unique().tolist()}
dict_list.append(edo_dict)

#Replace with correct variation for edo
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("edo pharm", case=False), "EDO PHARM LTD", df["NAME OF MANUFACTURER"])

# %%
efobi = df[df["NAME OF MANUFACTURER"].str.contains("efobi", na=False, case=False)]["NAME OF MANUFACTURER"]
efobi_dict = {"EFOBI NIGERIA LTD": efobi.unique().tolist()}
dict_list.append(efobi_dict)

#Replace with correct variation for efobi
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("efobi", case=False), "EFOBI NIGERIA LTD", df["NAME OF MANUFACTURER"])

# %%
efunpo = df[df["NAME OF MANUFACTURER"].str.contains("efunpo", na=False, case=False)]["NAME OF MANUFACTURER"]
efunpo_dict = {"EFUNPO PHARMA LTD": efunpo.unique().tolist()}
dict_list.append(efunpo_dict)

#Replace with correct variation for efunpo
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("efunpo", case=False), "EFUNPO PHARMA LTD", df["NAME OF MANUFACTURER"])

# %%
egyptian = df[df["NAME OF MANUFACTURER"].str.contains("egyptian int", na=False, case=False)]["NAME OF MANUFACTURER"]
egyptian_dict = {"EGYPTIAN INT'L PHARMACEUTICAL INDUSTRIES CO": egyptian.unique().tolist()}
dict_list.append(egyptian_dict)

#Replace with correct variation for egyptian
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("egyptian int", case=False), "EGYPTIAN INT'L PHARMACEUTICAL INDUSTRIES CO", df["NAME OF MANUFACTURER"])

# %%
emcure = df[df["NAME OF MANUFACTURER"].str.contains("emcure", na=False, case=False)]["NAME OF MANUFACTURER"]
emcure_dict = {"EMCURE PHARMACEUTICALS LTD": emcure.unique().tolist()}
dict_list.append(emcure_dict)

#Replace with correct variation for emcure
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("emcure", case=False), "EMCURE PHARMACEUTICALS LTD", df["NAME OF MANUFACTURER"])

# %%
enicar = df[df["NAME OF MANUFACTURER"].str.contains("enicar", na=False, case=False)]["NAME OF MANUFACTURER"]
enicar_dict = {"ENICAR PHARMACEUTICALS PVT LTD": enicar.unique().tolist()}
dict_list.append(enicar_dict)

#Replace with correct variation for enicar
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("enicar", case=False), "ENICAR PHARMACEUTICALS PVT LTD", df["NAME OF MANUFACTURER"])

# %%
enymatic = df[df["NAME OF MANUFACTURER"].str.contains("enymatic", na=False, case=False)]["NAME OF MANUFACTURER"]
enymatic_dict = {"ENYMATIC THERAPY LLC": enymatic.unique().tolist()}
dict_list.append(enymatic_dict)

#Replace with correct variation for enymatic
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("enymatic", case=False), "ENYMATIC THERAPY LLC", df["NAME OF MANUFACTURER"])

# %%
ernest = df[df["NAME OF MANUFACTURER"].str.contains("ernest", na=False, case=False)]["NAME OF MANUFACTURER"]
ernest_dict = {"ERNEST CHEMIST LIMITED": ernest.unique().tolist()}
dict_list.append(ernest_dict)

#Replace with correct variation for ernest
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("ernest", case=False), "ERNEST CHEMIST LIMITED", df["NAME OF MANUFACTURER"])

# %%
esapharma = df[df["NAME OF MANUFACTURER"].str.contains("esapharma", na=False, case=False)]["NAME OF MANUFACTURER"]
esapharma_dict = {"ESAPHARMA SRL PHARMACEUTICAL LABORATORY": esapharma.unique().tolist()}
dict_list.append(esapharma_dict)

#Replace with correct variation for esapharma
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("esapharma", case=False), "ESAPHARMA SRL PHARMACEUTICAL LABORATORY", df["NAME OF MANUFACTURER"])

# %%
esehi = df[df["NAME OF MANUFACTURER"].str.contains("esehi", na=False, case=False)]["NAME OF MANUFACTURER"]
esehi_dict = {"ESEHI PHARMA LTD": esehi.unique().tolist()}
dict_list.append(esehi_dict)

#Replace with correct variation for esehi
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("esehi", case=False), "ESEHI PHARMA LTD", df["NAME OF MANUFACTURER"])

# %%
eurolife = df[df["NAME OF MANUFACTURER"].str.contains("eurolife", na=False, case=False)]["NAME OF MANUFACTURER"]
eurolife_dict = {"EUROLIFE HEALTHCARE PVT LTD": eurolife.unique().tolist()}
dict_list.append(eurolife_dict)

#Replace with correct variation for eurolife
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("eurolife", case=False), "EUROLIFE HEALTHCARE PVT LTD", df["NAME OF MANUFACTURER"])

# %%
euro_egypt = df[df["NAME OF MANUFACTURER"].str.contains("european egyptian", na=False, case=False)]["NAME OF MANUFACTURER"]
euro_egypt_dict = {"EUROPEAN EGYPTIAN PHARM. IND.": euro_egypt.unique().tolist()}
dict_list.append(euro_egypt_dict)

#Replace with correct variation for euro_egypt
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("european egyptian", case=False), "EUROPEAN EGYPTIAN PHARM. IND", df["NAME OF MANUFACTURER"])

# %%
eva = df[df["NAME OF MANUFACTURER"].str.contains("eva pharma for", na=False, case=False)]["NAME OF MANUFACTURER"]
eva_dict = {"EVA PHARMA": eva.unique().tolist()}
dict_list.append(eva_dict)

#Replace with correct variation for eva
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("eva pharma for", case=False), "EVA PHARMA", df["NAME OF MANUFACTURER"])

# %%
evans = df[df["NAME OF MANUFACTURER"].str.contains("evans", na=False, case=False)]["NAME OF MANUFACTURER"]
evans_dict = {"EVANS BAROQUE LIMITED": evans.unique().tolist()}
dict_list.append(evans_dict)

#Replace with correct variation for evans
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("evans", case=False), "EVANS BAROQUE LIMITED", df["NAME OF MANUFACTURER"])

# %%
everdestiny = df[df["NAME OF MANUFACTURER"].str.contains("everdestiny", na=False, case=False)]["NAME OF MANUFACTURER"]
everdestiny_dict = {"EVERDESTINY PHARMACEUTICAL LIMITED": everdestiny.unique().tolist()}
dict_list.append(everdestiny_dict)

#Replace with correct variation for everdestiny
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("everdestiny", case=False), "EVERDESTINY PHARMACEUTICAL LIMITED", df["NAME OF MANUFACTURER"])

# %%
evergreen_m = df[df["NAME OF MANUFACTURER"].str.contains("evergreen morning", na=False, case=False)]["NAME OF MANUFACTURER"]
evergreen_m_dict = {"EVERGREEN MORNING STAR PHARM.IND.LTD": evergreen_m.unique().tolist()}
dict_list.append(evergreen_m_dict)

#Replace with correct variation for evergreen_m
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("evergreen morning", case=False), "EVERGREEN MORNING STAR PHARM.IND.LTD", df["NAME OF MANUFACTURER"])

# %%
evergreen = df[df["NAME OF MANUFACTURER"].str.contains("evergreen pharma", na=False, case=False)]["NAME OF MANUFACTURER"]
evergreen_dict = {"EVERGREEN PHARMACEUTICAL INDUSTRIES LTD": evergreen.unique().tolist()}
dict_list.append(evergreen_dict)

#Replace with correct variation for evergreen
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("evergreen pharma", case=False), "EVERGREEN MORNING STAR PHARM.IND.LTD", df["NAME OF MANUFACTURER"])

# %%
excella = df[df["NAME OF MANUFACTURER"].str.contains("excella", na=False, case=False)]["NAME OF MANUFACTURER"]
excella_dict = {"EXCELLA GMBH & CO. KG.": excella.unique().tolist()}
dict_list.append(excella_dict)

#Replace with correct variation for excella
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("excella", case=False), "EXCELLA GMBH & CO. KG.", df["NAME OF MANUFACTURER"])

# %%
exeltis = df[df["NAME OF MANUFACTURER"].str.contains("exeltis", na=False, case=False)]["NAME OF MANUFACTURER"]
exeltis_dict = {"EXELTIS ILAC": exeltis.unique().tolist()}
dict_list.append(exeltis_dict)

#Replace with correct variation for exeltis
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("exeltis", case=False), "EXELTIS ILAC", df["NAME OF MANUFACTURER"])

# %%
df["NAME OF MANUFACTURER"].unique()
# Out:
# array(['GUILIN PHARMACEUTICAL CO., LTD.', 'ECOMED PHARMA LIMITED',
#        'SHANXI XINYITONG PHARM CO. LTD', 'FIDSON HEALTHCARE PLC',
#        'AKUMS DRUGS & PHARMACEUTICALS LTD', 'BAYER PHARMACEUTICALS',
#        'CORAL LABORATORIES LTD',
#        'CSPC ZHONGNUO PHARMACEUTICAL (SHIJIAZHUANG) CO. LTD.',
#        'EMZOR PHARMACEUTICALS INDUSTRIES LIMITED',
#        'GLOBELA PHARMA PVT. LTD.', 'HOVID BHD.',
#        ' HUBEI KANGZHENG PHARM . CO., LTD.', 'INNOVA CAPTAB PVT LTD',
#        'JIANGSU RUINIAN QIANJIN PHARMACEUTICALS CO., LTD',
#        'JIANGXI XIER KANGTAI PHARMACEUTICAL CO. LTD',
#        'LESANTO LABORATORIES', 'LINCOLN PHARMACEUTICALS LTD',
#        'OLIVE HEALTHCARE', 'SYNCOM FORMULATIONS (INDIA) LTD',
#        'MAKCUR LABORATORIES LIMITED', 'MARS REMEDIES PVT LTD',
#        'McCOY PHARMA PVT LTD', 'MCW HEALTHCARE PVT LTD',
#        'NITIN LIFESCIENCES LTD.', 'OSAKA PHARMACEUTICALS PVT. LTD.',
# ...

# %%
faes = df[df["NAME OF MANUFACTURER"].str.contains("faes", na=False, case=False)]["NAME OF MANUFACTURER"]
faes_dict = {"FAES FARMA": faes.unique().tolist()}
dict_list.append(faes_dict)

#Replace with correct variation for faes
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("faes", case=False), "FAES FARMA", df["NAME OF MANUFACTURER"])

# %%
fareva = df[df["NAME OF MANUFACTURER"].str.contains("fareva", na=False, case=False)]["NAME OF MANUFACTURER"]
fareva_dict = {"FAREVA AMBOISE": fareva.unique().tolist()}
dict_list.append(fareva_dict)

#Replace with correct variation for fareva
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("fareva", case=False), "FAREVA AMBOISE", df["NAME OF MANUFACTURER"])

# %%
farmalabor = df[df["NAME OF MANUFACTURER"].str.contains("farmalabor", na=False, case=False)]["NAME OF MANUFACTURER"]
farmalabor_dict = {"FARMALABOR-PRODUTOS FARMACEUTICOS": farmalabor.unique().tolist()}
dict_list.append(farmalabor_dict)

#Replace with correct variation for farmalabor
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("farmalabor", case=False), "FARMALABOR-PRODUTOS FARMACEUTICOS", df["NAME OF MANUFACTURER"])

# %%
farmex = df[df["NAME OF MANUFACTURER"].str.contains("farmex", na=False, case=False)]["NAME OF MANUFACTURER"]
farmex_dict = {"FARMEX MEYERS LIMITED": farmex.unique().tolist()}
dict_list.append(farmex_dict)

#Replace with correct variation for farmex
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("farmex", case=False), "FARMEX MEYERS LIMITED", df["NAME OF MANUFACTURER"])

# %%
fdc = df[df["NAME OF MANUFACTURER"].str.contains("fdc", na=False, case=False)]["NAME OF MANUFACTURER"]
fdc_dict = {"FDC LIMITED": fdc.unique().tolist()}
dict_list.append(fdc_dict)

#Replace with correct variation for fdc
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("fdc", case=False), "FDC LIMITED", df["NAME OF MANUFACTURER"])

# %%
feccox = df[df["NAME OF MANUFACTURER"].str.contains("feccox", na=False, case=False)]["NAME OF MANUFACTURER"]
feccox_dict = {"FECCOX PHARMACY & GENERAL ENTERPRISES LIMITED": feccox.unique().tolist()}
dict_list.append(feccox_dict)

#Replace with correct variation for feccox
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("feccox", case=False), "FECCOX PHARMACY & GENERAL ENTERPRISES LIMITED", df["NAME OF MANUFACTURER"])

# %%
ferozsons = df[df["NAME OF MANUFACTURER"].str.contains("ferozsons", na=False, case=False)]["NAME OF MANUFACTURER"]
ferozsons_dict = {"FEROZSONS LABORATORIES LTD.": ferozsons.unique().tolist()}
dict_list.append(ferozsons_dict)

#Replace with correct variation for ferozsons
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("ferozsons", case=False), "FEROZSONS LABORATORIES LTD.", df["NAME OF MANUFACTURER"])

# %%
ferrer = df[df["NAME OF MANUFACTURER"].str.contains("ferrer", na=False, case=False)]["NAME OF MANUFACTURER"]
ferrer_dict = {"FERRER INTERNACIONAL": ferrer.unique().tolist()}
dict_list.append(ferrer_dict)

#Replace with correct variation for ferrer
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("ferrer", case=False), "FERRER INTERNACIONAL", df["NAME OF MANUFACTURER"])

# %%
ferring = df[df["NAME OF MANUFACTURER"].str.contains("ferring", na=False, case=False)]["NAME OF MANUFACTURER"]
ferring_dict = {"FERRING PHARMACEUTICALS": ferring.unique().tolist()}
dict_list.append(ferring_dict)

#Replace with correct variation for ferring
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("ferring", case=False), "FERRING PHARMACEUTICALS", df["NAME OF MANUFACTURER"])

# %%
finecure = df[df["NAME OF MANUFACTURER"].str.contains("finecure", na=False, case=False)]["NAME OF MANUFACTURER"]
finecure_dict = {"FINECURE PHARMACEUTICALS LIMITED": finecure.unique().tolist()}
dict_list.append(finecure_dict)

#Replace with correct variation for finecure
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("finecure", case=False), "FINECURE PHARMACEUTICALS LIMITED", df["NAME OF MANUFACTURER"])

# %%
fisons = df[df["NAME OF MANUFACTURER"].str.contains("fisons", na=False, case=False)]["NAME OF MANUFACTURER"]
fisons_dict = {"FISONS LTD": fisons.unique().tolist()}
dict_list.append(fisons_dict)

#Replace with correct variation for fisons
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("fisons", case=False), "FISONS LTD", df["NAME OF MANUFACTURER"])

# %%
fourrts = df[df["NAME OF MANUFACTURER"].str.contains("fourrts", na=False, case=False)]["NAME OF MANUFACTURER"]
fourrts_dict = {"FOURRTS (INDIA) LABORATORIES PVT LIMITED": fourrts.unique().tolist()}
dict_list.append(fourrts_dict)

#Replace with correct variation for fourrts
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("fourrts", case=False), "FOURRTS (INDIA) LABORATORIES PVT LIMITED", df["NAME OF MANUFACTURER"])

# %%
fredun = df[df["NAME OF MANUFACTURER"].str.contains("fred|frend", na=False, case=False)]["NAME OF MANUFACTURER"]
fredun_dict = {"FREDUN PHARMACEUTICALS LTD.": fredun.unique().tolist()}
dict_list.append(fredun_dict)

#Replace with correct variation for fredun
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("fred|frend", case=False), "FREDUN PHARMACEUTICALS LTD.", df["NAME OF MANUFACTURER"])

# %%
front = df[df["NAME OF MANUFACTURER"].str.contains("front", na=False, case=False)]["NAME OF MANUFACTURER"]
front_dict = {"FRONT PHARMACEUTICALS PLC": front.unique().tolist()}
dict_list.append(front_dict)

#Replace with correct variation for front
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("front", case=False), "FRONT PHARMACEUTICALS PLC", df["NAME OF MANUFACTURER"])

# %%
df["NAME OF MANUFACTURER"].unique()
# Out:
# array(['GUILIN PHARMACEUTICAL CO., LTD.', 'ECOMED PHARMA LIMITED',
#        'SHANXI XINYITONG PHARM CO. LTD', 'FIDSON HEALTHCARE PLC',
#        'AKUMS DRUGS & PHARMACEUTICALS LTD', 'BAYER PHARMACEUTICALS',
#        'CORAL LABORATORIES LTD',
#        'CSPC ZHONGNUO PHARMACEUTICAL (SHIJIAZHUANG) CO. LTD.',
#        'EMZOR PHARMACEUTICALS INDUSTRIES LIMITED',
#        'GLOBELA PHARMA PVT. LTD.', 'HOVID BHD.',
#        ' HUBEI KANGZHENG PHARM . CO., LTD.', 'INNOVA CAPTAB PVT LTD',
#        'JIANGSU RUINIAN QIANJIN PHARMACEUTICALS CO., LTD',
#        'JIANGXI XIER KANGTAI PHARMACEUTICAL CO. LTD',
#        'LESANTO LABORATORIES', 'LINCOLN PHARMACEUTICALS LTD',
#        'OLIVE HEALTHCARE', 'SYNCOM FORMULATIONS (INDIA) LTD',
#        'MAKCUR LABORATORIES LIMITED', 'MARS REMEDIES PVT LTD',
#        'McCOY PHARMA PVT LTD', 'MCW HEALTHCARE PVT LTD',
#        'NITIN LIFESCIENCES LTD.', 'OSAKA PHARMACEUTICALS PVT. LTD.',
# ...

# %%
gd = df[df["NAME OF MANUFACTURER"].str.contains("g.d. lab", na=False, case=False)]["NAME OF MANUFACTURER"]
gd_dict = {"G.D. LABORATORIES (INDIA) PVT. LTD.": gd.unique().tolist()}
dict_list.append(gd_dict)

#Replace with correct variation for gd
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("g.d. lab", case=False), "G.D. LABORATORIES (INDIA) PVT. LTD.", df["NAME OF MANUFACTURER"])

# %%
galentic = df[df["NAME OF MANUFACTURER"].str.contains("galentic", na=False, case=False)]["NAME OF MANUFACTURER"]
galentic_dict = {"GALENTIC PHARMA (INDIA) PVT. LTD.": galentic.unique().tolist()}
dict_list.append(galentic_dict)

#Replace with correct variation for galentic
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("galentic", case=False), "GALENTIC PHARMA (INDIA) PVT. LTD.", df["NAME OF MANUFACTURER"])

# %%
gauze = df[df["NAME OF MANUFACTURER"].str.contains("gauze", na=False, case=False)]["NAME OF MANUFACTURER"]
gauze_dict = {"GAUZE PHARM & LAB LTD": gauze.unique().tolist()}
dict_list.append(gauze_dict)

#Replace with correct variation for gauze
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("gauze", case=False), "GAUZE PHARM & LAB LTD", df["NAME OF MANUFACTURER"])

# %%
ge = df[df["NAME OF MANUFACTURER"].str.contains("ge healthcare ireland", na=False, case=False)]["NAME OF MANUFACTURER"]
ge_dict = {"GE HEALTHCARE": ge.unique().tolist()}
dict_list.append(ge_dict)

#Replace with correct variation for ge
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("ge healthcare ireland", case=False), "GE HEALTHCARE", df["NAME OF MANUFACTURER"])

# %%
gedeon = df[df["NAME OF MANUFACTURER"].str.contains("gedeon", na=False, case=False)]["NAME OF MANUFACTURER"]
gedeon_dict = {"GEDEON RICHTER": gedeon.unique().tolist()}
dict_list.append(gedeon_dict)

#Replace with correct variation for gedeon
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("gedeon", case=False), "GEDEON RICHTER", df["NAME OF MANUFACTURER"])

# %%
gelnova = df[df["NAME OF MANUFACTURER"].str.contains("gelnova", na=False, case=False)]["NAME OF MANUFACTURER"]
gelnova_dict = {"GELNOVA LABORATORIES (INDIA) PVT. LTD.": gelnova.unique().tolist()}
dict_list.append(gelnova_dict)

#Replace with correct variation for gelnova
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("gelnova", case=False), "GELNOVA LABORATORIES (INDIA) PVT. LTD.", df["NAME OF MANUFACTURER"])

# %%
geltec = df[df["NAME OF MANUFACTURER"].str.contains("geltec", na=False, case=False)]["NAME OF MANUFACTURER"]
geltec_dict = {"GELTEC PRIVATE LTD": geltec.unique().tolist()}
dict_list.append(geltec_dict)

#Replace with correct variation for gedeon
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("gedeon", case=False), "GELTEC PRIVATE LTD", df["NAME OF MANUFACTURER"])

# %%
gentle = df[df["NAME OF MANUFACTURER"].str.contains("gentle", na=False, case=False)]["NAME OF MANUFACTURER"]
gentle_dict = {"GENTLE HILLS LIMITED": gentle.unique().tolist()}
dict_list.append(gentle_dict)

#Replace with correct variation for gentle
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("gentle", case=False), "GENTLE HILLS LIMITED", df["NAME OF MANUFACTURER"])

# %%
getz = df[df["NAME OF MANUFACTURER"].str.contains("getz", na=False, case=False)]["NAME OF MANUFACTURER"]
getz_dict = {"GETZ PHARMA (PRIVATE) LIMITED": getz.unique().tolist()}
dict_list.append(getz_dict)

#Replace with correct variation for getz
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("getz", case=False), "GETZ PHARMA (PRIVATE) LIMITED", df["NAME OF MANUFACTURER"])

# %%
gilead = df[df["NAME OF MANUFACTURER"].str.contains("gilead", na=False, case=False)]["NAME OF MANUFACTURER"]
gilead_dict = {"GILEAD SCIENCES": gilead.unique().tolist()}
dict_list.append(gilead_dict)

#Replace with correct variation for gilead
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("gilead", case=False), "GILEAD SCIENCES", df["NAME OF MANUFACTURER"])

# %%
glaxo = df[df["NAME OF MANUFACTURER"].str.contains("glaxo", na=False, case=False)]["NAME OF MANUFACTURER"]
glaxo_dict = {"GLAXOSMITHKLINE PHARMACEUTICALS LTD.": glaxo.unique().tolist()}
dict_list.append(glaxo_dict)

#Replace with correct variation for glaxo
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("glaxo", case=False), "GLAXOSMITHKLINE PHARMACEUTICALS LTD.", df["NAME OF MANUFACTURER"])

# %%
global_pharma = df[df["NAME OF MANUFACTURER"].str.contains("global pharma", na=False, case=False)]["NAME OF MANUFACTURER"]
global_pharma_dict = {"GLOBAL PHARMA HEALTHCARE PVT LTD": global_pharma.unique().tolist()}
dict_list.append(global_pharma_dict)

#Replace with correct variation for global_pharma
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("global pharma", case=False), "GLOBAL PHARMA HEALTHCARE PVT LTD", df["NAME OF MANUFACTURER"])

# %%
glow = df[df["NAME OF MANUFACTURER"].str.contains("glow ", na=False, case=False)]["NAME OF MANUFACTURER"]
glow_dict = {"GLOW PHARMA PVT. LTD": glow.unique().tolist()}
dict_list.append(glow_dict)

#Replace with correct variation for glow
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("glow ", case=False), "GLOW PHARMA PVT. LTD", df["NAME OF MANUFACTURER"])

# %%
goldmoore = df[df["NAME OF MANUFACTURER"].str.contains("goldmoore", na=False, case=False)]["NAME OF MANUFACTURER"]
goldmoore_dict = {"GOLDMOORE INTERNATIONAL LTD": goldmoore.unique().tolist()}
dict_list.append(goldmoore_dict)

#Replace with correct variation for goldmoore
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("goldmoore", case=False), "GOLDMOORE INTERNATIONAL LTD", df["NAME OF MANUFACTURER"])

# %%
gopaldas = df[df["NAME OF MANUFACTURER"].str.contains("gopaldas", na=False, case=False)]["NAME OF MANUFACTURER"]
gopaldas_dict = {"GOPALDAS VISRAM & COMPANY LTD": gopaldas.unique().tolist()}
dict_list.append(gopaldas_dict)

#Replace with correct variation for gopaldas
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("gopaldas", case=False), "GOPALDAS VISRAM & COMPANY LTD", df["NAME OF MANUFACTURER"])

# %%
gracure = df[df["NAME OF MANUFACTURER"].str.contains("gracure", na=False, case=False)]["NAME OF MANUFACTURER"]
gracure_dict = {"GRACURE PHARMACEUTICALS LTD.": gracure.unique().tolist()}
dict_list.append(gracure_dict)

#Replace with correct variation for gracure
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("gracure", case=False), "GRACURE PHARMACEUTICALS LTD.", df["NAME OF MANUFACTURER"])

# %%
grand = df[df["NAME OF MANUFACTURER"].str.contains("grand", na=False, case=False)]["NAME OF MANUFACTURER"]
grand_dict = {"GRAND PHARMACEUTICAL (CHINA) CO. LIMITED": grand.unique().tolist()}
dict_list.append(grand_dict)

#Replace with correct variation for grand
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("grand", case=False), "GRAND PHARMACEUTICAL (CHINA) CO. LIMITED", df["NAME OF MANUFACTURER"])

# %%
greenfield = df[df["NAME OF MANUFACTURER"].str.contains("greenfie", na=False, case=False)]["NAME OF MANUFACTURER"]
greenfield_dict = {"GREENFIELD PHARMACEUTICALS (JIANGSU) CO. LTD": greenfield.unique().tolist()}
dict_list.append(greenfield_dict)

#Replace with correct variation for greenfield
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("greenfie", case=False), "GREENFIELD PHARMACEUTICALS (JIANGSU) CO. LTD", df["NAME OF MANUFACTURER"])

# %%
greenlife = df[df["NAME OF MANUFACTURER"].str.contains("greenlife", na=False, case=False)]["NAME OF MANUFACTURER"]
greenlife_dict = {"GREENLIFE BLISS HEALTHCARE LTD": greenlife.unique().tolist()}
dict_list.append(greenlife_dict)

#Replace with correct variation for greenlife
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("greenlife", case=False), "GREENLIFE BLISS HEALTHCARE LTD", df["NAME OF MANUFACTURER"])

# %%
gufic = df[df["NAME OF MANUFACTURER"].str.contains("gufic", na=False, case=False)]["NAME OF MANUFACTURER"]
gufic_dict = {"GUFIC BIOSCIENCES LTD": gufic.unique().tolist()}
dict_list.append(gufic_dict)

#Replace with correct variation for gufic
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("gufic", case=False), "GUFIC BIOSCIENCES LTD", df["NAME OF MANUFACTURER"])

# %%
gujarat = df[df["NAME OF MANUFACTURER"].str.contains("gujarat li", na=False, case=False)]["NAME OF MANUFACTURER"]
gujarat_dict = {"GUJARAT LIQUI PHARMACAPS PVT LTD": gujarat.unique().tolist()}
dict_list.append(gujarat_dict)

#Replace with correct variation for gujarat
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("gujarat", case=False), "GUJARAT LIQUI PHARMACAPS PVT LTD", df["NAME OF MANUFACTURER"])

# %%
df["NAME OF MANUFACTURER"].unique()
# Out:
# array(['GUILIN PHARMACEUTICAL CO., LTD.', 'ECOMED PHARMA LIMITED',
#        'SHANXI XINYITONG PHARM CO. LTD', 'FIDSON HEALTHCARE PLC',
#        'AKUMS DRUGS & PHARMACEUTICALS LTD', 'BAYER PHARMACEUTICALS',
#        'CORAL LABORATORIES LTD',
#        'CSPC ZHONGNUO PHARMACEUTICAL (SHIJIAZHUANG) CO. LTD.',
#        'EMZOR PHARMACEUTICALS INDUSTRIES LIMITED',
#        'GLOBELA PHARMA PVT. LTD.', 'HOVID BHD.',
#        ' HUBEI KANGZHENG PHARM . CO., LTD.', 'INNOVA CAPTAB PVT LTD',
#        'JIANGSU RUINIAN QIANJIN PHARMACEUTICALS CO., LTD',
#        'JIANGXI XIER KANGTAI PHARMACEUTICAL CO. LTD',
#        'LESANTO LABORATORIES', 'LINCOLN PHARMACEUTICALS LTD',
#        'OLIVE HEALTHCARE', 'SYNCOM FORMULATIONS (INDIA) LTD',
#        'MAKCUR LABORATORIES LIMITED', 'MARS REMEDIES PVT LTD',
#        'McCOY PHARMA PVT LTD', 'MCW HEALTHCARE PVT LTD',
#        'NITIN LIFESCIENCES LTD.', 'OSAKA PHARMACEUTICALS PVT. LTD.',
# ...

# %%
hab = df[df["NAME OF MANUFACTURER"].str.contains("hab", na=False, case=False)]["NAME OF MANUFACTURER"]
hab_dict = {"HAB PHARMACEUTICALS & RESEARCH LTD": hab.unique().tolist()}
dict_list.append(hab_dict)

#Replace with correct variation for hab
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("hab", case=False), "HAB PHARMACEUTICALS & RESEARCH LTD", df["NAME OF MANUFACTURER"])

# %%
halewood = df[df["NAME OF MANUFACTURER"].str.contains("halewood", na=False, case=False)]["NAME OF MANUFACTURER"]
halewood_dict = {"HALEWOOD LABORATORIES PVT. LTD.": halewood.unique().tolist()}
dict_list.append(halewood_dict)

#Replace with correct variation for halewood
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("halewood", case=False), "HALEWOOD LABORATORIES PVT. LTD.", df["NAME OF MANUFACTURER"])

# %%
hamax = df[df["NAME OF MANUFACTURER"].str.contains("hamax", na=False, case=False)]["NAME OF MANUFACTURER"]
hamax_dict = {"HAMAX PHARMACEUTICALS": hamax.unique().tolist()}
dict_list.append(hamax_dict)

#Replace with correct variation for hamax
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("hamax", case=False), "HAMAX PHARMACEUTICALS", df["NAME OF MANUFACTURER"])

# %%
hanlim = df[df["NAME OF MANUFACTURER"].str.contains("hanlim", na=False, case=False)]["NAME OF MANUFACTURER"]
hanlim_dict = {"HANLIM PHARM. CO. LTD": hanlim.unique().tolist()}
dict_list.append(hanlim_dict)

#Replace with correct variation for hanlim
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("hanlim", case=False), "HANLIM PHARM. CO. LTD", df["NAME OF MANUFACTURER"])

# %%
harbin = df[df["NAME OF MANUFACTURER"].str.contains("harbin", na=False, case=False)]["NAME OF MANUFACTURER"]
harbin_dict = {"HARBIN PHARMACEUTICAL GROUP CO. LTD": harbin.unique().tolist()}
dict_list.append(harbin_dict)

#Replace with correct variation for harbin
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("harbin", case=False), "HARBIN PHARMACEUTICAL GROUP CO. LTD", df["NAME OF MANUFACTURER"])

# %%
haupt = df[df["NAME OF MANUFACTURER"].str.contains("haupt", na=False, case=False)]["NAME OF MANUFACTURER"]
haupt_dict = {"HAUPT PHARMA": haupt.unique().tolist()}
dict_list.append(haupt_dict)

#Replace with correct variation for haupt
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("haupt", case=False), "HAUPT PHARMA", df["NAME OF MANUFACTURER"])

# do research

# %%
healthcare = df[df["NAME OF MANUFACTURER"].str.contains("healthcare formulations", na=False, case=False)]["NAME OF MANUFACTURER"]
healthcare_dict = {"HEALTHCARE FORMULATIONS PVT LIMITED": healthcare.unique().tolist()}
dict_list.append(healthcare_dict)

#Replace with correct variation for healthcare
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("healthcare formulations", case=False), "HEALTHCARE FORMULATIONS PVT LIMITED", df["NAME OF MANUFACTURER"])

# %%
hebei = df[df["NAME OF MANUFACTURER"].str.contains("hebei t", na=False, case=False)]["NAME OF MANUFACTURER"]
hebei_dict = {"HEBEI TIANCHENG PHARMACEUTICAL CO. LTD": hebei.unique().tolist()}
dict_list.append(hebei_dict)

#Replace with correct variation for hebei
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("hebei t", case=False), "HEBEI TIANCHENG PHARMACEUTICAL CO. LTD", df["NAME OF MANUFACTURER"])

# %%
hello = df[df["NAME OF MANUFACTURER"].str.contains("hello", na=False, case=False)]["NAME OF MANUFACTURER"]
hello_dict = {"HELLO PRODUCTS LIMITED": hello.unique().tolist()}
dict_list.append(hello_dict)

#Replace with correct variation for hello
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("hello", case=False), "HELLO PRODUCTS LIMITED", df["NAME OF MANUFACTURER"])

# %%
hetero = df[df["NAME OF MANUFACTURER"].str.contains("hetero", na=False, case=False)]["NAME OF MANUFACTURER"]
hetero_dict = {"HETERO LABS LIMITED": hetero.unique().tolist()}
dict_list.append(hetero_dict)

#Replace with correct variation for hetero
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("hetero", case=False), "HETERO LABS LIMITED", df["NAME OF MANUFACTURER"])

# %%
hilton = df[df["NAME OF MANUFACTURER"].str.contains("hilton", na=False, case=False)]["NAME OF MANUFACTURER"]
hilton_dict = {"HILTON PHARMA PVT LTD": hilton.unique().tolist()}
dict_list.append(hilton_dict)

#Replace with correct variation for hilton
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("hilton", case=False), "HILTON PHARMA PVT LTD", df["NAME OF MANUFACTURER"])

# %%
hospira = df[df["NAME OF MANUFACTURER"].str.contains("hospira", na=False, case=False)]["NAME OF MANUFACTURER"]
hospira_dict = {"HOSPIRA AUSTRALIA PTY LTD.": hospira.unique().tolist()}
dict_list.append(hospira_dict)

#Replace with correct variation for hospira
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("hospira", case=False), "HOSPIRA AUSTRALIA PTY LTD.", df["NAME OF MANUFACTURER"])

# %%
huangshan = df[df["NAME OF MANUFACTURER"].str.contains("huangshan", na=False, case=False)]["NAME OF MANUFACTURER"]
huangshan_dict = {"HUANGSHAN SHENGJI PHARMACEUTICAL CO. LIMITED": huangshan.unique().tolist()}
dict_list.append(huangshan_dict)

#Replace with correct variation for huangshan
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("huangshan", case=False), "HUANGSHAN SHENGJI PHARMACEUTICAL CO. LIMITED", df["NAME OF MANUFACTURER"])

# %%
huazhong = df[df["NAME OF MANUFACTURER"].str.contains("huazhong", na=False, case=False)]["NAME OF MANUFACTURER"]
huazhong_dict = {"HUAZHONG PHARM CO. LTD": huazhong.unique().tolist()}
dict_list.append(huazhong_dict)

#Replace with correct variation for huazhong
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("huazhong", case=False), "HUAZHONG PHARM CO. LTD", df["NAME OF MANUFACTURER"])

# %%
hunan = df[df["NAME OF MANUFACTURER"].str.contains("hunan", na=False, case=False)]["NAME OF MANUFACTURER"]
hunan_dict = {"HUNAN KELUN PHARMACEUTICAL CO. LTD": hunan.unique().tolist()}
dict_list.append(hunan_dict)

#Replace with correct variation for hunan
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("hunan", case=False), "HUNAN KELUN PHARMACEUTICAL CO. LTD", df["NAME OF MANUFACTURER"])

# %%
df["NAME OF MANUFACTURER"].unique()
# Out:
# array(['GUILIN PHARMACEUTICAL CO., LTD.', 'ECOMED PHARMA LIMITED',
#        'SHANXI XINYITONG PHARM CO. LTD', 'FIDSON HEALTHCARE PLC',
#        'AKUMS DRUGS & PHARMACEUTICALS LTD', 'BAYER PHARMACEUTICALS',
#        'CORAL LABORATORIES LTD',
#        'CSPC ZHONGNUO PHARMACEUTICAL (SHIJIAZHUANG) CO. LTD.',
#        'EMZOR PHARMACEUTICALS INDUSTRIES LIMITED',
#        'GLOBELA PHARMA PVT. LTD.', 'HOVID BHD.',
#        ' HUBEI KANGZHENG PHARM . CO., LTD.', 'INNOVA CAPTAB PVT LTD',
#        'JIANGSU RUINIAN QIANJIN PHARMACEUTICALS CO., LTD',
#        'JIANGXI XIER KANGTAI PHARMACEUTICAL CO. LTD',
#        'LESANTO LABORATORIES', 'LINCOLN PHARMACEUTICALS LTD',
#        'OLIVE HEALTHCARE', 'SYNCOM FORMULATIONS (INDIA) LTD',
#        'MAKCUR LABORATORIES LIMITED', 'MARS REMEDIES PVT LTD',
#        'McCOY PHARMA PVT LTD', 'MCW HEALTHCARE PVT LTD',
#        'NITIN LIFESCIENCES LTD.', 'OSAKA PHARMACEUTICALS PVT. LTD.',
# ...

# %%
icpa = df[df["NAME OF MANUFACTURER"].str.contains("icpa", na=False, case=False)]["NAME OF MANUFACTURER"]
icpa_dict = {"ICPA HEALTH PRODUCTS LTD": icpa.unique().tolist()}
dict_list.append(icpa_dict)

#Replace with correct variation for icpa
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("icpa", case=False), "ICPA HEALTH PRODUCTS LTD", df["NAME OF MANUFACTURER"])

# %%
ige = df[df["NAME OF MANUFACTURER"].str.contains("ige pharm", na=False, case=False)]["NAME OF MANUFACTURER"]
ige_dict = {"IGE PHARMACY NIGERIA LTD": ige.unique().tolist()}
dict_list.append(ige_dict)

#Replace with correct variation for ige
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("ige pharm", case=False), "IGE PHARMACY NIGERIA LTD", df["NAME OF MANUFACTURER"])

# %%
imperial = df[df["NAME OF MANUFACTURER"].str.contains("imperial", na=False, case=False)]["NAME OF MANUFACTURER"]
imperial_dict = {"IMPERIAL LIFE SCIENCES": imperial.unique().tolist()}
dict_list.append(imperial_dict)

#Replace with correct variation for imperial
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("imperial", case=False), "IMPERIAL LIFE SCIENCES", df["NAME OF MANUFACTURER"])

# %%
impulse = df[df["NAME OF MANUFACTURER"].str.contains("impulse", na=False, case=False)]["NAME OF MANUFACTURER"]
impulse_dict = {"IMPULSE PHARMA PVT. LTD.": impulse.unique().tolist()}
dict_list.append(impulse_dict)

#Replace with correct variation for impulse
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("impulse", case=False), "IMPULSE PHARMA PVT. LTD.", df["NAME OF MANUFACTURER"])

# %%
incepta = df[df["NAME OF MANUFACTURER"].str.contains("incepta", na=False, case=False)]["NAME OF MANUFACTURER"]
incepta_dict = {"INCEPTA PHARMACEUTICALS LIMITED": incepta.unique().tolist()}
dict_list.append(incepta_dict)

#Replace with correct variation for incepta
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("incepta", case=False), "INCEPTA PHARMACEUTICALS LIMITED", df["NAME OF MANUFACTURER"])

# %%
indchemie = df[df["NAME OF MANUFACTURER"].str.contains("indchemie", na=False, case=False)]["NAME OF MANUFACTURER"]
indchemie_dict = {"INDCHEMIE HEALTH SPECIALITIES PVT. LTD.": indchemie.unique().tolist()}
dict_list.append(indchemie_dict)

#Replace with correct variation for indchemie
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("indchemie", case=False), "INDCHEMIE HEALTH SPECIALITIES PVT. LTD.", df["NAME OF MANUFACTURER"])

# %%
indiana = df[df["NAME OF MANUFACTURER"].str.contains("indiana", na=False, case=False)]["NAME OF MANUFACTURER"]
indiana_dict = {"INDIANA OPHTHALMICS": indiana.unique().tolist()}
dict_list.append(indiana_dict)

#Replace with correct variation for indiana
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("indiana", case=False), "INDIANA OPHTHALMICS", df["NAME OF MANUFACTURER"])

# %%
ind = df[df["NAME OF MANUFACTURER"].str.contains("ind-", na=False, case=False)]["NAME OF MANUFACTURER"]
ind_dict = {"IND-SWIFT LIMITED": ind.unique().tolist()}
dict_list.append(ind_dict)

#Replace with correct variation for ind
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("ind-", case=False), "IND-SWIFT LIMITED", df["NAME OF MANUFACTURER"])

# %%
inject = df[df["NAME OF MANUFACTURER"].str.contains("inject", na=False, case=False)]["NAME OF MANUFACTURER"]
inject_dict = {"INJECT CARE PARENTERALS PVT. LTD.": inject.unique().tolist()}
dict_list.append(inject_dict)

#Replace with correct variation for inject
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("inject", case=False), "INJECT CARE PARENTERALS PVT. LTD.", df["NAME OF MANUFACTURER"])

# %%
innothera = df[df["NAME OF MANUFACTURER"].str.contains("innothera", na=False, case=False)]["NAME OF MANUFACTURER"]
innothera_dict = {"INNOTHERA": innothera.unique().tolist()}
dict_list.append(innothera_dict)

#Replace with correct variation for innothera
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("innothera", case=False), "INNOTHERA", df["NAME OF MANUFACTURER"])

# %%
intracell = df[df["NAME OF MANUFACTURER"].str.contains("intracell", na=False, case=False)]["NAME OF MANUFACTURER"]
intracell_dict = {"INTRACELL THERAPEUTICS PVT. LTD.": intracell.unique().tolist()}
dict_list.append(intracell_dict)

#Replace with correct variation for intracell
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("intracell", case=False), "INTRACELL THERAPEUTICS PVT. LTD.", df["NAME OF MANUFACTURER"])

# %%
intracin = df[df["NAME OF MANUFACTURER"].str.contains("intracin", na=False, case=False)]["NAME OF MANUFACTURER"]
intracin_dict = {"INTRACIN PHARMACEUTICALS PVT. LTD.": intracin.unique().tolist()}
dict_list.append(intracin_dict)

#Replace with correct variation for intracin
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("intracin", case=False), "INTRACIN PHARMACEUTICALS PVT. LTD.", df["NAME OF MANUFACTURER"])

# %%
inventia = df[df["NAME OF MANUFACTURER"].str.contains("inventia", na=False, case=False)]["NAME OF MANUFACTURER"]
inventia_dict = {"INVENTIA HEALTHCARE PVT. LTD.": inventia.unique().tolist()}
dict_list.append(inventia_dict)

#Replace with correct variation for inventia
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("inventia", case=False), "INVENTIA HEALTHCARE PVT. LTD.", df["NAME OF MANUFACTURER"])

# %%
ipca = df[df["NAME OF MANUFACTURER"].str.contains("ipca", na=False, case=False)]["NAME OF MANUFACTURER"]
ipca_dict = {"IPCA LABORATORIES LIMITED": ipca.unique().tolist()}
dict_list.append(ipca_dict)

#Replace with correct variation for ipca
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("ipca", case=False), "IPCA LABORATORIES LIMITED", df["NAME OF MANUFACTURER"])

# %%
ipr = df[df["NAME OF MANUFACTURER"].str.contains("ipr", na=False, case=False)]["NAME OF MANUFACTURER"]
ipr_dict = {"IPR PHARMACEUTICALS INC": ipr.unique().tolist()}
dict_list.append(ipr_dict)

#Replace with correct variation for ipr
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("ipr", case=False), "IPR PHARMACEUTICALS INC", df["NAME OF MANUFACTURER"])

# %%
ivee = df[df["NAME OF MANUFACTURER"].str.contains("ivee", na=False, case=False)]["NAME OF MANUFACTURER"]
ivee_dict = {"IVEE AQUA EPZ LIMITED": ivee.unique().tolist()}
dict_list.append(ivee_dict)

#Replace with correct variation for ivee
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("ivee", case=False), "IVEE AQUA EPZ LIMITED", df["NAME OF MANUFACTURER"])

# %%
jb = df[df["NAME OF MANUFACTURER"].str.contains("j.b ", na=False, case=False)]["NAME OF MANUFACTURER"]
jb_dict = {"J.B CHEMICALS & PHARMACEUTICALS LTD": jb.unique().tolist()}
dict_list.append(jb_dict)

#Replace with correct variation for jb
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("j.b ", case=False), "J.B CHEMICALS & PHARMACEUTICALS LTD", df["NAME OF MANUFACTURER"])

# %%
janssen_o = df[df["NAME OF MANUFACTURER"].str.contains("janssen o", na=False, case=False)]["NAME OF MANUFACTURER"]
janssen_o_dict = {"JANSSEN ORTHO LLC": janssen_o.unique().tolist()}
dict_list.append(janssen_o_dict)

#Replace with correct variation for janssen_o
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("janssen o", case=False), "JANSSEN ORTHO LLC", df["NAME OF MANUFACTURER"])

# %%
janssen = df[df["NAME OF MANUFACTURER"].str.contains("janssen", na=False, case=False)]["NAME OF MANUFACTURER"]
janssen_dict = {"JANSSEN PHARMACEUTICA NV": janssen.unique().tolist()}
dict_list.append(janssen_dict)

#Replace with correct variation for janssen
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("janssen", case=False), "JANSSEN PHARMACEUTICA NV", df["NAME OF MANUFACTURER"])

# %%
jash = df[df["NAME OF MANUFACTURER"].str.contains("jash", na=False, case=False)]["NAME OF MANUFACTURER"]
jash_dict = {"JASH PHARMA PVT. LTD.": jash.unique().tolist()}
dict_list.append(jash_dict)

#Replace with correct variation for jash
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("jash", case=False), "JASH PHARMA PVT. LTD.", df["NAME OF MANUFACTURER"])

# %%
jawa = df[df["NAME OF MANUFACTURER"].str.contains("jawa", na=False, case=False)]["NAME OF MANUFACTURER"]
jawa_dict = {"JAWA INTERNATIONAL LIMITED": jawa.unique().tolist()}
dict_list.append(jawa_dict)

#Replace with correct variation for jawa
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("jawa", case=False), "JAWA INTERNATIONAL LIMITED", df["NAME OF MANUFACTURER"])

# %%
jay = df[df["NAME OF MANUFACTURER"].str.contains("jay f", na=False, case=False)]["NAME OF MANUFACTURER"]
jay_dict = {"JAY FORMULATIONS LIMITED": jay.unique().tolist()}
dict_list.append(jay_dict)

#Replace with correct variation for jay
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("jay", case=False), "JAY FORMULATIONS LIMITED", df["NAME OF MANUFACTURER"])

# %%
jc = df[df["NAME OF MANUFACTURER"].str.contains("jc", na=False, case=False)]["NAME OF MANUFACTURER"]
jc_dict = {"JC UDEOZOR & SONS GLOBAL INDUSTRIAL LIMITED": jc.unique().tolist()}
dict_list.append(jc_dict)

#Replace with correct variation for jc
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("jc", case=False), "JC UDEOZOR & SONS GLOBAL INDUSTRIAL LIMITED", df["NAME OF MANUFACTURER"])

# %%
jesil = df[df["NAME OF MANUFACTURER"].str.contains("jesil", na=False, case=False)]["NAME OF MANUFACTURER"]
jesil_dict = {"JESIL PHARMACEUTICAL INDUSTRIES LIMITED": jesil.unique().tolist()}
dict_list.append(jesil_dict)

#Replace with correct variation for jesil
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("jesil", case=False), "JESIL PHARMACEUTICAL INDUSTRIES LIMITED", df["NAME OF MANUFACTURER"])

# %%
jewim = df[df["NAME OF MANUFACTURER"].str.contains("jewim", na=False, case=False)]["NAME OF MANUFACTURER"]
jewim_dict = {"JEWIM PHARMACEUTICAL (SHANDONG) CO. LTD.": jewim.unique().tolist()}
dict_list.append(jewim_dict)

#Replace with correct variation for jewim
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("jewim", case=False), "JEWIM PHARMACEUTICAL (SHANDONG) CO. LTD.", df["NAME OF MANUFACTURER"])

# %%
jfl = df[df["NAME OF MANUFACTURER"].str.contains("jfl", na=False, case=False)]["NAME OF MANUFACTURER"]
jfl_dict = {"JFL LIFE SCIENCES PVT. LTD.": jfl.unique().tolist()}
dict_list.append(jfl_dict)

#Replace with correct variation for jfl
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("jfl", case=False), "JFL LIFE SCIENCES PVT. LTD.", df["NAME OF MANUFACTURER"])

# %%
jiangsu_c = df[df["NAME OF MANUFACTURER"].str.contains("jiangsu c", na=False, case=False)]["NAME OF MANUFACTURER"]
jiangsu_c_dict = {"JIANGSU CHENPAI BOND PHARM. CO. LTD.": jiangsu_c.unique().tolist()}
dict_list.append(jiangsu_c_dict)

#Replace with correct variation for jiangsu_c
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("jiangsu c", case=False), "JIANGSU CHENPAI BOND PHARM. CO. LTD.", df["NAME OF MANUFACTURER"])

# %%
jiangsu_p = df[df["NAME OF MANUFACTURER"].str.contains("jiangsu p", na=False, case=False)]["NAME OF MANUFACTURER"]
jiangsu_p_dict = {"JIANGSU PENGYAO PHARMACEUTICALS CO. LTD.": jiangsu_p.unique().tolist()}
dict_list.append(jiangsu_p_dict)

#Replace with correct variation for jiangsu_p
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("jiangsu p", case=False), "JIANGSU PENGYAO PHARMACEUTICALS CO. LTD.", df["NAME OF MANUFACTURER"])

# %%
jinghua = df[df["NAME OF MANUFACTURER"].str.contains("jinghua", na=False, case=False)]["NAME OF MANUFACTURER"]
jinghua_dict = {"JINGHUA PHARMACEUTICAL GROUP CO. LIMITED": jinghua.unique().tolist()}
dict_list.append(jinghua_dict)

#Replace with correct variation for jinghua
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("jinghua", case=False), "JINGHUA PHARMACEUTICAL GROUP CO. LIMITED", df["NAME OF MANUFACTURER"])

# %%
jinling = df[df["NAME OF MANUFACTURER"].str.contains("jinling", na=False, case=False)]["NAME OF MANUFACTURER"]
jinling_dict = {"JINLING PHARM CO. LTD": jinling.unique().tolist()}
dict_list.append(jinling_dict)

#Replace with correct variation for jinling
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("jinling", case=False), "JINLING PHARM CO. LTD", df["NAME OF MANUFACTURER"])

# %%
jinzhou = df[df["NAME OF MANUFACTURER"].str.contains("jinzhou", na=False, case=False)]["NAME OF MANUFACTURER"]
jinzhou_dict = {"JINZHOU JINYANG PHARMA CO. LTD.": jinzhou.unique().tolist()}
dict_list.append(jinzhou_dict)

#Replace with correct variation for jinzhou
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("jinzhou", case=False), "JINZHOU JINYANG PHARMA CO. LTD.", df["NAME OF MANUFACTURER"])

# %%
johnson = df[df["NAME OF MANUFACTURER"].str.contains("johnson", na=False, case=False)]["NAME OF MANUFACTURER"]
johnson_dict = {"JOHNSON & JOHNSON (PTY) LTD.": johnson.unique().tolist()}
dict_list.append(johnson_dict)

#Replace with correct variation for johnson
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("johnson", case=False), "JOHNSON & JOHNSON (PTY) LTD.", df["NAME OF MANUFACTURER"])

# %%
jopan = df[df["NAME OF MANUFACTURER"].str.contains("jopan", na=False, case=False)]["NAME OF MANUFACTURER"]
jopan_dict = {"JOPAN PHARMACEUTICALS NIGERIA LIMITED": jopan.unique().tolist()}
dict_list.append(jopan_dict)

#Replace with correct variation for jopan
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("jopan", case=False), "JOPAN PHARMACEUTICALS NIGERIA LIMITED", df["NAME OF MANUFACTURER"])

# %%
jordan = df[df["NAME OF MANUFACTURER"].str.contains("sweden", na=False, case=False)]["NAME OF MANUFACTURER"]
jordan_dict = {"JORDAN SWEDEN MEDICAL & STERILIZATION CO. LTD.": jordan.unique().tolist()}
dict_list.append(jordan_dict)

#Replace with correct variation for jordan
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("sweden", case=False), "JORDAN SWEDEN MEDICAL & STERILIZATION CO. LTD.", df["NAME OF MANUFACTURER"])

# %%
joyfad = df[df["NAME OF MANUFACTURER"].str.contains("joyfad", na=False, case=False)]["NAME OF MANUFACTURER"]
joyfad_dict = {"JOYFAD PHARMACEUTICAL LABORATORIES LIMITED": joyfad.unique().tolist()}
dict_list.append(joyfad_dict)

#Replace with correct variation for joyfad
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("joyfad", case=False), "JOYFAD PHARMACEUTICAL LABORATORIES LIMITED", df["NAME OF MANUFACTURER"])

# %%
jsc = df[df["NAME OF MANUFACTURER"].str.contains("jsc p", na=False, case=False)]["NAME OF MANUFACTURER"]
jsc_dict = {"JSC PHARMSTANDARD": jsc.unique().tolist()}
dict_list.append(jsc_dict)

#Replace with correct variation for jsc
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("jsc p", case=False), "JSC PHARMSTANDARD", df["NAME OF MANUFACTURER"])

# %%
jubilant = df[df["NAME OF MANUFACTURER"].str.contains("jubilant", na=False, case=False)]["NAME OF MANUFACTURER"]
jubilant_dict = {"JUBILANT GENERICS LTD": jubilant.unique().tolist()}
dict_list.append(jubilant_dict)

#Replace with correct variation for jubilant
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("jubilant", case=False), "JUBILANT GENERICS LTD", df["NAME OF MANUFACTURER"])

# %%
juhel = df[df["NAME OF MANUFACTURER"].str.contains("juhel", na=False, case=False)]["NAME OF MANUFACTURER"]
juhel_dict = {"JUHEL NIGERIA LIMITED": juhel.unique().tolist()}
dict_list.append(juhel_dict)

#Replace with correct variation for juhel
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("juhel", case=False), "JUHEL NIGERIA LIMITED", df["NAME OF MANUFACTURER"])

# %%
df["NAME OF MANUFACTURER"].unique()
# Out:
# array(['GUILIN PHARMACEUTICAL CO., LTD.', 'ECOMED PHARMA LIMITED',
#        'SHANXI XINYITONG PHARM CO. LTD', 'FIDSON HEALTHCARE PLC',
#        'AKUMS DRUGS & PHARMACEUTICALS LTD', 'BAYER PHARMACEUTICALS',
#        'CORAL LABORATORIES LTD',
#        'CSPC ZHONGNUO PHARMACEUTICAL (SHIJIAZHUANG) CO. LTD.',
#        'EMZOR PHARMACEUTICALS INDUSTRIES LIMITED',
#        'GLOBELA PHARMA PVT. LTD.', 'HOVID BHD.',
#        ' HUBEI KANGZHENG PHARM . CO., LTD.', 'INNOVA CAPTAB PVT LTD',
#        'JIANGSU RUINIAN QIANJIN PHARMACEUTICALS CO., LTD',
#        'JIANGXI XIER KANGTAI PHARMACEUTICAL CO. LTD',
#        'LESANTO LABORATORIES', 'LINCOLN PHARMACEUTICALS LTD',
#        'OLIVE HEALTHCARE', 'SYNCOM FORMULATIONS (INDIA) LTD',
#        'MAKCUR LABORATORIES LIMITED', 'MARS REMEDIES PVT LTD',
#        'McCOY PHARMA PVT LTD', 'MCW HEALTHCARE PVT LTD',
#        'NITIN LIFESCIENCES LTD.', 'OSAKA PHARMACEUTICALS PVT. LTD.',
# ...

# %%
kamron = df[df["NAME OF MANUFACTURER"].str.contains("kamron", na=False, case=False)]["NAME OF MANUFACTURER"]
kamron_dict = {"KAMRON LABORATORIES LTD": kamron.unique().tolist()}
dict_list.append(kamron_dict)

#Replace with correct variation for kamron
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("kamron", case=False), "KAMRON LABORATORIES LTD", df["NAME OF MANUFACTURER"])

# %%
kendy = df[df["NAME OF MANUFACTURER"].str.contains("kendy", na=False, case=False)]["NAME OF MANUFACTURER"]
kendy_dict = {"KENDY LTD": kendy.unique().tolist()}
dict_list.append(kendy_dict)

#Replace with correct variation for kendy
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("kendy", case=False), "KENDY LTD", df["NAME OF MANUFACTURER"])

# %%
kepro = df[df["NAME OF MANUFACTURER"].str.contains("kepro", na=False, case=False)]["NAME OF MANUFACTURER"]
kepro_dict = {"KEPRO BV": kepro.unique().tolist()}
dict_list.append(kepro_dict)

#Replace with correct variation for kepro
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("kepro", case=False), "KEPRO BV", df["NAME OF MANUFACTURER"])

# %%
kesar = df[df["NAME OF MANUFACTURER"].str.contains("kesar", na=False, case=False)]["NAME OF MANUFACTURER"]
kesar_dict = {"KESAR PHARMA PVT. LTD.": kesar.unique().tolist()}
dict_list.append(kesar_dict)

#Replace with correct variation for kesar
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("kesar", case=False), "KESAR PHARMA PVT. LTD", df["NAME OF MANUFACTURER"])

# %%
khandekwal = df[df["NAME OF MANUFACTURER"].str.contains("khandekwal", na=False, case=False)]["NAME OF MANUFACTURER"]
khandekwal_dict = {"KHANDEKWAL LABORATORIES PVT. LTD.": khandekwal.unique().tolist()}
dict_list.append(khandekwal_dict)

#Replace with correct variation for khandekwal
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("khandekwal", case=False), "KHANDEKWAL LABORATORIES PVT. LTD.", df["NAME OF MANUFACTURER"])

# %%
kilitch = df[df["NAME OF MANUFACTURER"].str.contains("kilitch", na=False, case=False)]["NAME OF MANUFACTURER"]
kilitch_dict = {"KILITCH DRUGS (INDIA) LTD": kilitch.unique().tolist()}
dict_list.append(kilitch_dict)

#Replace with correct variation for kilitch
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("kilitch", case=False), "KILITCH DRUGS (INDIA) LTD", df["NAME OF MANUFACTURER"])

# %%
kingsize = df[df["NAME OF MANUFACTURER"].str.contains("kingsize", na=False, case=False)]["NAME OF MANUFACTURER"]
kingsize_dict = {"KINGSIZE PHARMACEUTICALS NIG LIMITED": kingsize.unique().tolist()}
dict_list.append(kingsize_dict)

#Replace with correct variation for kingsize
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("kingsize", case=False), "KINGSIZE PHARMACEUTICALS NIG LIMITED", df["NAME OF MANUFACTURER"])

# %%
kontam = df[df["NAME OF MANUFACTURER"].str.contains("kontam", na=False, case=False)]["NAME OF MANUFACTURER"]
kontam_dict = {"KONTAM PHARMACEUTICAL (ZHONGSHAN) CO. LTD": kontam.unique().tolist()}
dict_list.append(kontam_dict)

#Replace with correct variation for kontam
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("kontam", case=False), "KONTAM PHARMACEUTICAL (ZHONGSHAN) CO. LTD", df["NAME OF MANUFACTURER"])

# %%
kotra = df[df["NAME OF MANUFACTURER"].str.contains("kontra|kotra", na=False, case=False)]["NAME OF MANUFACTURER"]
kotra_dict = {"KOTRA PHARM (M) SDN BHD": kontam.unique().tolist()}
dict_list.append(kotra_dict)

#Replace with correct variation for kotra
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("kotra", case=False), "KOTRA PHARM (M) SDN BHD", df["NAME OF MANUFACTURER"])

# %%
korea = df[df["NAME OF MANUFACTURER"].str.contains("korea p", na=False, case=False)]["NAME OF MANUFACTURER"]
korea_dict = {"KOREA PHARMA CO. LTD.": korea.unique().tolist()}
dict_list.append(korea_dict)

#Replace with correct variation for korea
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("korea p", case=False), "KOREA PHARMA CO. LTD.", df["NAME OF MANUFACTURER"])

# %%
korea_u = df[df["NAME OF MANUFACTURER"].str.contains("korea u", na=False, case=False)]["NAME OF MANUFACTURER"]
korea_u_dict = {"KOREA UNITED PHARM. INC": korea_u.unique().tolist()}
dict_list.append(korea_u_dict)

#Replace with correct variation for korea_u
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("korea u", case=False), "KOREA UNITED PHARM. INC", df["NAME OF MANUFACTURER"])

# %%
kosa = df[df["NAME OF MANUFACTURER"].str.contains("kosa", na=False, case=False)]["NAME OF MANUFACTURER"]
kosa_dict = {"KOSA PHARMA (P) LIMITED": kosa.unique().tolist()}
dict_list.append(kosa_dict)

#Replace with correct variation for kosa
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("kosa", case=False), "KOSA PHARMA (P) LIMITED", df["NAME OF MANUFACTURER"])

# %%
kremoint = df[df["NAME OF MANUFACTURER"].str.contains("kremoint", na=False, case=False)]["NAME OF MANUFACTURER"]
kremoint_dict = {"KREMOINT PHARM PVT. LTD.": kremoint.unique().tolist()}
dict_list.append(kremoint_dict)

#Replace with correct variation for kremoint
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("kremoint", case=False), "KREMOINT PHARM PVT. LTD.", df["NAME OF MANUFACTURER"])

# %%
krishat = df[df["NAME OF MANUFACTURER"].str.contains("krishat", na=False, case=False)]["NAME OF MANUFACTURER"]
krishat_dict = {"KRISHAT PHARMA IND. LTD.": krishat.unique().tolist()}
dict_list.append(krishat_dict)

#Replace with correct variation for krishat
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("krishat", case=False), "KRISHAT PHARMA IND. LTD.", df["NAME OF MANUFACTURER"])

# %%
kunimed = df[df["NAME OF MANUFACTURER"].str.contains("kunimed", na=False, case=False)]["NAME OF MANUFACTURER"]
kunimed_dict = {"KUNIMED PHARMACHEM LIMITED": kunimed.unique().tolist()}
dict_list.append(kunimed_dict)

#Replace with correct variation for kunimed
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("kunimed", case=False), "KUNIMED PHARMACHEM LIMITED", df["NAME OF MANUFACTURER"])

# %%
kwality = df[df["NAME OF MANUFACTURER"].str.contains("kwality", na=False, case=False)]["NAME OF MANUFACTURER"]
kwality_dict = {"KWALITY PHARMACEUTICALS PVT. LIMITED": kwality.unique().tolist()}
dict_list.append(kwality_dict)

#Replace with correct variation for kwality
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("kwality", case=False), "KWALITY PHARMACEUTICALS PVT. LIMITED", df["NAME OF MANUFACTURER"])

# %%
df["NAME OF MANUFACTURER"].unique()
# Out:
# array(['GUILIN PHARMACEUTICAL CO., LTD.', 'ECOMED PHARMA LIMITED',
#        'SHANXI XINYITONG PHARM CO. LTD', 'FIDSON HEALTHCARE PLC',
#        'AKUMS DRUGS & PHARMACEUTICALS LTD', 'BAYER PHARMACEUTICALS',
#        'CORAL LABORATORIES LTD',
#        'CSPC ZHONGNUO PHARMACEUTICAL (SHIJIAZHUANG) CO. LTD.',
#        'EMZOR PHARMACEUTICALS INDUSTRIES LIMITED',
#        'GLOBELA PHARMA PVT. LTD.', 'HOVID BHD.',
#        ' HUBEI KANGZHENG PHARM . CO., LTD.', 'INNOVA CAPTAB PVT LTD',
#        'JIANGSU RUINIAN QIANJIN PHARMACEUTICALS CO., LTD',
#        'JIANGXI XIER KANGTAI PHARMACEUTICAL CO. LTD',
#        'LESANTO LABORATORIES', 'LINCOLN PHARMACEUTICALS LTD',
#        'OLIVE HEALTHCARE', 'SYNCOM FORMULATIONS (INDIA) LTD',
#        'MAKCUR LABORATORIES LIMITED', 'MARS REMEDIES PVT LTD',
#        'McCOY PHARMA PVT LTD', 'MCW HEALTHCARE PVT LTD',
#        'NITIN LIFESCIENCES LTD.', 'OSAKA PHARMACEUTICALS PVT. LTD.',
# ...

# %%
labesfal = df[df["NAME OF MANUFACTURER"].str.contains("labesfal", na=False, case=False)]["NAME OF MANUFACTURER"]
labesfal_dict = {"LABESFAL LABORATORIES ALMIRO": labesfal.unique().tolist()}
dict_list.append(labesfal_dict)

#Replace with correct variation for labesfal
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("labesfal", case=False), "LABESFAL LABORATORIES ALMIRO", df["NAME OF MANUFACTURER"])

# %%
laborate = df[df["NAME OF MANUFACTURER"].str.contains("laborate", na=False, case=False)]["NAME OF MANUFACTURER"]
laborate_dict = {"LABORATE PHARMACEUTICALS INDIA LTD": laborate.unique().tolist()}
dict_list.append(laborate_dict)

#Replace with correct variation for laborate
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("laborate", case=False), "LABORATE PHARMACEUTICALS INDIA LTD", df["NAME OF MANUFACTURER"])

# %%
laboratoire = df[df["NAME OF MANUFACTURER"].str.contains("laboratoire inno", na=False, case=False)]["NAME OF MANUFACTURER"]
laboratoire_dict = {"LABORATOIRE INNOTECH INTERNATIONAL": laboratoire.unique().tolist()}
dict_list.append(laboratoire_dict)

#Replace with correct variation for laboratoire
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("laboratoire inno", case=False), "LABORATOIRE INNOTECH INTERNATIONAL", df["NAME OF MANUFACTURER"])

# %%
laboratoria = df[df["NAME OF MANUFACTURER"].str.contains("laboratoria", na=False, case=False)]["NAME OF MANUFACTURER"]
laboratoria_dict = {"LABORATORIA QUALIPHAR": laboratoria.unique().tolist()}
dict_list.append(laboratoria_dict)

#Replace with correct variation for laboratoria
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("laboratoria", case=False), "LABORATORIA QUALIPHAR", df["NAME OF MANUFACTURER"])

# %%
laboratories_l = df[df["NAME OF MANUFACTURER"].str.contains("laboratories leon", na=False, case=False)]["NAME OF MANUFACTURER"]
laboratories_l_dict = {"LABORATORIES LEON FARMA": laboratories_l.unique().tolist()}
dict_list.append(laboratories_l_dict)

#Replace with correct variation for laboratories_l
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("laboratories leon", case=False), "LABORATORIES LEON FARMA", df["NAME OF MANUFACTURER"])

# %%
laboratories_s = df[df["NAME OF MANUFACTURER"].str.contains("laboratories soph", na=False, case=False)]["NAME OF MANUFACTURER"]
laboratories_s_dict = {"LABORATORIES SOPHARTEX": laboratories_s.unique().tolist()}
dict_list.append(laboratories_s_dict)

#Replace with correct variation for laboratories_s
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("laboratories soph", case=False), "LABORATORIES SOPHARTEX", df["NAME OF MANUFACTURER"])

# %%
laboratorios_b = df[df["NAME OF MANUFACTURER"].str.contains("laboratorios basi", na=False, case=False)]["NAME OF MANUFACTURER"]
laboratorios_b_dict = {"LABORATORIOS BASI-INDUSTRIA FARMACEUTICAL": laboratorios_b.unique().tolist()}
dict_list.append(laboratorios_b_dict)

#Replace with correct variation for laboratorios_b
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("laboratorios basi", case=False), "LABORATORIOS BASI-INDUSTRIA FARMACEUTICAL", df["NAME OF MANUFACTURER"])

# %%
lactose = df[df["NAME OF MANUFACTURER"].str.contains("lactose", na=False, case=False)]["NAME OF MANUFACTURER"]
lactose_dict = {"LACTOSE (INDIA) LTD": lactose.unique().tolist()}
dict_list.append(lactose_dict)

#Replace with correct variation for lactose
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("lactose", case=False), "LACTOSE (INDIA) LTD", df["NAME OF MANUFACTURER"])

# %%
lark = df[df["NAME OF MANUFACTURER"].str.contains("lark", na=False, case=False)]["NAME OF MANUFACTURER"]
lark_dict = {"LARK LABORATORIES (INDIA) LTD": lark.unique().tolist()}
dict_list.append(lark_dict)

#Replace with correct variation for lark
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("lark", case=False), "LARK LABORATORIES (INDIA) LTD", df["NAME OF MANUFACTURER"])

# %%
laurus = df[df["NAME OF MANUFACTURER"].str.contains("laurus", na=False, case=False)]["NAME OF MANUFACTURER"]
laurus_dict = {"LAURUS LABS": laurus.unique().tolist()}
dict_list.append(laurus_dict)

#Replace with correct variation for laurus
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("laurus", case=False), "LAURUS LABS", df["NAME OF MANUFACTURER"])

# %%
lek = df[df["NAME OF MANUFACTURER"].str.contains("lek", na=False, case=False)]["NAME OF MANUFACTURER"]
lek_dict = {"LEK PHARMACEUTICALS": lek.unique().tolist()}
dict_list.append(lek_dict)

#Replace with correct variation for lek_p
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("lek", case=False), "LEK PHARMACEUTICALS", df["NAME OF MANUFACTURER"])

# %%
leo = df[df["NAME OF MANUFACTURER"].str.contains("leo lab", na=False, case=False)]["NAME OF MANUFACTURER"]
leo_dict = {"LEO LABORATORIES LTD": leo.unique().tolist()}
dict_list.append(leo_dict)

#Replace with correct variation for leo
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("leo", case=False), "LEO LABORATORIES LTD", df["NAME OF MANUFACTURER"])

# %%
les = df[df["NAME OF MANUFACTURER"].str.contains("les lab", na=False, case=False)]["NAME OF MANUFACTURER"]
les_dict = {"LES LABORATOIRES SERVIER INDUSTRIE": les.unique().tolist()}
dict_list.append(les_dict)

#Replace with correct variation for les
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("les lab", case=False), "LES LABORATOIRES SERVIER INDUSTRIE", df["NAME OF MANUFACTURER"])

# %%
lilly = df[df["NAME OF MANUFACTURER"].str.contains("lil", na=False, case=False)]["NAME OF MANUFACTURER"]
lilly_dict = {"LILLY S.A.": lilly.unique().tolist()}
dict_list.append(lilly_dict)

#Replace with correct variation for lilly
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("lil", case=False), "LILLY S.A.", df["NAME OF MANUFACTURER"])

# %%
lupin = df[df["NAME OF MANUFACTURER"].str.contains("lupin", na=False, case=False)]["NAME OF MANUFACTURER"]
lupin_dict = {"LUPIN LTD": lupin.unique().tolist()}
dict_list.append(lupin_dict)

#Replace with correct variation for lupin
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("lupin", case=False), "LUPIN LTD", df["NAME OF MANUFACTURER"])

# %%
lusomedicamenta = df[df["NAME OF MANUFACTURER"].str.contains("lusomedicamenta", na=False, case=False)]["NAME OF MANUFACTURER"]
lusomedicamenta_dict = {"LUSOMEDICAMENTA": lusomedicamenta.unique().tolist()}
dict_list.append(lusomedicamenta_dict)

#Replace with correct variation for lusomedicamenta
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("lusomedicamenta", case=False), "LUSOMEDICAMENTA", df["NAME OF MANUFACTURER"])

# %%
lyka = df[df["NAME OF MANUFACTURER"].str.contains("lyka", na=False, case=False)]["NAME OF MANUFACTURER"]
lyka_dict = {"LYKA LABS LTD": lyka.unique().tolist()}
dict_list.append(lyka_dict)

#Replace with correct variation for lyka
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("lyka", case=False), "LYKA LABS LTD", df["NAME OF MANUFACTURER"])

# %%
df["NAME OF MANUFACTURER"].unique()
# Out:
# array(['GUILIN PHARMACEUTICAL CO., LTD.', 'ECOMED PHARMA LIMITED',
#        'SHANXI XINYITONG PHARM CO. LTD', 'FIDSON HEALTHCARE PLC',
#        'AKUMS DRUGS & PHARMACEUTICALS LTD', 'BAYER PHARMACEUTICALS',
#        'CORAL LABORATORIES LTD',
#        'CSPC ZHONGNUO PHARMACEUTICAL (SHIJIAZHUANG) CO. LTD.',
#        'EMZOR PHARMACEUTICALS INDUSTRIES LIMITED',
#        'GLOBELA PHARMA PVT. LTD.', 'HOVID BHD.',
#        ' HUBEI KANGZHENG PHARM . CO., LTD.', 'INNOVA CAPTAB PVT LTD',
#        'JIANGSU RUINIAN QIANJIN PHARMACEUTICALS CO., LTD',
#        'JIANGXI XIER KANGTAI PHARMACEUTICAL CO. LTD',
#        'LESANTO LABORATORIES', 'LINCOLN PHARMACEUTICALS LTD',
#        'OLIVE HEALTHCARE', 'SYNCOM FORMULATIONS (INDIA) LTD',
#        'MAKCUR LABORATORIES LIMITED', 'MARS REMEDIES PVT LTD',
#        'McCOY PHARMA PVT LTD', 'MCW HEALTHCARE PVT LTD',
#        'NITIN LIFESCIENCES LTD.', 'OSAKA PHARMACEUTICALS PVT. LTD.',
# ...

# %%
glenmark = df[df["NAME OF MANUFACTURER"].str.contains("glenmark", na=False, case=False)]["NAME OF MANUFACTURER"]
glenmark_dict = {"GLENMARK PHARMACEUTICAL LTD": glenmark.unique().tolist()}
dict_list.append(glenmark_dict)

#Replace with correct variation for glenmark
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("glenmark", case=False), "GLENMARK PHARMACEUTICAL LTD", df["NAME OF MANUFACTURER"])

# %%
mancare = df[df["NAME OF MANUFACTURER"].str.contains("mancare", na=False, case=False)]["NAME OF MANUFACTURER"]
mancare_dict = {"MANCARE PHARMACEUTICALS PVT. LTD": mancare.unique().tolist()}
dict_list.append(mancare_dict)

#Replace with correct variation for mancare
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("mancare", case=False), "MANCARE PHARMACEUTICALS PVT. LTD", df["NAME OF MANUFACTURER"])

# %%
maxheal = df[df["NAME OF MANUFACTURER"].str.contains("maxheal", na=False, case=False)]["NAME OF MANUFACTURER"]
maxheal_dict = {"MAXHEAL LABORATORIES PVT. LTD": maxheal.unique().tolist()}
dict_list.append(maxheal_dict)

#Replace with correct variation for maxheal
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("maxheal", case=False), "MAXHEAL LABORATORIES PVT. LTD", df["NAME OF MANUFACTURER"])

# %%
micro = df[df["NAME OF MANUFACTURER"].str.contains("micro", na=False, case=False)]["NAME OF MANUFACTURER"]
micro_dict = {"MICRO LABS LIMITED": micro.unique().tolist()}
dict_list.append(micro_dict)

#Replace with correct variation for micro
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("micro", case=False), "MICRO LABS LIMITED", df["NAME OF MANUFACTURER"])

# %%
rhydburg = df[df["NAME OF MANUFACTURER"].str.contains("rhydburg", na=False, case=False)]["NAME OF MANUFACTURER"]
rhydburg_dict = {"RHYDBURG PHARMACEUTICALS LTD.": rhydburg.unique().tolist()}
dict_list.append(rhydburg_dict)

#Replace with correct variation for rhydburg
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("rhydburg", case=False), "RHYDBURG PHARMACEUTICALS LTD.", df["NAME OF MANUFACTURER"])

# %%
saga = df[df["NAME OF MANUFACTURER"].str.contains("saga l", na=False, case=False)]["NAME OF MANUFACTURER"]
saga_dict = {"SAGA LABORATORIES": saga.unique().tolist()}
dict_list.append(saga_dict)

#Replace with correct variation for saga
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("saga lab", case=False), "SAGA LABORATORIES", df["NAME OF MANUFACTURER"])

# %%
scott = df[df["NAME OF MANUFACTURER"].str.contains("scot", na=False, case=False)]["NAME OF MANUFACTURER"]
scott_dict = {"SCOTT-EDIL PHARMACIA LTD": scott.unique().tolist()}
dict_list.append(scott_dict)

#Replace with correct variation for scott
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("scott", case=False), "SCOTT-EDIL PHARMACIA LTD", df["NAME OF MANUFACTURER"])

# %%
scitra = df[df["NAME OF MANUFACTURER"].str.contains("scitra", na=False, case=False)]["NAME OF MANUFACTURER"]
scitra_dict = {"SOAP & CHEMICAL INDUSTRIAL TRADING COMPANY (SCITRA)": scitra.unique().tolist()}
dict_list.append(scitra_dict)

#Replace with correct variation for scitra
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("scitra", case=False), "SOAP & CHEMICAL INDUSTRIAL TRADING COMPANY (SCITRA)", df["NAME OF MANUFACTURER"])

# %%
theon = df[df["NAME OF MANUFACTURER"].str.contains("theon p", na=False, case=False)]["NAME OF MANUFACTURER"]
theon_dict = {"THEON PHARMACEUTICALS LTD": theon.unique().tolist()}
dict_list.append(theon_dict)

#Replace with correct variation for theon
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("theon p", case=False), "THEON PHARMACEUTICALS LTD", df["NAME OF MANUFACTURER"])

# %%
west = df[df["NAME OF MANUFACTURER"].str.contains("west", na=False, case=False)]["NAME OF MANUFACTURER"]
west_dict = {"WEST COAST PHARMACEUTICAL WORKS LTD.": west.unique().tolist()}
dict_list.append(west_dict)

#Replace with correct variation for west
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("west", case=False), "WEST COAST PHARMACEUTICAL WORKS LTD.", df["NAME OF MANUFACTURER"])

# %%
yash = df[df["NAME OF MANUFACTURER"].str.contains("yash", na=False, case=False)]["NAME OF MANUFACTURER"]
yash_dict = {"YASH MEDICARE PRIVATE LIMITED": yash.unique().tolist()}
dict_list.append(yash_dict)

#Replace with correct variation for yash
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("yash", case=False), "YASH MEDICARE PRIVATE LIMITED", df["NAME OF MANUFACTURER"])

# %%
medicef = df[df["NAME OF MANUFACTURER"].str.contains("medicef", na=False, case=False)]["NAME OF MANUFACTURER"]
medicef_dict = {"MEDICEF PHARMA": medicef.unique().tolist()}
dict_list.append(medicef_dict)

#Replace with correct variation for medicef
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("medicef", case=False), "MEDICEF PHARMA", df["NAME OF MANUFACTURER"])

# %%
garnier = df[df["NAME OF MANUFACTURER"].str.contains("garnier", na=False, case=False)]["NAME OF MANUFACTURER"]
garnier_dict = {"SWISS GARNIER LIFE SCIENCES": garnier.unique().tolist()}
dict_list.append(garnier_dict)

#Replace with correct variation for garnier
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("garnier", case=False), "SWISS GARNIER LIFE SCIENCES", df["NAME OF MANUFACTURER"])

# %%
mmc = df[df["NAME OF MANUFACTURER"].str.contains("mmc", na=False, case=False)]["NAME OF MANUFACTURER"]
mmc_dict = {"MMC HEALTHCARE LTD": mmc.unique().tolist()}
dict_list.append(mmc_dict)

#Replace with correct variation for mmc
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("mmc", case=False), "MMC HEALTHCARE LTD", df["NAME OF MANUFACTURER"])

# %%
df["NAME OF MANUFACTURER"].unique()
# Out:
# array(['GUILIN PHARMACEUTICAL CO., LTD.', 'ECOMED PHARMA LIMITED',
#        'SHANXI XINYITONG PHARM CO. LTD', 'FIDSON HEALTHCARE PLC',
#        'AKUMS DRUGS & PHARMACEUTICALS LTD', 'BAYER PHARMACEUTICALS',
#        'CORAL LABORATORIES LTD',
#        'CSPC ZHONGNUO PHARMACEUTICAL (SHIJIAZHUANG) CO. LTD.',
#        'EMZOR PHARMACEUTICALS INDUSTRIES LIMITED',
#        'GLOBELA PHARMA PVT. LTD.', 'HOVID BHD.',
#        ' HUBEI KANGZHENG PHARM . CO., LTD.', 'INNOVA CAPTAB PVT LTD',
#        'JIANGSU RUINIAN QIANJIN PHARMACEUTICALS CO., LTD',
#        'JIANGXI XIER KANGTAI PHARMACEUTICAL CO. LTD',
#        'LESANTO LABORATORIES', 'LINCOLN PHARMACEUTICALS LTD',
#        'OLIVE HEALTHCARE', 'SYNCOM FORMULATIONS (INDIA) LTD',
#        'MAKCUR LABORATORIES LIMITED', 'MARS REMEDIES PVT LTD',
#        'McCOY PHARMA PVT LTD', 'MCW HEALTHCARE PVT LTD',
#        'NITIN LIFESCIENCES LTD.', 'OSAKA PHARMACEUTICALS PVT. LTD.',
# ...

# %%
maan = df[df["NAME OF MANUFACTURER"].str.contains("maan", na=False, case=False)]["NAME OF MANUFACTURER"]
maan_dict = {"MAAN PHARMACEUTICALS LTD": maan.unique().tolist()}
dict_list.append(maan_dict)

#Replace with correct variation for maan
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("maan", case=False), "MAAN PHARMACEUTICALS LTD", df["NAME OF MANUFACTURER"])

# %%
madras = df[df["NAME OF MANUFACTURER"].str.contains("madras", na=False, case=False)]["NAME OF MANUFACTURER"]
madras_dict = {"MADRAS PHARMACEUTICALS": madras.unique().tolist()}
dict_list.append(madras_dict)

#Replace with correct variation for madras
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("madras", case=False), "MADRAS PHARMACEUTICALS", df["NAME OF MANUFACTURER"])

# %%
maneesh = df[df["NAME OF MANUFACTURER"].str.contains("maneesh", na=False, case=False)]["NAME OF MANUFACTURER"]
maneesh_dict = {"MANEESH EXPORTS": maneesh.unique().tolist()}
dict_list.append(maneesh_dict)

#Replace with correct variation for maneesh
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("maneesh", case=False), "MANEESH EXPORTS", df["NAME OF MANUFACTURER"])

# %%
maphar = df[df["NAME OF MANUFACTURER"].str.contains("maphar", na=False, case=False)]["NAME OF MANUFACTURER"]
maphar_dict = {"MAPHAR": maphar.unique().tolist()}
dict_list.append(maphar_dict)

#Replace with correct variation for maphar
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("maphar", case=False), "MAPHAR", df["NAME OF MANUFACTURER"])

# %%
mass = df[df["NAME OF MANUFACTURER"].str.contains("mass", na=False, case=False)]["NAME OF MANUFACTURER"]
mass_dict = {"MASS PHARMA (PVT) LTD": mass.unique().tolist()}
dict_list.append(mass_dict)

#Replace with correct variation for mass
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("mass", case=False), "MASS PHARMA (PVT) LTD", df["NAME OF MANUFACTURER"])

# %%
maxtar = df[df["NAME OF MANUFACTURER"].str.contains("maxtar", na=False, case=False)]["NAME OF MANUFACTURER"]
maxtar_dict = {"MAXTAR BIO-GENICS": maxtar.unique().tolist()}
dict_list.append(maxtar_dict)

#Replace with correct variation for maxtar
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("maxtar", case=False), "MAXTAR BIO-GENICS", df["NAME OF MANUFACTURER"])

# %%
may = df[df["NAME OF MANUFACTURER"].str.contains("may", na=False, case=False)]["NAME OF MANUFACTURER"]
may_dict = {"MAY & BAKER NIGERIA PLC.": may.unique().tolist()}
dict_list.append(may_dict)

#Replace with correct variation for may
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("may", case=False), "MAY & BAKER NIGERIA PLC.", df["NAME OF MANUFACTURER"])

# %%
mcneil = df[df["NAME OF MANUFACTURER"].str.contains("mcneil", na=False, case=False)]["NAME OF MANUFACTURER"]
mcneil_dict = {"McNEIL & ARGUS PHARMACEUTICAL LTD": mcneil.unique().tolist()}
dict_list.append(mcneil_dict)

#Replace with correct variation for mcneil
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("mcneil", case=False), "McNEIL & ARGUS PHARMACEUTICAL LTD", df["NAME OF MANUFACTURER"])

# %%
mecure = df[df["NAME OF MANUFACTURER"].str.contains("me cure", na=False, case=False)]["NAME OF MANUFACTURER"]
mecure_dict = {"ME CURE INDUSTRIES LTD.": mecure.unique().tolist()}
dict_list.append(mecure_dict)

#Replace with correct variation for mecure
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("me cure", case=False), "ME CURE INDUSTRIES LTD.", df["NAME OF MANUFACTURER"])

# %%
medgel = df[df["NAME OF MANUFACTURER"].str.contains("medgel", na=False, case=False)]["NAME OF MANUFACTURER"]
medgel_dict = {"MEDGEL PVT LTD": medgel.unique().tolist()}
dict_list.append(medgel_dict)

#Replace with correct variation for medgel
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("medgel", case=False), "MEDGEL PVT LTD", df["NAME OF MANUFACTURER"])

# %%
medibios = df[df["NAME OF MANUFACTURER"].str.contains("medibios", na=False, case=False)]["NAME OF MANUFACTURER"]
medibios_dict = {"MEDIBIOS LABORATORIES PVT LTD": medibios.unique().tolist()}
dict_list.append(medibios_dict)

#Replace with correct variation for medibios
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("medibios", case=False), "MEDIBIOS LABORATORIES PVT LTD", df["NAME OF MANUFACTURER"])

# %%
medical = df[df["NAME OF MANUFACTURER"].str.contains("medical u", na=False, case=False)]["NAME OF MANUFACTURER"]
medical_dict = {"MEDICAL UNION PHARMACEUTICALS": medical.unique().tolist()}
dict_list.append(medical_dict)

#Replace with correct variation for medical
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("medical u", case=False), "MEDICAL UNION PHARMACEUTICALS", df["NAME OF MANUFACTURER"])

# %%
medicamen = df[df["NAME OF MANUFACTURER"].str.contains("medicamen bio", na=False, case=False)]["NAME OF MANUFACTURER"]
medicamen_dict = {"MEDICAMEN BIOTECH LTD": medicamen.unique().tolist()}
dict_list.append(medicamen_dict)

#Replace with correct variation for medicamen
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("medicamen bio", case=False), "MEDICAMEN BIOTECH LTD", df["NAME OF MANUFACTURER"])

# %%
medico = df[df["NAME OF MANUFACTURER"].str.contains("medico", na=False, case=False)]["NAME OF MANUFACTURER"]
medico_dict = {"MEDICO LABS": medico.unique().tolist()}
dict_list.append(medico_dict)

#Replace with correct variation for medico
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("medico", case=False), "MEDICO LABS", df["NAME OF MANUFACTURER"])

# %%
medin = df[df["NAME OF MANUFACTURER"].str.contains("med-in", na=False, case=False)]["NAME OF MANUFACTURER"]
medin_dict = {"MED-IN PHARM INTRAVENOUS FLUIDS": medin.unique().tolist()}
dict_list.append(medin_dict)

#Replace with correct variation for medin
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("med-in", case=False), "MED-IN PHARM INTRAVENOUS FLUIDS", df["NAME OF MANUFACTURER"])

# %%
medipharco = df[df["NAME OF MANUFACTURER"].str.contains("medipharco", na=False, case=False)]["NAME OF MANUFACTURER"]
medipharco_dict = {"MEDIPHARCO": medipharco.unique().tolist()}
dict_list.append(medipharco_dict)

#Replace with correct variation for medipharco
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("medipharco", case=False), "MEDIPHARCO", df["NAME OF MANUFACTURER"])

# %%
medisure = df[df["NAME OF MANUFACTURER"].str.contains("medisure", na=False, case=False)]["NAME OF MANUFACTURER"]
medisure_dict = {"MEDISURE LABORATORIES PAKISTAN (PVT) LIMITED": medisure.unique().tolist()}
dict_list.append(medisure_dict)

#Replace with correct variation for medisure
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("medisure", case=False), "MEDISURE LABORATORIES PAKISTAN (PVT) LIMITED", df["NAME OF MANUFACTURER"])

# %%
mediwin = df[df["NAME OF MANUFACTURER"].str.contains("mediwin", na=False, case=False)]["NAME OF MANUFACTURER"]
mediwin_dict = {"MEDIWIN PHARMACEUTICALS": mediwin.unique().tolist()}
dict_list.append(mediwin_dict)

#Replace with correct variation for mediwin
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("mediwin", case=False), "MEDIWIN PHARMACEUTICALS", df["NAME OF MANUFACTURER"])

# %%
medley = df[df["NAME OF MANUFACTURER"].str.contains("medley", na=False, case=False)]["NAME OF MANUFACTURER"]
medley_dict = {"MEDLEY PHARMACEUTICALS LTD": medley.unique().tolist()}
dict_list.append(medley_dict)

#Replace with correct variation for medley
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("medley", case=False), "MEDLEY PHARMACEUTICALS LTD", df["NAME OF MANUFACTURER"])

# %%
medopharm = df[df["NAME OF MANUFACTURER"].str.contains("medopharm", na=False, case=False)]["NAME OF MANUFACTURER"]
medopharm_dict = {"MEDOPHARM PVT LTD": medopharm.unique().tolist()}
dict_list.append(medopharm_dict)

#Replace with correct variation for medopharm
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("medopharm", case=False), "MEDOPHARM PVT LTD", df["NAME OF MANUFACTURER"])

# %%
medreich = df[df["NAME OF MANUFACTURER"].str.contains("medreich", na=False, case=False)]["NAME OF MANUFACTURER"]
medreich_dict = {"MEDREICH LIMITED": medreich.unique().tolist()}
dict_list.append(medreich_dict)

#Replace with correct variation for medreich
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("medreich", case=False), "MEDREICH LIMITED", df["NAME OF MANUFACTURER"])

# %%
medrugs = df[df["NAME OF MANUFACTURER"].str.contains("medrugs", na=False, case=False)]["NAME OF MANUFACTURER"]
medrugs_dict = {"MEDRUGS LIMITED": medrugs.unique().tolist()}
dict_list.append(medrugs_dict)

#Replace with correct variation for medrugs
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("medrugs", case=False), "MEDRUGS LIMITED", df["NAME OF MANUFACTURER"])

# %%
medwin = df[df["NAME OF MANUFACTURER"].str.contains("medwin", na=False, case=False)]["NAME OF MANUFACTURER"]
medwin_dict = {"MEDWIN PHARMACEUTICALS": medwin.unique().tolist()}
dict_list.append(medwin_dict)

#Replace with correct variation for medwin
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("medwin", case=False), "MEDWIN PHARMACEUTICALS", df["NAME OF MANUFACTURER"])

# %%
megalife = df[df["NAME OF MANUFACTURER"].str.contains("megalife", na=False, case=False)]["NAME OF MANUFACTURER"]
megalife_dict = {"MEGALIFE SCIENCES PUBLIC COMPANY LIMITED": megalife.unique().tolist()}
dict_list.append(megalife_dict)

#Replace with correct variation for megalife
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("megalife", case=False), "MEGALIFE SCIENCES PUBLIC COMPANY LIMITED", df["NAME OF MANUFACTURER"])

# %%
mekophar = df[df["NAME OF MANUFACTURER"].str.contains("mekophar", na=False, case=False)]["NAME OF MANUFACTURER"]
mekophar_dict = {"MEKOPHAR CHEMICAL PHARMACEUTICAL": mekophar.unique().tolist()}
dict_list.append(mekophar_dict)

#Replace with correct variation for mekophar
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("mekophar", case=False), "MEKOPHAR CHEMICAL PHARMACEUTICAL", df["NAME OF MANUFACTURER"])

# %%
menarini = df[df["NAME OF MANUFACTURER"].str.contains("menarini", na=False, case=False)]["NAME OF MANUFACTURER"]
menarini_dict = {"MENARINI GROUP": menarini.unique().tolist()}
dict_list.append(menarini_dict)

#Replace with correct variation for menarini
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("menarini", case=False), "MENARINI GROUP", df["NAME OF MANUFACTURER"])

# %%
merck = df[df["NAME OF MANUFACTURER"].str.contains("merck", na=False, case=False)]["NAME OF MANUFACTURER"]
merck_dict = {"MERCK": merck.unique().tolist()}
dict_list.append(merck_dict)

#Replace with correct variation for merck
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("merck", case=False), "MERCK", df["NAME OF MANUFACTURER"])

# %%
mercle = df[df["NAME OF MANUFACTURER"].str.contains("mercle", na=False, case=False)]["NAME OF MANUFACTURER"]
mercle_dict = {"MERCLE": mercle.unique().tolist()}
dict_list.append(mercle_dict)

#Replace with correct variation for mercle
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("mercle", case=False), "MERCLE", df["NAME OF MANUFACTURER"])

# %%
mercury = df[df["NAME OF MANUFACTURER"].str.contains("mercury", na=False, case=False)]["NAME OF MANUFACTURER"]
mercury_dict = {"MERCURY LABORATORIES LTD": mercury.unique().tolist()}
dict_list.append(mercury_dict)

#Replace with correct variation for mercury
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("mercury", case=False), "MERCURY LABORATORIES LTD", df["NAME OF MANUFACTURER"])

# %%
meyer = df[df["NAME OF MANUFACTURER"].str.contains("meyer o", na=False, case=False)]["NAME OF MANUFACTURER"]
meyer_dict = {"MEYER ORGANICS PVT LTD": meyer.unique().tolist()}
dict_list.append(meyer_dict)

#Replace with correct variation for meyer
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("meyer o", case=False), "MEYER ORGANICS PVT LTD", df["NAME OF MANUFACTURER"])

# %%
michelle = df[df["NAME OF MANUFACTURER"].str.contains("michelle", na=False, case=False)]["NAME OF MANUFACTURER"]
michelle_dict = {"MICHELLE LABORATORIES LTD.": michelle.unique().tolist()}
dict_list.append(michelle_dict)

#Replace with correct variation for michelle
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("michelle", case=False), "MICHELLE LABORATORIES LTD.", df["NAME OF MANUFACTURER"])

# %%
midas = df[df["NAME OF MANUFACTURER"].str.contains("midas", na=False, case=False)]["NAME OF MANUFACTURER"]
midas_dict = {"MIDAS-CARE PHARMACEUTICALS PVT LTD": midas.unique().tolist()}
dict_list.append(midas_dict)

#Replace with correct variation for midas
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("midas", case=False), "MIDAS-CARE PHARMACEUTICALS PVT LTD", df["NAME OF MANUFACTURER"])

# %%
mihika = df[df["NAME OF MANUFACTURER"].str.contains("mihika", na=False, case=False)]["NAME OF MANUFACTURER"]
mihika_dict = {"MIHIKA PHARMACEUTICALS": mihika.unique().tolist()}
dict_list.append(mihika_dict)

#Replace with correct variation for mihika
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("mihika", case=False), "MIHIKA PHARMACEUTICALS", df["NAME OF MANUFACTURER"])

# %%
milan = df[df["NAME OF MANUFACTURER"].str.contains("milan", na=False, case=False)]["NAME OF MANUFACTURER"]
milan_dict = {"MILAN LABORATORIES (INDIA) PVT LTD": milan.unique().tolist()}
dict_list.append(milan_dict)

#Replace with correct variation for milan
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("milan", case=False), "MILAN LABORATORIES (INDIA) PVT LTD", df["NAME OF MANUFACTURER"])

# %%
mipharm = df[df["NAME OF MANUFACTURER"].str.contains("mipharm", na=False, case=False)]["NAME OF MANUFACTURER"]
mipharm_dict = {"MIPHARM": mipharm.unique().tolist()}
dict_list.append(mipharm_dict)

#Replace with correct variation for mipharm
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("mipharm", case=False), "MIPHARM", df["NAME OF MANUFACTURER"])

# %%
miraflash = df[df["NAME OF MANUFACTURER"].str.contains("miraf", na=False, case=False)]["NAME OF MANUFACTURER"]
miraflash_dict = {"MIRAFLASH NIGERIA LIMITED": miraflash.unique().tolist()}
dict_list.append(miraflash_dict)

#Replace with correct variation for miraflash
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("miraflash", case=False), "MIRAFLASH NIGERIA LIMITED", df["NAME OF MANUFACTURER"])

# %%
misbah = df[df["NAME OF MANUFACTURER"].str.contains("misbah", na=False, case=False)]["NAME OF MANUFACTURER"]
misbah_dict = {"MISBAH PHARM LTD": misbah.unique().tolist()}
dict_list.append(misbah_dict)

#Replace with correct variation for misbah
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("misbah", case=False), "MISBAH PHARM LTD", df["NAME OF MANUFACTURER"])

# %%
modi = df[df["NAME OF MANUFACTURER"].str.contains("modi", na=False, case=False)]["NAME OF MANUFACTURER"]
modi_dict = {"MODI-MUNDI PHARMA PVT LTD": modi.unique().tolist()}
dict_list.append(modi_dict)

#Replace with correct variation for modi
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("modi", case=False), "MODI-MUNDI PHARMA PVT LTD", df["NAME OF MANUFACTURER"])

# %%
montage = df[df["NAME OF MANUFACTURER"].str.contains("montage", na=False, case=False)]["NAME OF MANUFACTURER"]
montage_dict = {"MONTAGE LABORATORIES PVT LTD": montage.unique().tolist()}
dict_list.append(montage_dict)

#Replace with correct variation for montage
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("montage", case=False), "MONTAGE LABORATORIES PVT LTD", df["NAME OF MANUFACTURER"])

# %%
mopson = df[df["NAME OF MANUFACTURER"].str.contains("mopson", na=False, case=False)]["NAME OF MANUFACTURER"]
mopson_dict = {"MOPSON PHARMACEUTICAL LIMITED": mopson.unique().tolist()}
dict_list.append(mopson_dict)

#Replace with correct variation for mopson
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("mopson", case=False), "MOPSON PHARMACEUTICAL LIMITED", df["NAME OF MANUFACTURER"])

# %%
morison = df[df["NAME OF MANUFACTURER"].str.contains("morison", na=False, case=False)]["NAME OF MANUFACTURER"]
morison_dict = {"MORISON INDUSTRIES PLC": morison.unique().tolist()}
dict_list.append(morison_dict)

#Replace with correct variation for morison
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("morison", case=False), "MORISON INDUSTRIES PLC", df["NAME OF MANUFACTURER"])

# %%
genix = df[df["NAME OF MANUFACTURER"].str.contains("genix", na=False, case=False)]["NAME OF MANUFACTURER"]
genix_dict = {"GENIX PHARMA LTD": genix.unique().tolist()}
dict_list.append(genix_dict)

#Replace with correct variation for genix
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("genix", case=False), "GENIX PHARMA LTD", df["NAME OF MANUFACTURER"])

# %%
msn = df[df["NAME OF MANUFACTURER"].str.contains("msn", na=False, case=False)]["NAME OF MANUFACTURER"]
msn_dict = {"MSN LABORATORIES PVT LTD": msn.unique().tolist()}
dict_list.append(msn_dict)

#Replace with correct variation for msn
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("msn", case=False), "MSN LABORATORIES PVT LTD", df["NAME OF MANUFACTURER"])

# %%
mylan = df[df["NAME OF MANUFACTURER"].str.contains("mylan", na=False, case=False)]["NAME OF MANUFACTURER"]
mylan_dict = {"MYLAN LABORATORIES LIMITED": mylan.unique().tolist()}
dict_list.append(mylan_dict)

#Replace with correct variation for mylan
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("mylan", case=False), "MYLAN LABORATORIES LIMITED", df["NAME OF MANUFACTURER"])

# %%
df["NAME OF MANUFACTURER"].unique()
# Out:
# array(['GUILIN PHARMACEUTICAL CO., LTD.', 'ECOMED PHARMA LIMITED',
#        'SHANXI XINYITONG PHARM CO. LTD', 'FIDSON HEALTHCARE PLC',
#        'AKUMS DRUGS & PHARMACEUTICALS LTD', 'BAYER PHARMACEUTICALS',
#        'CORAL LABORATORIES LTD',
#        'CSPC ZHONGNUO PHARMACEUTICAL (SHIJIAZHUANG) CO. LTD.',
#        'EMZOR PHARMACEUTICALS INDUSTRIES LIMITED',
#        'GLOBELA PHARMA PVT. LTD.', 'HOVID BHD.',
#        ' HUBEI KANGZHENG PHARM . CO., LTD.', 'INNOVA CAPTAB PVT LTD',
#        'JIANGSU RUINIAN QIANJIN PHARMACEUTICALS CO., LTD',
#        'JIANGXI XIER KANGTAI PHARMACEUTICAL CO. LTD',
#        'LESANTO LABORATORIES', 'LINCOLN PHARMACEUTICALS LTD',
#        'OLIVE HEALTHCARE', 'SYNCOM FORMULATIONS (INDIA) LTD',
#        'MAKCUR LABORATORIES LIMITED', 'MARS REMEDIES PVT LTD',
#        'McCOY PHARMA PVT LTD', 'MCW HEALTHCARE PVT LTD',
#        'NITIN LIFESCIENCES LTD.', 'OSAKA PHARMACEUTICALS PVT. LTD.',
# ...

# %%
naari = df[df["NAME OF MANUFACTURER"].str.contains("naari", na=False, case=False)]["NAME OF MANUFACTURER"]
naari_dict = {"NAARI PHARMA PRIVATE LIMITED": naari.unique().tolist()}
dict_list.append(naari_dict)

#Replace with correct variation for naari
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("naari", case=False), "NAARI PHARMA PRIVATE LIMITED", df["NAME OF MANUFACTURER"])

# %%
nalis = df[df["NAME OF MANUFACTURER"].str.contains("nalis", na=False, case=False)]["NAME OF MANUFACTURER"]
nalis_dict = {"NALIS PHARMACEUTICALS LIMITED": nalis.unique().tolist()}
dict_list.append(nalis_dict)

#Replace with correct variation for nalis
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("nalis", case=False), "NALIS PHARMACEUTICALS LIMITED", df["NAME OF MANUFACTURER"])

# %%
natco = df[df["NAME OF MANUFACTURER"].str.contains("natco", na=False, case=False)]["NAME OF MANUFACTURER"]
natco_dict = {"NATCO PHARMA LIMITED": natco.unique().tolist()}
dict_list.append(natco_dict)

#Replace with correct variation for natco
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("natco", case=False), "NATCO PHARMA LIMITED", df["NAME OF MANUFACTURER"])

# %%
nature = df[df["NAME OF MANUFACTURER"].str.contains("nature", na=False, case=False)]["NAME OF MANUFACTURER"]
nature_dict = {"NATURE & NUTURE INDUSTRIES LIMITED": nature.unique().tolist()}
dict_list.append(nature_dict)

#Replace with correct variation for nature
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("nature", case=False), "NATURE & NUTURE INDUSTRIES LIMITED", df["NAME OF MANUFACTURER"])

# %%
navketan_p = df[df["NAME OF MANUFACTURER"].str.contains("navketan p", na=False, case=False)]["NAME OF MANUFACTURER"]
navketan_p_dict = {"NAVKETAN PHARMA PVT LTD": navketan_p.unique().tolist()}
dict_list.append(navketan_p_dict)

#Replace with correct variation for navketan_p
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("navketan p", case=False), "NAVKETAN PHARMA PVT LTD", df["NAME OF MANUFACTURER"])

# %%
navketan_r = df[df["NAME OF MANUFACTURER"].str.contains("navketan r", na=False, case=False)]["NAME OF MANUFACTURER"]
navketan_r_dict = {"NAVKETAN RESEARCH AND LABORATORIES PVT LTD": navketan_r.unique().tolist()}
dict_list.append(navketan_r_dict)

#Replace with correct variation for navketan_r
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("navketan r", case=False), "NAVKETAN RESEARCH AND LABORATORIES PVT LTD", df["NAME OF MANUFACTURER"])

# %%
naxpar = df[df["NAME OF MANUFACTURER"].str.contains("naxpar", na=False, case=False)]["NAME OF MANUFACTURER"]
naxpar_dict = {"NAXPAR PHARMA PVT LTD": naxpar.unique().tolist()}
dict_list.append(naxpar_dict)

#Replace with correct variation for naxpar
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("naxpar", case=False), "NAXPAR PHARMA PVT LTD", df["NAME OF MANUFACTURER"])

# %%
ncpc_h = df[df["NAME OF MANUFACTURER"].str.contains("ncpc h", na=False, case=False)]["NAME OF MANUFACTURER"]
ncpc_h_dict = {"NCPC HEBEI HUAMIN PHARM CO. LTD": ncpc_h.unique().tolist()}
dict_list.append(ncpc_h_dict)

#Replace with correct variation for ncpc_h
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("ncpc h", case=False), "NCPC HEBEI HUAMIN PHARM CO. LTD", df["NAME OF MANUFACTURER"])

# %%
ncpc_p = df[df["NAME OF MANUFACTURER"].str.contains("ncpc p|north china", na=False, case=False)]["NAME OF MANUFACTURER"]
ncpc_p_dict = {"NORTH CHINA PHARMACEUTICAL CO. LTD": ncpc_p.unique().tolist()}
dict_list.append(ncpc_p_dict)

#Replace with correct variation for ncpc_p
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("ncpc p|north china", case=False), "NORTH CHINA PHARMACEUTICAL CO. LTD", df["NAME OF MANUFACTURER"])

# %%
nectar = df[df["NAME OF MANUFACTURER"].str.contains("nectar", na=False, case=False)]["NAME OF MANUFACTURER"]
nectar_dict = {"NECTAR LIFESCIENCES LTD": nectar.unique().tolist()}
dict_list.append(nectar_dict)

#Replace with correct variation for nectar
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("nectar", case=False), "NECTAR LIFESCIENCES LTD", df["NAME OF MANUFACTURER"])

# %%
neimeth = df[df["NAME OF MANUFACTURER"].str.contains("neimeth", na=False, case=False)]["NAME OF MANUFACTURER"]
neimeth_dict = {"NEIMETH INTERNATIONAL PHARMACEUTICALS PLC": neimeth.unique().tolist()}
dict_list.append(neimeth_dict)

#Replace with correct variation for neimeth
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("neimeth", case=False), "NEIMETH INTERNATIONAL PHARMACEUTICALS PLC", df["NAME OF MANUFACTURER"])

# %%
nem = df[df["NAME OF MANUFACTURER"].str.contains("nem lab", na=False, case=False)]["NAME OF MANUFACTURER"]
nem_dict = {"NEM LABORATORIES PVT LTD": nem.unique().tolist()}
dict_list.append(nem_dict)

#Replace with correct variation for nem
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("nem lab", case=False), "NEM LABORATORIES PVT LTD", df["NAME OF MANUFACTURER"])

# %%
nemel = df[df["NAME OF MANUFACTURER"].str.contains("nemel", na=False, case=False)]["NAME OF MANUFACTURER"]
nemel_dict = {"NEMEL PHARMACEUTICALS LIMITED": nemel.unique().tolist()}
dict_list.append(nemel_dict)

#Replace with correct variation for nemel
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("nemel", case=False), "NEMEL PHARMACEUTICALS LIMITED", df["NAME OF MANUFACTURER"])

# %%
neon = df[df["NAME OF MANUFACTURER"].str.contains("neon", na=False, case=False)]["NAME OF MANUFACTURER"]
neon_dict = {"NEON LABORATORIES LTD": neon.unique().tolist()}
dict_list.append(neon_dict)

#Replace with correct variation for neon
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("neon", case=False), "NEON LABORATORIES LTD", df["NAME OF MANUFACTURER"])

# %%
neopharma = df[df["NAME OF MANUFACTURER"].str.contains("neopharma", na=False, case=False)]["NAME OF MANUFACTURER"]
neopharma_dict = {"NEOPHARMA LLC": neopharma.unique().tolist()}
dict_list.append(neopharma_dict)

#Replace with correct variation for neopharma
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("neopharma", case=False), "NEOPHARMA LLC", df["NAME OF MANUFACTURER"])

# %%
neros = df[df["NAME OF MANUFACTURER"].str.contains("neros", na=False, case=False)]["NAME OF MANUFACTURER"]
neros_dict = {"NEROS PHARMACEUTICALS LTD": neros.unique().tolist()}
dict_list.append(neros_dict)

#Replace with correct variation for neros
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("neros", case=False), "NEROS PHARMACEUTICALS LTD", df["NAME OF MANUFACTURER"])

# %%
new_d = df[df["NAME OF MANUFACTURER"].str.contains("new d", na=False, case=False)]["NAME OF MANUFACTURER"]
new_d_dict = {"NEW DIVINE FAVOUR PHARMACEUTICALS INDUSTRIES LIMITED": new_d.unique().tolist()}
dict_list.append(new_d_dict)

#Replace with correct variation for new_d
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("new d", case=False), "NEW DIVINE FAVOUR PHARMACEUTICALS INDUSTRIES LIMITED", df["NAME OF MANUFACTURER"])

# %%
new_h = df[df["NAME OF MANUFACTURER"].str.contains("new h", na=False, case=False)]["NAME OF MANUFACTURER"]
new_h_dict = {"NEW HEALTHWAY COMPANY LIMITED": new_h.unique().tolist()}
dict_list.append(new_h_dict)

#Replace with correct variation for new_h
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("new h", case=False), "NEW HEALTHWAY COMPANY LIMITED", df["NAME OF MANUFACTURER"])

# %%
nhmb = df[df["NAME OF MANUFACTURER"].str.contains("nhmb", na=False, case=False)]["NAME OF MANUFACTURER"]
nhmb_dict = {"NHMB COMPANY LTD": nhmb.unique().tolist()}
dict_list.append(nhmb_dict)

#Replace with correct variation for nhmb
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("nhmb", case=False), "NHMB COMPANY LTD", df["NAME OF MANUFACTURER"])

# %%
nichben = df[df["NAME OF MANUFACTURER"].str.contains("nichben", na=False, case=False)]["NAME OF MANUFACTURER"]
nichben_dict = {"NICHBEN PHARM IND NIG LTD": nichben.unique().tolist()}
dict_list.append(nichben_dict)

#Replace with correct variation for nichben
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("nichben", case=False), "NICHBEN PHARM IND NIG LTD", df["NAME OF MANUFACTURER"])

# %%
airforce = df[df["NAME OF MANUFACTURER"].str.contains("airforce", na=False, case=False)]["NAME OF MANUFACTURER"]
airforce_dict = {"NIGERIAN AIRFORCE DRUG MANUFACTURING UNIT LTD": airforce.unique().tolist()}
dict_list.append(airforce_dict)

#Replace with correct variation for airforce
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("airforce", case=False), "NIGERIAN AIRFORCE DRUG MANUFACTURING UNIT LTD", df["NAME OF MANUFACTURER"])

# %%
army = df[df["NAME OF MANUFACTURER"].str.contains("army", na=False, case=False)]["NAME OF MANUFACTURER"]
army_dict = {"NIGERIAN ARMY SMALL SCALE DRUG MANUFACTURING UNIT (NASDMU)": army.unique().tolist()}
dict_list.append(army_dict)

#Replace with correct variation for army
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("army", case=False), "NIGERIAN ARMY SMALL SCALE DRUG MANUFACTURING UNIT (NASDMU)", df["NAME OF MANUFACTURER"])

# %%
nigerian_g = df[df["NAME OF MANUFACTURER"].str.contains("nigerian g", na=False, case=False)]["NAME OF MANUFACTURER"]
nigerian_g_dict = {"NIGERIAN GERMAN CHEMICALS PLC": nigerian_g.unique().tolist()}
dict_list.append(nigerian_g_dict)

#Replace with correct variation for nigerian_g
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("nigerian g", case=False), "NIGERIAN GERMAN CHEMICALS PLC", df["NAME OF MANUFACTURER"])

# %%
ningbo = df[df["NAME OF MANUFACTURER"].str.contains("ningbo", na=False, case=False)]["NAME OF MANUFACTURER"]
ningbo_dict = {"NINGBO DAHONGYING PHARM CO LTD": ningbo.unique().tolist()}
dict_list.append(ningbo_dict)

#Replace with correct variation for ningbo
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("ningbo", case=False), "NINGBO DAHONGYING PHARM CO LTD", df["NAME OF MANUFACTURER"])

# %%
nino = df[df["NAME OF MANUFACTURER"].str.contains("nino", na=False, case=False)]["NAME OF MANUFACTURER"]
nino_dict = {"NINO PHARMA & CHEMICAL COMPANY LIMITED": nino.unique().tolist()}
dict_list.append(nino_dict)

#Replace with correct variation for nino
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("nino", case=False), "NINO PHARMA & CHEMICAL COMPANY LIMITED", df["NAME OF MANUFACTURER"])

# %%
norris = df[df["NAME OF MANUFACTURER"].str.contains("norris", na=False, case=False)]["NAME OF MANUFACTURER"]
norris_dict = {"NORRIS MEDICINES LIMITED":norris.unique().tolist()}
dict_list.append(norris_dict)

#Replace with correct variation for norris
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("norris", case=False), "NORRIS MEDICINES LIMITED", df["NAME OF MANUFACTURER"])

# %%
novartis = df[df["NAME OF MANUFACTURER"].str.contains("novartis|norv", na=False, case=False)]["NAME OF MANUFACTURER"]
novartis_dict = {"NOVARTIS PHARMA":novartis.unique().tolist()}
dict_list.append(novartis_dict)

#Replace with correct variation for novartis
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("novartis|norv", case=False), "NOVARTIS PHARMA", df["NAME OF MANUFACTURER"])

# %%
nouvasant = df[df["NAME OF MANUFACTURER"].str.contains("nouvasant", na=False, case=False)]["NAME OF MANUFACTURER"]
nouvasant_dict = {"NOUVASANT PHARMHEALTH LTD":nouvasant.unique().tolist()}
dict_list.append(nouvasant_dict)

#Replace with correct variation for nouvasant
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("nouvasant", case=False), "NOUVASANT PHARMHEALTH LTD", df["NAME OF MANUFACTURER"])

# %%
nucleus = df[df["NAME OF MANUFACTURER"].str.contains("nucleus", na=False, case=False)]["NAME OF MANUFACTURER"]
nucleus_dict = {"NUCLEUS FORMULATION PVT LTD":nucleus.unique().tolist()}
dict_list.append(nucleus_dict)

#Replace with correct variation for nucleus
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("nucleus", case=False), "NUCLEUS FORMULATION PVT LTD", df["NAME OF MANUFACTURER"])

# %%
nuel = df[df["NAME OF MANUFACTURER"].str.contains("nuel", na=False, case=False)]["NAME OF MANUFACTURER"]
nuel_dict = {"NUEL PHARMACEUTICAL LIMITED": nuel.unique().tolist()}
dict_list.append(nuel_dict)

#Replace with correct variation for nuel
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("nuel", case=False), "NUEL PHARMACEUTICAL LIMITED", df["NAME OF MANUFACTURER"])

# %%
nugale = df[df["NAME OF MANUFACTURER"].str.contains("nugale", na=False, case=False)]["NAME OF MANUFACTURER"]
nugale_dict = {"NUGALE PHARM INCORPORATED": nugale.unique().tolist()}
dict_list.append(nugale_dict)

#Replace with correct variation for nugale
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("nugale", case=False), "NUGALE PHARM INCORPORATED", df["NAME OF MANUFACTURER"])

# %%
df["NAME OF MANUFACTURER"].unique()
# Out:
# array(['GUILIN PHARMACEUTICAL CO., LTD.', 'ECOMED PHARMA LIMITED',
#        'SHANXI XINYITONG PHARM CO. LTD', 'FIDSON HEALTHCARE PLC',
#        'AKUMS DRUGS & PHARMACEUTICALS LTD', 'BAYER PHARMACEUTICALS',
#        'CORAL LABORATORIES LTD',
#        'CSPC ZHONGNUO PHARMACEUTICAL (SHIJIAZHUANG) CO. LTD.',
#        'EMZOR PHARMACEUTICALS INDUSTRIES LIMITED',
#        'GLOBELA PHARMA PVT. LTD.', 'HOVID BHD.',
#        ' HUBEI KANGZHENG PHARM . CO., LTD.', 'INNOVA CAPTAB PVT LTD',
#        'JIANGSU RUINIAN QIANJIN PHARMACEUTICALS CO., LTD',
#        'JIANGXI XIER KANGTAI PHARMACEUTICAL CO. LTD',
#        'LESANTO LABORATORIES', 'LINCOLN PHARMACEUTICALS LTD',
#        'OLIVE HEALTHCARE', 'SYNCOM FORMULATIONS (INDIA) LTD',
#        'MAKCUR LABORATORIES LIMITED', 'MARS REMEDIES PVT LTD',
#        'McCOY PHARMA PVT LTD', 'MCW HEALTHCARE PVT LTD',
#        'NITIN LIFESCIENCES LTD.', 'OSAKA PHARMACEUTICALS PVT. LTD.',
# ...

# %%
oak = df[df["NAME OF MANUFACTURER"].str.contains("oak", na=False, case=False)]["NAME OF MANUFACTURER"]
oak_dict = {"OAK FAITH PHARMACEUTICAL RESOURCES LIMITED": oak.unique().tolist()}
dict_list.append(oak_dict)

#Replace with correct variation for oak
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("oak", case=False), "OAK FAITH PHARMACEUTICAL RESOURCES LIMITED", df["NAME OF MANUFACTURER"])

# %%
ocean = df[df["NAME OF MANUFACTURER"].str.contains("ocean", na=False, case=False)]["NAME OF MANUFACTURER"]
ocean_dict = {"OCEAN HEALTHCARE PVT LTD": ocean.unique().tolist()}
dict_list.append(ocean_dict)

#Replace with correct variation for ocean
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("ocean", case=False), "OCEAN HEALTHCARE PVT LTD", df["NAME OF MANUFACTURER"])

# %%
odesco = df[df["NAME OF MANUFACTURER"].str.contains("odesco", na=False, case=False)]["NAME OF MANUFACTURER"]
odesco_dict = {"ODESCO PHARM IND NIG LTD": odesco.unique().tolist()}
dict_list.append(odesco_dict)

#Replace with correct variation for odesco
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("odesco", case=False), "ODESCO PHARM IND NIG LTD", df["NAME OF MANUFACTURER"])

# %%
oncotec = df[df["NAME OF MANUFACTURER"].str.contains("oncotec", na=False, case=False)]["NAME OF MANUFACTURER"]
oncotec_dict = {"ONCOTEC PHARMA PRODUKTION": oncotec.unique().tolist()}
dict_list.append(oncotec_dict)

#Replace with correct variation for oncotec
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("oncotec", case=False), "ONCOTEC PHARMA PRODUKTION", df["NAME OF MANUFACTURER"])

# %%
orange = df[df["NAME OF MANUFACTURER"].str.contains("orange", na=False, case=False)]["NAME OF MANUFACTURER"]
orange_dict = {"ORANGE KALBE LIMITED": orange.unique().tolist()}
dict_list.append(orange_dict)

#Replace with correct variation for orange
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("orange", case=False), "ORANGE KALBE LIMITED", df["NAME OF MANUFACTURER"])

# %%
ordain = df[df["NAME OF MANUFACTURER"].str.contains("ordain", na=False, case=False)]["NAME OF MANUFACTURER"]
ordain_dict = {"ORDAIN HEALTH CARE GLOBAL PVT. LTD": ordain.unique().tolist()}
dict_list.append(ordain_dict)

#Replace with correct variation for ordain
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("ordain", case=False), "ORDAIN HEALTH CARE GLOBAL PVT. LTD", df["NAME OF MANUFACTURER"])

# %%
orfema = df[df["NAME OF MANUFACTURER"].str.contains("orfema", na=False, case=False)]["NAME OF MANUFACTURER"]
orfema_dict = {"ORFEMA PHARMACEUTICAL INDUSTRY LIMITED": orfema.unique().tolist()}
dict_list.append(orfema_dict)

#Replace with correct variation for orfema
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("orfema", case=False), "ORFEMA PHARMACEUTICAL INDUSTRY LIMITED", df["NAME OF MANUFACTURER"])

# %%
oxalis = df[df["NAME OF MANUFACTURER"].str.contains("oxalis", na=False, case=False)]["NAME OF MANUFACTURER"]
oxalis_dict = {"OXALIS LAB": oxalis.unique().tolist()}
dict_list.append(oxalis_dict)

#Replace with correct variation for oxalis
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("oxalis", case=False), "OXALIS LAB", df["NAME OF MANUFACTURER"])

# %%
ozah = df[df["NAME OF MANUFACTURER"].str.contains("ozah", na=False, case=False)]["NAME OF MANUFACTURER"]
ozah_dict = {"OZAH CHEMICALS & PHARM LTD": ozah.unique().tolist()}
dict_list.append(ozah_dict)

#Replace with correct variation for ozah
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("ozah", case=False), "OZAH CHEMICALS & PHARM LTD", df["NAME OF MANUFACTURER"])

# %%
dankos = df[df["NAME OF MANUFACTURER"].str.contains("dankos", na=False, case=False)]["NAME OF MANUFACTURER"]
dankos_dict = {"PT DANKOS FARMA": dankos.unique().tolist()}
dict_list.append(dankos_dict)

#Replace with correct variation for dankos
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("dankos", case=False), "PT DANKOS FARMA", df["NAME OF MANUFACTURER"])

# %%
tempo = df[df["NAME OF MANUFACTURER"].str.contains("tempo", na=False, case=False)]["NAME OF MANUFACTURER"]
tempo_dict = {"PT TEMPO SCAN PACIFIC": tempo.unique().tolist()}
dict_list.append(tempo_dict)

#Replace with correct variation for tempo
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("tempo", case=False), "PT TEMPO SCAN PACIFIC", df["NAME OF MANUFACTURER"])

# %%
pal = df[df["NAME OF MANUFACTURER"].str.contains("pal p", na=False, case=False)]["NAME OF MANUFACTURER"]
pal_dict = {"PAL PHARMACEUTICAL IND. LTD.": pal.unique().tolist()}
dict_list.append(pal_dict)

#Replace with correct variation for pal
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("pal", case=False), "PAL PHARMACEUTICAL IND LTD", df["NAME OF MANUFACTURER"])

# %%
patheon = df[df["NAME OF MANUFACTURER"].str.contains("patheon", na=False, case=False)]["NAME OF MANUFACTURER"]
patheon_dict = {"PATHEON INC.": patheon.unique().tolist()}
dict_list.append(patheon_dict)

#Replace with correct variation for patheon
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("patheon", case=False), "PATHEON INC.", df["NAME OF MANUFACTURER"])

# %%
pauco = df[df["NAME OF MANUFACTURER"].str.contains("pauco", na=False, case=False)]["NAME OF MANUFACTURER"]
pauco_dict = {"PAUCO PHARM INDUSTRIES NIG LTD": pauco.unique().tolist()}
dict_list.append(pauco_dict)

#Replace with correct variation for pauco
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("pauco", case=False), "PAUCO PHARM INDUSTRIES NIG LTD", df["NAME OF MANUFACTURER"])

# %%
peace = df[df["NAME OF MANUFACTURER"].str.contains("peace", na=False, case=False)]["NAME OF MANUFACTURER"]
peace_dict = {"PEACE STANDARD PHARM IND LTD": peace.unique().tolist()}
dict_list.append(peace_dict)

#Replace with correct variation for peace
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("peace", case=False), "PEACE STANDARD PHARM IND LTD", df["NAME OF MANUFACTURER"])

# %%
pell = df[df["NAME OF MANUFACTURER"].str.contains("pell", na=False, case=False)]["NAME OF MANUFACTURER"]
pell_dict = {"PELL TECH HEALTHCARE PVT LTD": pell.unique().tolist()}
dict_list.append(pell_dict)

#Replace with correct variation for pell
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("pell", case=False), "PELL TECH HEALTHCARE PVT LTD", df["NAME OF MANUFACTURER"])

# %%
pfizer = df[df["NAME OF MANUFACTURER"].str.contains("pfizer", na=False, case=False)]["NAME OF MANUFACTURER"]
pfizer_dict = {"PFIZER PHARMACEUTICALS LLC": pfizer.unique().tolist()}
dict_list.append(pfizer_dict)

#Replace with correct variation for pfizer
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("pfizer", case=False), "PFIZER PHARMACEUTICALS LLC", df["NAME OF MANUFACTURER"])

# %%
phamatex = df[df["NAME OF MANUFACTURER"].str.contains("pharmatex|phamatex", na=False, case=False)]["NAME OF MANUFACTURER"]
phamatex_dict = {"PHAMATEX INDUSTRIES LIMITED": phamatex.unique().tolist()}
dict_list.append(phamatex_dict)

#Replace with correct variation for phamatex
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("pharmatex|phamatex", case=False), "PHAMATEX INDUSTRIES LIMITED", df["NAME OF MANUFACTURER"])

# %%
pharco = df[df["NAME OF MANUFACTURER"].str.contains("pharco p", na=False, case=False)]["NAME OF MANUFACTURER"]
pharco_dict = {"PHARCO PHARM LIMITED": pharco.unique().tolist()}
dict_list.append(pharco_dict)

#Replace with correct variation for pharco
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("pharco p", case=False), "PHARCO PHARM LIMITED", df["NAME OF MANUFACTURER"])

# %%
pharmasol = df[df["NAME OF MANUFACTURER"].str.contains("pharmasol", na=False, case=False)]["NAME OF MANUFACTURER"]
pharmasol_dict = {"PHARMASOL LIMITED": pharmasol.unique().tolist()}
dict_list.append(pharmasol_dict)

#Replace with correct variation for pharmasol
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("pharmasol", case=False), "PHARMASOL LIMITED", df["NAME OF MANUFACTURER"])

# %%
pharmax = df[df["NAME OF MANUFACTURER"].str.contains("pharmax", na=False, case=False)]["NAME OF MANUFACTURER"]
pharmax_dict = {"PHARMAX INDIA PRIVATE LTD": pharmax.unique().tolist()}
dict_list.append(pharmax_dict)

#Replace with correct variation for pharmax
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("pharmax", case=False), "PHARMAX INDIA PRIVATE LTD", df["NAME OF MANUFACTURER"])

# %%
pharmedic = df[df["NAME OF MANUFACTURER"].str.contains("pharmedic", na=False, case=False)]["NAME OF MANUFACTURER"]
pharmedic_dict = {"PHARMEDIC JSC": pharmedic.unique().tolist()}
dict_list.append(pharmedic_dict)

#Replace with correct variation for pharmedic
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("pharmedic", case=False), "PHARMEDIC JSC", df["NAME OF MANUFACTURER"])

# %%
pharmevo = df[df["NAME OF MANUFACTURER"].str.contains("pharmevo", na=False, case=False)]["NAME OF MANUFACTURER"]
pharmevo_dict = {"PHARMEVO PVT LTD": pharmevo.unique().tolist()}
dict_list.append(pharmevo_dict)

#Replace with correct variation for pharmevo
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("pharmevo", case=False), "PHARMEVO PVT LTD", df["NAME OF MANUFACTURER"])

# %%
pierre = df[df["NAME OF MANUFACTURER"].str.contains("pierre", na=False, case=False)]["NAME OF MANUFACTURER"]
pierre_dict = {"PIERRE FABRE MEDICAMENT PRODUCTION": pierre.unique().tolist()}
dict_list.append(pierre_dict)

#Replace with correct variation for pierre
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("pierre", case=False), "PIERRE FABRE MEDICAMENT PRODUCTION", df["NAME OF MANUFACTURER"])

# %%
pinnacle = df[df["NAME OF MANUFACTURER"].str.contains("pinnacle", na=False, case=False)]["NAME OF MANUFACTURER"]
pinnacle_dict = {"PINNACLE LIFE SCIENCE PVT LTD": pinnacle.unique().tolist()}
dict_list.append(pinnacle_dict)

#Replace with correct variation for pinnacle
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("pinnacle", case=False), "PINNACLE LIFE SCIENCE PVT LTD", df["NAME OF MANUFACTURER"])

# %%
piramal = df[df["NAME OF MANUFACTURER"].str.contains("piramal", na=False, case=False)]["NAME OF MANUFACTURER"]
piramal_dict = {"PIRAMAL HEALTHCARE UK LIMITED": piramal.unique().tolist()}
dict_list.append(piramal_dict)

#Replace with correct variation for piramal
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("piramal", case=False), "PIRAMAL HEALTHCARE UK LIMITED", df["NAME OF MANUFACTURER"])

# %%
popular = df[df["NAME OF MANUFACTURER"].str.contains("popular", na=False, case=False)]["NAME OF MANUFACTURER"]
popular_dict = {"POPULAR PHARMACEUTICALS LTD": popular.unique().tolist()}
dict_list.append(popular_dict)

#Replace with correct variation for popular
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("popular", case=False), "POPULAR PHARMACEUTICALS LTD", df["NAME OF MANUFACTURER"])

# %%
pregna = df[df["NAME OF MANUFACTURER"].str.contains("pregna", na=False, case=False)]["NAME OF MANUFACTURER"]
pregna_dict = {"PREGNA INTERNATIONAL LTD": pregna.unique().tolist()}    
dict_list.append(pregna_dict)

#Replace with correct variation for pregna
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("pregna", case=False), "PREGNA INTERNATIONAL LTD", df["NAME OF MANUFACTURER"])

# %%
principle = df[df["NAME OF MANUFACTURER"].str.contains("principle", na=False, case=False)]["NAME OF MANUFACTURER"]
principle_dict = {"PRINCIPLE HEALTHCARE GROUP": principle.unique().tolist()}       
dict_list.append(principle_dict)

#Replace with correct variation for principle
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("principle", case=False), "PRINCIPLE HEALTHCARE GROUP", df["NAME OF MANUFACTURER"])

# %%
protech = df[df["NAME OF MANUFACTURER"].str.contains("protech", na=False, case=False)]["NAME OF MANUFACTURER"]
protech_dict = {"PROTECH BIOSYSTEMS PVT. LTD.": protech.unique().tolist()}   
dict_list.append(protech_dict)

#Replace with correct variation for protech
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("protech", case=False), "PROTECH BIOSYSTEMS PVT. LTD.", df["NAME OF MANUFACTURER"])

# %%
psychotropics = df[df["NAME OF MANUFACTURER"].str.contains("psychotropics", na=False, case=False)]["NAME OF MANUFACTURER"]
psychotropics_dict = {"PSYCHOTROPICS INDIA LTD.": psychotropics.unique().tolist()}   
dict_list.append(psychotropics_dict)

#Replace with correct variation for psychotropics
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("psychotropics", case=False), "PSYCHOTROPICS INDIA LTD.", df["NAME OF MANUFACTURER"])

# %%
binatang = df[df["NAME OF MANUFACTURER"].str.contains("binatang", na=False, case=False)]["NAME OF MANUFACTURER"]
binatang_dict = {"PT BINATANG TOEDJOE": binatang.unique().tolist()}   
dict_list.append(binatang_dict)

#Replace with correct variation for binatang
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("binatang", case=False), "PT BINATANG TOEDJOE", df["NAME OF MANUFACTURER"])

# %%
dexa = df[df["NAME OF MANUFACTURER"].str.contains("dexa", na=False, case=False)]["NAME OF MANUFACTURER"]
dexa_dict = {"PT DEXA MEDICA": dexa.unique().tolist()}   
dict_list.append(dexa_dict)

#Replace with correct variation for dexa
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("dexa", case=False), "PT DEXA MEDICA", df["NAME OF MANUFACTURER"])

# %%
kalbe = df[df["NAME OF MANUFACTURER"].str.contains("kalbe f", na=False, case=False)]["NAME OF MANUFACTURER"]
kalbe_dict = {"PT KALBE FARMA TBK": kalbe.unique().tolist()}   
dict_list.append(kalbe_dict)

#Replace with correct variation for kalbe
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("kalbe f", case=False), "PT KALBE FARMA TBK", df["NAME OF MANUFACTURER"])

# %%
kimia = df[df["NAME OF MANUFACTURER"].str.contains("kimia", na=False, case=False)]["NAME OF MANUFACTURER"]
kimia_dict = {"PT KIMIA FARMA (PERSERO) TBK": kimia.unique().tolist()}   
dict_list.append(kimia_dict)

#Replace with correct variation for kimia
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("kimia", case=False), "PT KIMIA FARMA (PERSERO) TBK", df["NAME OF MANUFACTURER"])

# %%
harsen = df[df["NAME OF MANUFACTURER"].str.contains("harsen", na=False, case=False)]["NAME OF MANUFACTURER"]
harsen_dict = {"PT HARSEN": harsen.unique().tolist()}   
dict_list.append(harsen_dict)

#Replace with correct variation for harsen
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("harsen", case=False), "PT HARSEN", df["NAME OF MANUFACTURER"])

# %%
marin = df[df["NAME OF MANUFACTURER"].str.contains("marin", na=False, case=False)]["NAME OF MANUFACTURER"]
marin_dict = {"PT MARIN LIZA FARMASI": marin.unique().tolist()}   
dict_list.append(marin_dict)

#Replace with correct variation for marin
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("marin", case=False), "PT MARIN LIZA FARMASI", df["NAME OF MANUFACTURER"])

# %%
pim = df[df["NAME OF MANUFACTURER"].str.contains("pim", na=False, case=False)]["NAME OF MANUFACTURER"]
pim_dict = {"PT PIM  PHARMACEUTICALS": pim.unique().tolist()}   
dict_list.append(pim_dict)

#Replace with correct variation for pim
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("pim", case=False), "PT PIM  PHARMACEUTICALS", df["NAME OF MANUFACTURER"])

# %%
pulse = df[df["NAME OF MANUFACTURER"].str.contains("pulse pharmaceutical", na=False, case=False)]["NAME OF MANUFACTURER"]
pulse_dict = {"PULSE PHARMACEUTICALS PVT LTD": pulse.unique().tolist()}   
dict_list.append(pulse_dict)

#Replace with correct variation for pulse
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("pulse pharmaceutical", case=False), "PULSE PHARMACEUTICALS PVT LTD", df["NAME OF MANUFACTURER"])

# %%
cussons = df[df["NAME OF MANUFACTURER"].str.contains("cussons", na=False, case=False)]["NAME OF MANUFACTURER"]
cussons_dict = {"PZ CUSSONS NIGERIA PLC": cussons.unique().tolist()}   
dict_list.append(cussons_dict)

#Replace with correct variation for cussons
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("cussons", case=False), "PZ CUSSONS NIGERIA PLC", df["NAME OF MANUFACTURER"])

# %%
queisser = df[df["NAME OF MANUFACTURER"].str.contains("queisser", na=False, case=False)]["NAME OF MANUFACTURER"]
queisser_dict = {"QUEISSER PHARMA": queisser.unique().tolist()}   
dict_list.append(queisser_dict)

#Replace with correct variation for queisser
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("queisser", case=False), "QUEISSER PHARMA", df["NAME OF MANUFACTURER"])

# %%
df["NAME OF MANUFACTURER"].unique()
# Out:
# array(['GUILIN PHARMACEUTICAL CO., LTD.', 'ECOMED PHARMA LIMITED',
#        'SHANXI XINYITONG PHARM CO. LTD', 'FIDSON HEALTHCARE PLC',
#        'AKUMS DRUGS & PHARMACEUTICALS LTD', 'BAYER PHARMACEUTICALS',
#        'CORAL LABORATORIES LTD',
#        'CSPC ZHONGNUO PHARMACEUTICAL (SHIJIAZHUANG) CO. LTD.',
#        'EMZOR PHARMACEUTICALS INDUSTRIES LIMITED',
#        'GLOBELA PHARMA PVT. LTD.', 'HOVID BHD.',
#        ' HUBEI KANGZHENG PHARM . CO., LTD.', 'INNOVA CAPTAB PVT LTD',
#        'JIANGSU RUINIAN QIANJIN PHARMACEUTICALS CO., LTD',
#        'JIANGXI XIER KANGTAI PHARMACEUTICAL CO. LTD',
#        'LESANTO LABORATORIES', 'LINCOLN PHARMACEUTICALS LTD',
#        'OLIVE HEALTHCARE', 'SYNCOM FORMULATIONS (INDIA) LTD',
#        'MAKCUR LABORATORIES LIMITED', 'MARS REMEDIES PVT LTD',
#        'McCOY PHARMA PVT LTD', 'MCW HEALTHCARE PVT LTD',
#        'NITIN LIFESCIENCES LTD.', 'OSAKA PHARMACEUTICALS PVT. LTD.',
# ...

# %%
rafarm = df[df["NAME OF MANUFACTURER"].str.contains("rafarm", na=False, case=False)]["NAME OF MANUFACTURER"]
rafarm_dict = {"RAFARM": rafarm.unique().tolist()}   
dict_list.append(rafarm_dict)

#Replace with correct variation for rafarm
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("rafarm", case=False), "RAFARM", df["NAME OF MANUFACTURER"])

# %%
rajrab = df[df["NAME OF MANUFACTURER"].str.contains("rajrab", na=False, case=False)]["NAME OF MANUFACTURER"]
rajrab_dict = {"RAJRAB LTD": rajrab.unique().tolist()}   
dict_list.append(rajrab_dict)

#Replace with correct variation for rajrab
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("rajrab", case=False), "RAJRAB LTD", df["NAME OF MANUFACTURER"])

# %%
ranbaxy = df[df["NAME OF MANUFACTURER"].str.contains("ranbaxy", na=False, case=False)]["NAME OF MANUFACTURER"]
ranbaxy_dict = {"RANBAXY LABORATORIES LIMITED": ranbaxy.unique().tolist()}   
dict_list.append(ranbaxy_dict)

#Replace with correct variation for ranbaxy
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("ranbaxy", case=False), "RANBAXY LABORATORIES LIMITED", df["NAME OF MANUFACTURER"])

# %%
ratnamani = df[df["NAME OF MANUFACTURER"].str.contains("ratnamani", na=False, case=False)]["NAME OF MANUFACTURER"]
ratnamani_dict = {"RATNAMANI HEALTHCARE PVT LTD": ratnamani.unique().tolist()}   
dict_list.append(ratnamani_dict)

#Replace with correct variation for ratnamani
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("ratnamani", case=False), "RATNAMANI HEALTHCARE PVT LTD", df["NAME OF MANUFACTURER"])

# %%
ravenbhel = df[df["NAME OF MANUFACTURER"].str.contains("ravenbhel", na=False, case=False)]["NAME OF MANUFACTURER"]
ravenbhel_dict = {"RAVENBHEL HEALTHCARE PVT LTD": ravenbhel.unique().tolist()}   
dict_list.append(ravenbhel_dict)

#Replace with correct variation for ravenbhel
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("ravenbhel", case=False), "RAVENBHEL HEALTHCARE PVT LTD", df["NAME OF MANUFACTURER"])

# %%
reagan = df[df["NAME OF MANUFACTURER"].str.contains("reagan", na=False, case=False)]["NAME OF MANUFACTURER"]
reagan_dict = {"REAGAN REMEDIES LIMITED": reagan.unique().tolist()}   
dict_list.append(reagan_dict)

#Replace with correct variation for reagan
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("reagan", case=False), "REAGAN REMEDIES LIMITED", df["NAME OF MANUFACTURER"])

# %%
reckitt = df[df["NAME OF MANUFACTURER"].str.contains("reckitt", na=False, case=False)]["NAME OF MANUFACTURER"]
reckitt_dict = {"RECKITT BENCKISER INTERNATIONAL LIMITED": reckitt.unique().tolist()}   
dict_list.append(reckitt_dict)

#Replace with correct variation for reckitt
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("reckitt", case=False), "RECKITT BENCKISER INTERNATIONAL LIMITED", df["NAME OF MANUFACTURER"])

# %%
regal = df[df["NAME OF MANUFACTURER"].str.contains("regal", na=False, case=False)]["NAME OF MANUFACTURER"]
regal_dict = {"REGAL LABORATORIES": regal.unique().tolist()}   
dict_list.append(regal_dict)

#Replace with correct variation for regal
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("regal", case=False), "REGAL LABORATORIES", df["NAME OF MANUFACTURER"])

# %%
relax = df[df["NAME OF MANUFACTURER"].str.contains("relax", na=False, case=False)]["NAME OF MANUFACTURER"]
relax_dict = {"RELAX BIOTECH PVT LTD": relax.unique().tolist()}   
dict_list.append(relax_dict)

#Replace with correct variation for relax
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("relax", case=False), "RELAX BIOTECH PVT LTD", df["NAME OF MANUFACTURER"])

# %%
remedica = df[df["NAME OF MANUFACTURER"].str.contains("remedica", na=False, case=False)]["NAME OF MANUFACTURER"]
remedica_dict = {"REMEDICA LIMITED": remedica.unique().tolist()}   
dict_list.append(remedica_dict)

#Replace with correct variation for remedica
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("remedica", case=False), "REMEDICA LIMITED", df["NAME OF MANUFACTURER"])

# %%
remica = df[df["NAME OF MANUFACTURER"].str.contains("remica", na=False, case=False)]["NAME OF MANUFACTURER"]
remica_dict = {"REMICA LTD": remica.unique().tolist()}   
dict_list.append(remica_dict)

#Replace with correct variation for remica
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("remica", case=False), "REMICA LTD", df["NAME OF MANUFACTURER"])

# %%
renata = df[df["NAME OF MANUFACTURER"].str.contains("renata", na=False, case=False)]["NAME OF MANUFACTURER"]
renata_dict = {"RENATA LTD": renata.unique().tolist()}   
dict_list.append(renata_dict)

#Replace with correct variation for renata
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("renata", case=False), "RENATA LTD", df["NAME OF MANUFACTURER"])

# %%
renown = df[df["NAME OF MANUFACTURER"].str.contains("renown", na=False, case=False)]["NAME OF MANUFACTURER"]
renown_dict = {"RENOWN PHARMA PVT LTD": renown.unique().tolist()}   
dict_list.append(renown_dict)

#Replace with correct variation for renown
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("renown", case=False), "RENOWN PHARMA PVT LTD", df["NAME OF MANUFACTURER"])

# %%
replek = df[df["NAME OF MANUFACTURER"].str.contains("replek", na=False, case=False)]["NAME OF MANUFACTURER"]
replek_dict = {"REPLEK FARM LTD.": replek.unique().tolist()}   
dict_list.append(replek_dict)

#Replace with correct variation for replek
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("replek", case=False), "REPLEK FARM LTD.", df["NAME OF MANUFACTURER"])

# %%
richy = df[df["NAME OF MANUFACTURER"].str.contains("richy", na=False, case=False)]["NAME OF MANUFACTURER"]
richy_dict = {"RICHYGOLD INTERNATIONAL LIMITED": richy.unique().tolist()}   
dict_list.append(richy_dict)

#Replace with correct variation for richy
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("richy", case=False), "RICHYGOLD INTERNATIONAL LIMITED", df["NAME OF MANUFACTURER"])

# %%
rock = df[df["NAME OF MANUFACTURER"].str.contains("rock", na=False, case=False)]["NAME OF MANUFACTURER"]
rock_dict = {"ROCK PHARM LABORATORIES PVT LTD": rock.unique().tolist()}   
dict_list.append(rock_dict)

#Replace with correct variation for rock
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("rock", case=False), "ROCK PHARM LABORATORIES PVT LTD", df["NAME OF MANUFACTURER"])

# %%
ronald = df[df["NAME OF MANUFACTURER"].str.contains("ronald", na=False, case=False)]["NAME OF MANUFACTURER"]
ronald_dict = {"RONALD PHARMACEUTICALS PVT LTD": ronald.unique().tolist()}   
dict_list.append(ronald_dict)

#Replace with correct variation for ronald
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("ronald", case=False), "RONALD PHARMACEUTICALS PVT LTD", df["NAME OF MANUFACTURER"])

# %%
rott = df[df["NAME OF MANUFACTURER"].str.contains("rott", na=False, case=False)]["NAME OF MANUFACTURER"]
rott_dict = {"ROTTENDORF PHARMA": rott.unique().tolist()}   
dict_list.append(rott_dict)

#Replace with correct variation for rott
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("rott", case=False), "ROTTENDORF PHARMA", df["NAME OF MANUFACTURER"])

# %%
sandoz = df[df["NAME OF MANUFACTURER"].str.contains("sandoz", na=False, case=False)]["NAME OF MANUFACTURER"]
sandoz_dict = {"SANDOZ": sandoz.unique().tolist()}   
dict_list.append(sandoz_dict)

#Replace with correct variation for sandoz
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("sandoz", case=False), "SANDOZ", df["NAME OF MANUFACTURER"])

# %%
farmaceutici = df[df["NAME OF MANUFACTURER"].str.contains("farmaceutici", na=False, case=False)]["NAME OF MANUFACTURER"]
farmaceutici_dict = {"S.M FARMACEUTICI S.R.L": farmaceutici.unique().tolist()}   
dict_list.append(farmaceutici_dict)

#Replace with correct variation for farmaceutici
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("farmaceutici", case=False), "S.M FARMACEUTICI S.R.L", df["NAME OF MANUFACTURER"])

# %%
saffron = df[df["NAME OF MANUFACTURER"].str.contains("saffron", na=False, case=False)]["NAME OF MANUFACTURER"]
saffron_dict = {"SAFFRON PHARMACEUTICALS PVT. LTD.": saffron.unique().tolist()}   
dict_list.append(saffron_dict)

#Replace with correct variation for saffron
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("saffron", case=False), "SAFFRON PHARMACEUTICALS PVT. LTD.", df["NAME OF MANUFACTURER"])

# %%
sagar = df[df["NAME OF MANUFACTURER"].str.contains("sagar", na=False, case=False)]["NAME OF MANUFACTURER"]
sagar_dict = {"SAGAR VITACEUTICALS NIGERIA LIMITED": sagar.unique().tolist()}   
dict_list.append(sagar_dict)

#Replace with correct variation for sagar
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("sagar", case=False), "SAGAR VITACEUTICALS NIGERIA LIMITED", df["NAME OF MANUFACTURER"])

# %%
saimira = df[df["NAME OF MANUFACTURER"].str.contains("sai mira", na=False, case=False)]["NAME OF MANUFACTURER"]
saimira_dict = {"SAI MIRA INNOPHARM PVT LTD": saimira.unique().tolist()}   
dict_list.append(saimira_dict)

#Replace with correct variation for saimira
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("saimira", case=False), "SAI MIRA INNOPHARM PVT LTD", df["NAME OF MANUFACTURER"])

# %%
saitech = df[df["NAME OF MANUFACTURER"].str.contains("saitech", na=False, case=False)]["NAME OF MANUFACTURER"]
saitech_dict = {"SAITECH MEDICARE PVT. LTD": saitech.unique().tolist()}   
dict_list.append(saitech_dict)

#Replace with correct variation for saitech
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("saitech", case=False), "SAITECH MEDICARE PVT. LTD", df["NAME OF MANUFACTURER"])

# %%
sakar = df[df["NAME OF MANUFACTURER"].str.contains("sakar", na=False, case=False)]["NAME OF MANUFACTURER"]
sakar_dict = {"SAKAR HEALTHCARE PVT LTD": sakar.unique().tolist()}   
dict_list.append(sakar_dict)

#Replace with correct variation for sakar
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("sakar", case=False), "SAKAR HEALTHCARE PVT LTD", df["NAME OF MANUFACTURER"])

# %%
salud = df[df["NAME OF MANUFACTURER"].str.contains("salud", na=False, case=False)]["NAME OF MANUFACTURER"]
salud_dict = {"SALUD CARE INDIA PVT LTD": salud.unique().tolist()}   
dict_list.append(salud_dict)

#Replace with correct variation for salud
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("salud", case=False), "SALUD CARE INDIA PVT LTD", df["NAME OF MANUFACTURER"])

# %%
salutas = df[df["NAME OF MANUFACTURER"].str.contains("salutas", na=False, case=False)]["NAME OF MANUFACTURER"]
salutas_dict = {"SALUTAS PHARMA": salutas.unique().tolist()}   
dict_list.append(salutas_dict)

#Replace with correct variation for salutas
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("salutas", case=False), "SALUTAS PHARMA", df["NAME OF MANUFACTURER"])

# %%
sam = df[df["NAME OF MANUFACTURER"].str.contains("sam p", na=False, case=False)]["NAME OF MANUFACTURER"]
sam_dict = {"SAM PHARMACEUTICALS LTD": sam.unique().tolist()}   
dict_list.append(sam_dict)

#Replace with correct variation for sam
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("sam p", case=False), "SAM PHARMACEUTICALS LTD", df["NAME OF MANUFACTURER"])

# %%
samace = df[df["NAME OF MANUFACTURER"].str.contains("sam-ace", na=False, case=False)]["NAME OF MANUFACTURER"]
samace_dict = {"SAM-ACE LTD": samace.unique().tolist()}   
dict_list.append(samace_dict)

#Replace with correct variation for samace
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("sam p", case=False),"SAM-ACE LTD" , df["NAME OF MANUFACTURER"])

# %%
samarth = df[df["NAME OF MANUFACTURER"].str.contains("samarth", na=False, case=False)]["NAME OF MANUFACTURER"]
samarth_dict = {"SAMARTH LIFE SCIENCES PVT LTD": samarth.unique().tolist()}   
dict_list.append(samarth_dict)

#Replace with correct variation for samarth
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("samarth", case=False), "SAMARTH LIFE SCIENCES PVT LTD" , df["NAME OF MANUFACTURER"])

# %%
samrudh = df[df["NAME OF MANUFACTURER"].str.contains("samrudh", na=False, case=False)]["NAME OF MANUFACTURER"]
samrudh_dict = {"SAMRUDH PHARMACEUTICALS PVT LTD": samrudh.unique().tolist()}   
dict_list.append(samrudh_dict)

#Replace with correct variation for samrudh
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("samrudh", case=False), "SAMRUDH PHARMACEUTICALS PVT LTD" , df["NAME OF MANUFACTURER"])

# %%
sance = df[df["NAME OF MANUFACTURER"].str.contains("sance", na=False, case=False)]["NAME OF MANUFACTURER"]
sance_dict = {"SANCE LABORATORIES PVT LTD": sance.unique().tolist()}   
dict_list.append(sance_dict)

#Replace with correct variation for sance
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("sance", case=False), "SANCE LABORATORIES PVT LTD" , df["NAME OF MANUFACTURER"])

# %%
sanofi = df[df["NAME OF MANUFACTURER"].str.contains("sanofi", na=False, case=False)]["NAME OF MANUFACTURER"]
sanofi_dict = {"SANOFI": sanofi.unique().tolist()}   
dict_list.append(sanofi_dict)

#Replace with correct variation for sanofi
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("sanofi", case=False), "SANOFI" , df["NAME OF MANUFACTURER"])

# %%
saokim = df[df["NAME OF MANUFACTURER"].str.contains("saokim", na=False, case=False)]["NAME OF MANUFACTURER"]
saokim_dict = {"SAOKIM PHARMACEUTICAL JOINT STOCK COMPANY": saokim.unique().tolist()}   
dict_list.append(saokim_dict)

#Replace with correct variation for saokim
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("saokim", case=False), "SAOKIM PHARMACEUTICAL JOINT STOCK COMPANY" , df["NAME OF MANUFACTURER"])

# %%
sapphire = df[df["NAME OF MANUFACTURER"].str.contains("sapphire", na=False, case=False)]["NAME OF MANUFACTURER"]
sapphire_dict = {"SAPPHIRE LIFESCIENCES PVT LTD": sapphire.unique().tolist()}   
dict_list.append(sapphire_dict)

#Replace with correct variation for sapphire
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("sapphire", case=False), "SAPPHIRE LIFESCIENCES PVT LTD" , df["NAME OF MANUFACTURER"])

# %%
saro = df[df["NAME OF MANUFACTURER"].str.contains("saro", na=False, case=False)]["NAME OF MANUFACTURER"]
saro_dict = {"SARO LIFECARE LIMITED": saro.unique().tolist()}   
dict_list.append(saro_dict)

#Replace with correct variation for saro
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("saro", case=False), "SARO LIFECARE LIMITED" , df["NAME OF MANUFACTURER"])

# %%
schering = df[df["NAME OF MANUFACTURER"].str.contains("schering", na=False, case=False)]["NAME OF MANUFACTURER"]
schering_dict = {"SCHERING PLOUGH LABO NV": schering.unique().tolist()}   
dict_list.append(schering_dict)

#Replace with correct variation for schering
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("schering", case=False), "SCHERING PLOUGH LABO NV" , df["NAME OF MANUFACTURER"])

# %%
seebest = df[df["NAME OF MANUFACTURER"].str.contains("seebest", na=False, case=False)]["NAME OF MANUFACTURER"]
seebest_dict = {"SEEBEST PHARMA CHEMISTS LTD": seebest.unique().tolist()}   
dict_list.append(seebest_dict)

#Replace with correct variation for seebest
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("seebest", case=False), "SEEBEST PHARMA CHEMISTS LTD" , df["NAME OF MANUFACTURER"])

# %%
servier = df[df["NAME OF MANUFACTURER"].str.contains("servier", na=False, case=False)]["NAME OF MANUFACTURER"]
servier_dict = {"SERVIER (INDUSTRIES) LIMITED": servier.unique().tolist()} 
dict_list.append(servier_dict)

#Replace with correct variation for servier
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("servier", case=False), "SERVIER (INDUSTRIES) LIMITED" , df["NAME OF MANUFACTURER"])

# %%
sewell = df[df["NAME OF MANUFACTURER"].str.contains("sewell", na=False, case=False)]["NAME OF MANUFACTURER"]
sewell_dict = {"SEWELL PHARMACEUTICALS LIMITED": sewell.unique().tolist()}   
dict_list.append(sewell_dict)

#Replace with correct variation for sewell
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("sewell", case=False), "SEWELL PHARMACEUTICALS LIMITED" , df["NAME OF MANUFACTURER"])

# %%
shalina = df[df["NAME OF MANUFACTURER"].str.contains("shalina", na=False, case=False)]["NAME OF MANUFACTURER"]
shalina_dict = {"SHALINA LABORATORIES PVT LTD.": shalina.unique().tolist()}   
dict_list.append(shalina_dict)

#Replace with correct variation for shalina
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("shalina", case=False), "SHALINA LABORATORIES PVT LTD." , df["NAME OF MANUFACTURER"])

# %%
shamshree = df[df["NAME OF MANUFACTURER"].str.contains("shamshree", na=False, case=False)]["NAME OF MANUFACTURER"]
shamshree_dict = {"SHAMSHREE LIFESCIENCES LIMITED": shamshree.unique().tolist()}   
dict_list.append(shamshree_dict)

#Replace with correct variation for shamshree
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("shamshree", case=False), "SHAMSHREE LIFESCIENCES LIMITED" , df["NAME OF MANUFACTURER"])

# %%
shenglu = df[df["NAME OF MANUFACTURER"].str.contains("shenglu", na=False, case=False)]["NAME OF MANUFACTURER"]
shenglu_dict = {"SHANDONG SHENGLU PHARMA CO. LTD": shenglu.unique().tolist()}   
dict_list.append(shenglu_dict)

#Replace with correct variation for shenglu
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("shenglu", case=False), "SHANDONG SHENGLU PHARMA CO. LTD" , df["NAME OF MANUFACTURER"])

# %%
kangtai = df[df["NAME OF MANUFACTURER"].str.contains("kangtai", na=False, case=False)]["NAME OF MANUFACTURER"]
kangtai_dict = {"SHANDONG XIER KANGTAI PHARMACEUTICAL CO. LTD": kangtai.unique().tolist()}
dict_list.append(kangtai_dict)

#Replace with correct variation for kangtai
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("kangtai", case=False), "SHANDONG XIER KANGTAI PHARMACEUTICAL CO. LTD" , df["NAME OF MANUFACTURER"])

# %%
yikang = df[df["NAME OF MANUFACTURER"].str.contains("yikang", na=False, case=False)]["NAME OF MANUFACTURER"]
yikang_dict = {"SHANDONG YIKANG PHARMACEUTICAL CO. LTD": yikang.unique().tolist()}   
dict_list.append(yikang_dict)

#Replace with correct variation for yikang
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("yikang", case=False), "SHANDONG YIKANG PHARMACEUTICAL CO. LTD" , df["NAME OF MANUFACTURER"])

# %%
shelys = df[df["NAME OF MANUFACTURER"].str.contains("shelys", na=False, case=False)]["NAME OF MANUFACTURER"]
shelys_dict = {"SHELYS PHARMACEUTICALS LTD": shelys.unique().tolist()}  
dict_list.append(shelys_dict)

#Replace with correct variation for shelys
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("shelys", case=False), "SHELYS PHARMACEUTICALS LTD" , df["NAME OF MANUFACTURER"])

# %%
shijiazhuang = df[df["NAME OF MANUFACTURER"].str.contains("shijiazhuang p", na=False, case=False)]["NAME OF MANUFACTURER"]
shijiazhuang_dict = {"SHIJIAZHUANG PHARMACEUTICAL CO. LTD": shijiazhuang.unique().tolist()}      
dict_list.append(shijiazhuang_dict)

#Replace with correct variation for shijiazhuang
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("shijiazhuang p", case=False), "SHIJIAZHUANG PHARMACEUTICAL CO. LTD" , df["NAME OF MANUFACTURER"])

# %%
poong = df[df["NAME OF MANUFACTURER"].str.contains("poong", na=False, case=False)]["NAME OF MANUFACTURER"]
poong_dict = {"SHIN POONG PHARMACEUTICAL CO. LTD.": poong.unique().tolist()}   
dict_list.append(poong_dict)

#Replace with correct variation for poong
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("poong", case=False), "SHIN POONG PHARMACEUTICAL CO. LTD." , df["NAME OF MANUFACTURER"])

# %%
shine = df[df["NAME OF MANUFACTURER"].str.contains("shine", na=False, case=False)]["NAME OF MANUFACTURER"]
shine_dict = {"SHINE PHARMACEUTICALS LTD": shine.unique().tolist()}   
dict_list.append(shine_dict)

#Replace with correct variation for shine
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("shine", case=False), "SHINE PHARMACEUTICALS LTD" , df["NAME OF MANUFACTURER"])

# %%
shivek = df[df["NAME OF MANUFACTURER"].str.contains("shivek", na=False, case=False)]["NAME OF MANUFACTURER"]
shivek_dict = {"SHIVEK LABS LTD": shivek.unique().tolist()} 
dict_list.append(shivek_dict)

#Replace with correct variation for shivek
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("shivek", case=False), "SHIVEK LABS LTD" , df["NAME OF MANUFACTURER"])

# %%
shukra = df[df["NAME OF MANUFACTURER"].str.contains("shukra", na=False, case=False)]["NAME OF MANUFACTURER"]
shukra_dict = {"SHUKRA PHARMACEUTICALS LIMITED": shukra.unique().tolist()} 
dict_list.append(shukra_dict)

#Replace with correct variation for shukra
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("shukra", case=False), "SHUKRA PHARMACEUTICALS LIMITED" , df["NAME OF MANUFACTURER"])

# %%
sichuan = df[df["NAME OF MANUFACTURER"].str.contains("sichuan", na=False, case=False)]["NAME OF MANUFACTURER"]
sichuan_dict = {"SICHUAN KELUN PHARM CO LTD": sichuan.unique().tolist()}   
dict_list.append(sichuan_dict)

#Replace with correct variation for sichuan
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("sichuan", case=False), "SICHUAN KELUN PHARM CO LTD" , df["NAME OF MANUFACTURER"])

# %%
siegfried = df[df["NAME OF MANUFACTURER"].str.contains("siegfried", na=False, case=False)]["NAME OF MANUFACTURER"]
siegfried_dict = {"SIEGFRIED": siegfried.unique().tolist()}       
dict_list.append(siegfried_dict)

#Replace with correct variation for siegfried
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("siegfried", case=False), "SIEGFRIED" , df["NAME OF MANUFACTURER"])

# %%
sinopharm = df[df["NAME OF MANUFACTURER"].str.contains("sinopharm", na=False, case=False)]["NAME OF MANUFACTURER"]
sinopharm_dict = {"SINOPHARM XINGSHA PHARMACEUTICALS(XIAMEN) CO. LTD": sinopharm.unique().tolist()}   
dict_list.append(sinopharm_dict)

#Replace with correct variation for sinopharm
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("sinopharm", case=False), "SINOPHARM XINGSHA PHARMACEUTICALS(XIAMEN) CO. LTD" , df["NAME OF MANUFACTURER"])

# %%
sirio = df[df["NAME OF MANUFACTURER"].str.contains("sirio", na=False, case=False)]["NAME OF MANUFACTURER"]
sirio_dict = {"SIRIO PHARMA CO. LTD": sirio.unique().tolist()}   
dict_list.append(sirio_dict)

#Replace with correct variation for sirio
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("sirio", case=False), "SIRIO PHARMA CO. LTD" , df["NAME OF MANUFACTURER"])

# %%
skg = df[df["NAME OF MANUFACTURER"].str.contains("skg", na=False, case=False)]["NAME OF MANUFACTURER"]
skg_dict = {"SKG PHARMACEUTICAL LTD": skg.unique().tolist()}   
dict_list.append(skg_dict)

#Replace with correct variation for skg
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("skg", case=False), "SKG PHARMACEUTICAL LTD" , df["NAME OF MANUFACTURER"])

# %%
beecham = df[df["NAME OF MANUFACTURER"].str.contains("beecham", na=False, case=False)]["NAME OF MANUFACTURER"]
beecham_dict = {"SMITHKLINE BEECHAM LTD": beecham.unique().tolist()}   
dict_list.append(beecham_dict)

#Replace with correct variation for beecham
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("beecham", case=False), "SMITHKLINE BEECHAM LTD" , df["NAME OF MANUFACTURER"])

# %%
sofak = df[df["NAME OF MANUFACTURER"].str.contains("sofak", na=False, case=False)]["NAME OF MANUFACTURER"]
sofak_dict = {"SOFAK PHARMACEUTICAL IND LTD": sofak.unique().tolist()}   
dict_list.append(sofak_dict)

#Replace with correct variation for sofak
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("sofak", case=False), "SOFAK PHARMACEUTICAL IND LTD" , df["NAME OF MANUFACTURER"])

# %%
sofarimex = df[df["NAME OF MANUFACTURER"].str.contains("sofarimex", na=False, case=False)]["NAME OF MANUFACTURER"]
sofarimex_dict = {"SOFARIMEX - INDUSTRIA QUIMICA E FARMACEUTICA": sofarimex.unique().tolist()}   
dict_list.append(sofarimex_dict)

#Replace with correct variation for sofarimex
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("sofarimex", case=False), "SOFARIMEX - INDUSTRIA QUIMICA E FARMACEUTICA" , df["NAME OF MANUFACTURER"])

# %%
softech = df[df["NAME OF MANUFACTURER"].str.contains("softech", na=False, case=False)]["NAME OF MANUFACTURER"]
softech_dict = {"SOFTECH PHARMA PVT LTD": softech.unique().tolist()}   
dict_list.append(softech_dict)

#Replace with correct variation for softech
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("softech", case=False), "SOFTECH PHARMA PVT LTD" , df["NAME OF MANUFACTURER"])

# %%
softgel = df[df["NAME OF MANUFACTURER"].str.contains("softgel", na=False, case=False)]["NAME OF MANUFACTURER"]
softgel_dict = {"SOFTGEL HEALTHCARE PVT LTD": softgel.unique().tolist()}   
dict_list.append(softgel_dict)

#Replace with correct variation for softgel
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("softgel", case=False), "SOFTGEL HEALTHCARE PVT LTD" , df["NAME OF MANUFACTURER"])

# %%
sophia = df[df["NAME OF MANUFACTURER"].str.contains("sophia", na=False, case=False)]["NAME OF MANUFACTURER"]
sophia_dict = {"SOPHIA PHARMACEUTICAL COMPANY LTD": sophia.unique().tolist()}   
dict_list.append(sophia_dict)

#Replace with correct variation for sophia
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("sophia", case=False), "SOPHIA PHARMACEUTICAL COMPANY LTD" , df["NAME OF MANUFACTURER"])

# %%
sparsh = df[df["NAME OF MANUFACTURER"].str.contains("sparsh", na=False, case=False)]["NAME OF MANUFACTURER"]
sparsh_dict = {"SPARSH BIO-TECH PVT LTD": sparsh.unique().tolist()}   
dict_list.append(sparsh_dict)

#Replace with correct variation for sparsh
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("sparsh", case=False), "SPARSH BIO-TECH PVT LTD" , df["NAME OF MANUFACTURER"])

# %%
stedman = df[df["NAME OF MANUFACTURER"].str.contains("stedman", na=False, case=False)]["NAME OF MANUFACTURER"]
stedman_dict = {"STEDMAN PHARMACEUTICALS PRIVATE LTD": stedman.unique().tolist()}   
dict_list.append(stedman_dict)

#Replace with correct variation for stedman
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("stedman", case=False), "STEDMAN PHARMACEUTICALS PRIVATE LTD" , df["NAME OF MANUFACTURER"])

# %%
steri = df[df["NAME OF MANUFACTURER"].str.contains("steri-gene", na=False, case=False)]["NAME OF MANUFACTURER"]
steri_dict = {"STERI-GENE LIFE SCIENCES LTD": steri.unique().tolist()}   
dict_list.append(steri_dict)

#Replace with correct variation for steri
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("steri", case=False), "STERI-GENE LIFE SCIENCES LTD" , df["NAME OF MANUFACTURER"])

# %%
sterling = df[df["NAME OF MANUFACTURER"].str.contains("sterling", na=False, case=False)]["NAME OF MANUFACTURER"]
sterling_dict = {"STERLING HEALTHCARE PVT LTD": sterling.unique().tolist()}   
dict_list.append(sterling_dict)

#Replace with correct variation for sterling
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("sterling", case=False), "STERLING HEALTHCARE PVT LTD" , df["NAME OF MANUFACTURER"])

# %%
strides = df[df["NAME OF MANUFACTURER"].str.contains("strides", na=False, case=False)]["NAME OF MANUFACTURER"]
strides_dict = {"STRIDES ARCOLAB LTD": strides.unique().tolist()}   
dict_list.append(strides_dict)

#Replace with correct variation for strides
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("strides", case=False), "STRIDES ARCOLAB LTD" , df["NAME OF MANUFACTURER"])

# %%
surelife = df[df["NAME OF MANUFACTURER"].str.contains("surelife", na=False, case=False)]["NAME OF MANUFACTURER"]
surelife_dict = {"SURELIFE PHARM INDUSTRIES LTD": surelife.unique().tolist()}   
dict_list.append(surelife_dict)

#Replace with correct variation for surelife
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("surelife", case=False), "SURELIFE PHARM INDUSTRIES LTD" , df["NAME OF MANUFACTURER"])

# %%
surmount = df[df["NAME OF MANUFACTURER"].str.contains("surmount", na=False, case=False)]["NAME OF MANUFACTURER"]
surmount_dict = {"SURMOUNT LABORATORIES PVT LTD": surmount.unique().tolist()}   
dict_list.append(surmount_dict)

#Replace with correct variation for surmount
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("surmount", case=False), "SURMOUNT LABORATORIES PVT LTD" , df["NAME OF MANUFACTURER"])

# %%
swiss = df[df["NAME OF MANUFACTURER"].str.contains("swiss", na=False, case=False)]["NAME OF MANUFACTURER"]
swiss_dict = {"SWISS PHARMA PVT. LTD.": swiss.unique().tolist()}   
dict_list.append(swiss_dict)

#Replace with correct variation for swiss
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("swiss", case=False), "SWISS PHARMA PVT. LTD." , df["NAME OF MANUFACTURER"])

# %%
synokem = df[df["NAME OF MANUFACTURER"].str.contains("synokem", na=False, case=False)]["NAME OF MANUFACTURER"]
synokem_dict = {"SYNOKEM PHARMACEUTICALS LTD": synokem.unique().tolist()}   
dict_list.append(synokem_dict)

#Replace with correct variation for synokem
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("synokem", case=False), "SWISS  PHARMA PVT. LTD." , df["NAME OF MANUFACTURER"])

# %%
df["NAME OF MANUFACTURER"].unique()
# Out:
# array(['GUILIN PHARMACEUTICAL CO., LTD.', 'ECOMED PHARMA LIMITED',
#        'SHANXI XINYITONG PHARM CO. LTD', 'FIDSON HEALTHCARE PLC',
#        'AKUMS DRUGS & PHARMACEUTICALS LTD', 'BAYER PHARMACEUTICALS',
#        'CORAL LABORATORIES LTD',
#        'CSPC ZHONGNUO PHARMACEUTICAL (SHIJIAZHUANG) CO. LTD.',
#        'EMZOR PHARMACEUTICALS INDUSTRIES LIMITED',
#        'GLOBELA PHARMA PVT. LTD.', 'HOVID BHD.',
#        ' HUBEI KANGZHENG PHARM . CO., LTD.', 'INNOVA CAPTAB PVT LTD',
#        'JIANGSU RUINIAN QIANJIN PHARMACEUTICALS CO., LTD',
#        'SHANDONG XIER KANGTAI PHARMACEUTICAL CO. LTD',
#        'LESANTO LABORATORIES', 'LINCOLN PHARMACEUTICALS LTD',
#        'OLIVE HEALTHCARE', 'SYNCOM FORMULATIONS (INDIA) LTD',
#        'MAKCUR LABORATORIES LIMITED', 'MARS REMEDIES PVT LTD',
#        'McCOY PHARMA PVT LTD', 'MCW HEALTHCARE PVT LTD',
#        'NITIN LIFESCIENCES LTD.', 'OSAKA PHARMACEUTICALS PVT. LTD.',
# ...

# %%
tuwoods = df[df["NAME OF MANUFACTURER"].str.contains("t.u woods", na=False, case=False)]["NAME OF MANUFACTURER"]
tuwoods_dict = {"T.U WOODS PHARMACEUTICAL INDUSTRIES LTD": tuwoods.unique().tolist()}   
dict_list.append(tuwoods_dict)

#Replace with correct variation for tuwoods
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("t.u woods", case=False), "T.U WOODS PHARMACEUTICAL INDUSTRIES LTD" , df["NAME OF MANUFACTURER"])

# %%
takeda = df[df["NAME OF MANUFACTURER"].str.contains("takeda", na=False, case=False)]["NAME OF MANUFACTURER"]
takeda_dict = {"TAKEDA": takeda.unique().tolist()}   
dict_list.append(takeda_dict)

#Replace with correct variation for takeda
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("takeda", case=False), "TAKEDA" , df["NAME OF MANUFACTURER"])

# %%
teva = df[df["NAME OF MANUFACTURER"].str.contains("teva", na=False, case=False)]["NAME OF MANUFACTURER"]
teva_dict = {"TEVA PHARMACEUTICALS LTD": teva.unique().tolist()}   
dict_list.append(teva_dict)

#Replace with correct variation for teva
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("teva", case=False), "TEVA PHARMACEUTICALS LTD" , df["NAME OF MANUFACTURER"])

# %%
metholatum = df[df["NAME OF MANUFACTURER"].str.contains("metholatum", na=False, case=False)]["NAME OF MANUFACTURER"]
metholatum_dict = {"THE METHOLATUM CO LTD": metholatum.unique().tolist()}   
dict_list.append(metholatum_dict)

#Replace with correct variation for metholatum
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("metholatum", case=False), "THE METHOLATUM CO LTD" , df["NAME OF MANUFACTURER"])

# %%
united = df[df["NAME OF MANUFACTURER"].str.contains("the united", na=False, case=False)]["NAME OF MANUFACTURER"]
united_dict = {"THE UNITED PHARMACEUTICALS MANUFACTURING CO LTD": united.unique().tolist()}   
dict_list.append(united_dict)

#Replace with correct variation for united
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("the united", case=False), "THE UNITED PHARMACEUTICALS MANUFACTURING CO LTD" , df["NAME OF MANUFACTURER"])

# %%
themis = df[df["NAME OF MANUFACTURER"].str.contains("themis", na=False, case=False)]["NAME OF MANUFACTURER"]
themis_dict = {"THEMIS MEDICARE LIMITED": themis.unique().tolist()}   
dict_list.append(themis_dict)

#Replace with correct variation for themis
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("themis", case=False), "THEMIS MEDICARE LIMITED" , df["NAME OF MANUFACTURER"])

# %%
therapeutic = df[(df["NAME OF MANUFACTURER"].str.contains("therapeutic", na=False, case=False)) & (df["NAME OF MANUFACTURER"].str.contains("intracell",na=False, case=False) == False)]["NAME OF MANUFACTURER"]
therapeutic_dict = {"THERAPEUTIC LABORATORIES NIGERIA LTD": therapeutic.unique().tolist()}   
dict_list.append(therapeutic_dict)

#Replace with correct variation for therapeutic
df["NAME OF MANUFACTURER"] = np.where((df["NAME OF MANUFACTURER"].str.contains("therapeutic", na=False, case=False)) & (df["NAME OF MANUFACTURER"].str.contains("intracell",na=False, case=False) == False), "THERAPEUTIC LABORATORIES NIGERIA LTD" , df["NAME OF MANUFACTURER"])

# %%
thompson = df[df["NAME OF MANUFACTURER"].str.contains("thompson", na=False, case=False)]["NAME OF MANUFACTURER"]
thompson_dict = {"THOMPSON AND CAPPER LIMITED": thompson.unique().tolist()}   
dict_list.append(thompson_dict)

#Replace with correct variation for thompson
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("thompson", case=False), "THOMPSON AND CAPPER LIMITED" , df["NAME OF MANUFACTURER"])

# %%
kingyork = df[df["NAME OF MANUFACTURER"].str.contains("kingyork", na=False, case=False)]["NAME OF MANUFACTURER"]
kingyork_dict = {"TIANJIN KINGYORK PHARMACEUTICALS CO. LIMITED": kingyork.unique().tolist()}   
dict_list.append(kingyork_dict)

#Replace with correct variation for kingyork
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("kingyork", case=False), "TIANJIN KINGYORK PHARMACEUTICALS CO. LIMITED" , df["NAME OF MANUFACTURER"])

# %%
till = df[df["NAME OF MANUFACTURER"].str.contains("till h", na=False, case=False)]["NAME OF MANUFACTURER"]
till_dict = {"TILL HEALTHCARE PVT LTD": till.unique().tolist()}   
dict_list.append(till_dict)

#Replace with correct variation for till
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("till", case=False), "TILL HEALTHCARE PVT LTD" , df["NAME OF MANUFACTURER"])

# %%
torrent = df[df["NAME OF MANUFACTURER"].str.contains("torrent", na=False, case=False)]["NAME OF MANUFACTURER"]
torrent_dict = {"TORRENT PHARMACEUTICALS LTD": torrent.unique().tolist()}   
dict_list.append(torrent_dict)

#Replace with correct variation for torrent
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("torrent", case=False), "TORRENT PHARMACEUTICALS LTD" , df["NAME OF MANUFACTURER"])

# %%
troikka = df[df["NAME OF MANUFACTURER"].str.contains("troikka", na=False, case=False)]["NAME OF MANUFACTURER"]
troikka_dict = {"TROIKKA PHARMACEUTICALS LTD": troikka.unique().tolist()}   
dict_list.append(troikka_dict)

#Replace with correct variation for troikka
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("troikka", case=False), "TROIKKA PHARMACEUTICALS LTD" , df["NAME OF MANUFACTURER"])

# %%
tuton = df[df["NAME OF MANUFACTURER"].str.contains("tuton", na=False, case=False)]["NAME OF MANUFACTURER"]
tuton_dict = {"TUTON PHARMACEUTICALS PVT LTD": tuton.unique().tolist()}   
dict_list.append(tuton_dict)

#Replace with correct variation for tuton
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("tuton", case=False), "TUTON PHARMACEUTICALS PVT LTD" , df["NAME OF MANUFACTURER"])

# %%
tuyil = df[df["NAME OF MANUFACTURER"].str.contains("tuyil", na=False, case=False)]["NAME OF MANUFACTURER"]
tuyil_dict = {"TUYIL PHARMACEUTICAL INDUSTRIES LIMITED": tuyil.unique().tolist()}   
dict_list.append(tuyil_dict)

#Replace with correct variation for tuyil
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("tuyil", case=False), "TUYIL PHARMACEUTICAL INDUSTRIES LIMITED" , df["NAME OF MANUFACTURER"])

# %%
ucan = df[df["NAME OF MANUFACTURER"].str.contains("ucan", na=False, case=False)]["NAME OF MANUFACTURER"]
ucan_dict = {"UCAN CONCEPTS LTD": ucan.unique().tolist()}   
dict_list.append(ucan_dict)

#Replace with correct variation for ucan
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("ucan", case=False), "UCAN CONCEPTS LTD" , df["NAME OF MANUFACTURER"])

# %%
ucb = df[df["NAME OF MANUFACTURER"].str.contains("ucb", na=False, case=False)]["NAME OF MANUFACTURER"]
ucb_dict = {"UCB PHARMA": ucb.unique().tolist()}   
dict_list.append(ucb_dict)

#Replace with correct variation for ucb
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("ucb", case=False), "UCB PHARMA" , df["NAME OF MANUFACTURER"])

# %%
ugolab = df[df["NAME OF MANUFACTURER"].str.contains("ugolab", na=False, case=False)]["NAME OF MANUFACTURER"]
ugolab_dict = {"UGOLAB PRODUCTIONS (NIG) LTD": ugolab.unique().tolist()}   
dict_list.append(ugolab_dict)

#Replace with correct variation for ugolab
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("ugolab", case=False), "UGOLAB PRODUCTIONS (NIG) LTD" , df["NAME OF MANUFACTURER"])

# %%
umedica = df[df["NAME OF MANUFACTURER"].str.contains("umedica", na=False, case=False)]["NAME OF MANUFACTURER"]
umedica_dict = {"UMEDICA LABORATORIES PVT LTD": umedica.unique().tolist()}   
dict_list.append(umedica_dict)

#Replace with correct variation for umedica
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("umedica", case=False), "UMEDICA LABORATORIES PVT LTD" , df["NAME OF MANUFACTURER"])

# %%
unichem = df[df["NAME OF MANUFACTURER"].str.contains("unichem", na=False, case=False)]["NAME OF MANUFACTURER"]
unichem_dict = {"UNICHEM LABORATORIES LIMITED": unichem.unique().tolist()}   
dict_list.append(unichem_dict)

#Replace with correct variation for unichem
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("unichem", case=False), "UNICHEM LABORATORIES LIMITED" , df["NAME OF MANUFACTURER"])

# %%
unicure = df[df["NAME OF MANUFACTURER"].str.contains("unicure", na=False, case=False)]["NAME OF MANUFACTURER"]
unicure_dict = {"UNICURE PHARMACEUTICAL CO. LTD": unicure.unique().tolist()}   
dict_list.append(unicure_dict)

#Replace with correct variation for unicure
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("unichem", case=False), "UNICURE PHARMACEUTICAL CO. LTD" , df["NAME OF MANUFACTURER"])

# %%
unilink = df[df["NAME OF MANUFACTURER"].str.contains("unilink", na=False, case=False)]["NAME OF MANUFACTURER"]
unilink_dict = {"UNILINK PHARMA (P) LTD": unilink.unique().tolist()}   
dict_list.append(unilink_dict)

#Replace with correct variation for unilink
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("unilink", case=False), "UNILINK PHARMA (P) LTD" , df["NAME OF MANUFACTURER"])

# %%
unimax = df[df["NAME OF MANUFACTURER"].str.contains("unimax", na=False, case=False)]["NAME OF MANUFACTURER"]
unimax_dict = {"UNIMAX LABORATORIES": unimax.unique().tolist()}   
dict_list.append(unimax_dict)

#Replace with correct variation for unimax
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("unimax", case=False), "UNIMAX LABORATORIES" , df["NAME OF MANUFACTURER"])

# %%
unimed = df[df["NAME OF MANUFACTURER"].str.contains("unimed pharma inc", na=False, case=False)]["NAME OF MANUFACTURER"]
unimed_dict = {"UNIMED PHARMA INC": unimed.unique().tolist()}   
dict_list.append(unimed_dict)

#Replace with correct variation for unimed
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("unimed pharma inc", case=False), "UNIMED PHARMA INC" , df["NAME OF MANUFACTURER"])

# %%
unique = df[df["NAME OF MANUFACTURER"].str.contains("unique", na=False, case=False)]["NAME OF MANUFACTURER"]
unique_dict = {"UNIQUE PHARMACEUTICALS LIMITED": unique.unique().tolist()}   
dict_list.append(unique_dict)

#Replace with correct variation for unique
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("unique", case=False), "UNIQUE PHARMACEUTICALS LIMITED" , df["NAME OF MANUFACTURER"])

# %%
unither = df[df["NAME OF MANUFACTURER"].str.contains("unither", na=False, case=False)]["NAME OF MANUFACTURER"]
unither_dict = {"UNITHER LIQUID MANUFACTURING": unither.unique().tolist()}   
dict_list.append(unither_dict)

#Replace with correct variation for unither
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("unither", case=False), "UNITHER LIQUID MANUFACTURING" , df["NAME OF MANUFACTURER"])

# %%
universal = df[df["NAME OF MANUFACTURER"].str.contains("universal", na=False, case=False)]["NAME OF MANUFACTURER"]
universal_dict = {"UNIVERSAL MEDICARE LTD": universal.unique().tolist()}   
dict_list.append(universal_dict)

#Replace with correct variation for universal
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("universal", case=False), "UNIVERSAL MEDICARE LTD" , df["NAME OF MANUFACTURER"])

# %%
us_pharma = df[df["NAME OF MANUFACTURER"].str.contains("us parma", na=False, case=False)]["NAME OF MANUFACTURER"]
us_pharma_dict = {"US PHARMA USA CO. LIMITED": us_pharma.unique().tolist()}   
dict_list.append(us_pharma_dict)

#Replace with correct variation for us_pharma
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("us parma", case=False), "US PHARMA USA CO. LIMITED" , df["NAME OF MANUFACTURER"])

# %%
vadis = df[df["NAME OF MANUFACTURER"].str.contains("vadis", na=False, case=False)]["NAME OF MANUFACTURER"]
vadis_dict = {"VADIS PHARMACEUTICALS LIMITED": vadis.unique().tolist()}   
dict_list.append(vadis_dict)

#Replace with correct variation for vadis
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("vadis", case=False), "VADIS PHARMACEUTICALS LIMITED" , df["NAME OF MANUFACTURER"])

# %%
vapi = df[df["NAME OF MANUFACTURER"].str.contains("vapi", na=False, case=False)]["NAME OF MANUFACTURER"]
vapi_dict = {"VAPI CARE PHARMA PVT. LTD.": vapi.unique().tolist()}   
dict_list.append(vapi_dict)

#Replace with correct variation for vapi
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("vapi", case=False), "VAPI CARE PHARMA PVT. LTD." , df["NAME OF MANUFACTURER"])

# %%
vee = df[df["NAME OF MANUFACTURER"].str.contains("vee e", na=False, case=False)]["NAME OF MANUFACTURER"]
vee_dict = {"VEE EXCEL DRUGS & PHARMACEUTICAL (P) LTD": vee.unique().tolist()}   
dict_list.append(vee_dict)

#Replace with correct variation for vee
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("vee e", case=False), "VEE EXCEL DRUGS & PHARMACEUTICAL (P) LTD" , df["NAME OF MANUFACTURER"])

# %%
verve = df[df["NAME OF MANUFACTURER"].str.contains("verve", na=False, case=False)]["NAME OF MANUFACTURER"]
verve_dict = {"VERVE HUMAN CARE LABORATORIES LTD": verve.unique().tolist()}   
dict_list.append(verve_dict)

#Replace with correct variation for verve
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("verve", case=False), "VERVE HUMAN CARE LABORATORIES LTD" , df["NAME OF MANUFACTURER"])

# %%
vinco = df[df["NAME OF MANUFACTURER"].str.contains("vinco", na=False, case=False)]["NAME OF MANUFACTURER"]
vinco_dict = {"VINCO PHARMACEUTICALS NIGERIA LIMITED": vinco.unique().tolist()}   
dict_list.append(vinco_dict)

#Replace with correct variation for vinco
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("vinco", case=False), "VINCO PHARMACEUTICALS NIGERIA LIMITED" , df["NAME OF MANUFACTURER"])

# %%
vindas = df[df["NAME OF MANUFACTURER"].str.contains("vindas", na=False, case=False)]["NAME OF MANUFACTURER"]
vindas_dict = {"VINDAS CHEMICAL INDUSTRIES PVT LTD": vindas.unique().tolist()}   
dict_list.append(vindas_dict)

#Replace with correct variation for vindas
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("vindas", case=False), "VINDAS CHEMICAL INDUSTRIES PVT LTD" , df["NAME OF MANUFACTURER"])

# %%
virchow = df[df["NAME OF MANUFACTURER"].str.contains("virchow", na=False, case=False)]["NAME OF MANUFACTURER"]
virchow_dict = {"VIRCHOW BIOTECH PRIVATE LTD": virchow.unique().tolist()}   
dict_list.append(virchow_dict)

#Replace with correct variation for virchow
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("virchow", case=False), "VIRCHOW BIOTECH PRIVATE LTD" , df["NAME OF MANUFACTURER"])

# %%
vitabiotics = df[df["NAME OF MANUFACTURER"].str.contains("vitabiotics", na=False, case=False)]["NAME OF MANUFACTURER"]
vitabiotics_dict = {"VITABIOTICS NIGERIA LIMITED": vitabiotics.unique().tolist()}   
dict_list.append(vitabiotics_dict)

#Replace with correct variation for vitabiotics
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("vitabiotics", case=False), "VITABIOTICS NIGERIA LIMITED" , df["NAME OF MANUFACTURER"])

# %%
vital = df[df["NAME OF MANUFACTURER"].str.contains("vital h", na=False, case=False)]["NAME OF MANUFACTURER"]
vital_dict = {"VITAL HEALTHCARE PVT LTD": vital.unique().tolist()}   
dict_list.append(vital_dict)

#Replace with correct variation for vital
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("vital h", case=False), "VITAL HEALTHCARE PVT LTD" , df["NAME OF MANUFACTURER"])

# %%
vitaline = df[df["NAME OF MANUFACTURER"].str.contains("vitaline", na=False, case=False)]["NAME OF MANUFACTURER"]
vitaline_dict = {"VITALINE SOCIEDAD ANOIMA CERRADA": vitaline.unique().tolist()}   
dict_list.append(vitaline_dict)

#Replace with correct variation for vitaline
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("vitaline", case=False), "VITALINE SOCIEDAD ANOIMA CERRADA" , df["NAME OF MANUFACTURER"])

# %%
vixa = df[df["NAME OF MANUFACTURER"].str.contains("vixa", na=False, case=False)]["NAME OF MANUFACTURER"]
vixa_dict = {"VIXA BIOPHARM CO. LTD": vixa.unique().tolist()}   
dict_list.append(vixa_dict)

#Replace with correct variation for vixa
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("vixa", case=False), "VIXA BIOPHARM CO. LTD" , df["NAME OF MANUFACTURER"])

# %%
vovantis = df[df["NAME OF MANUFACTURER"].str.contains("vovantis", na=False, case=False)]["NAME OF MANUFACTURER"]
vovantis_dict = {"VOVANTIS LABORATORIES PVT LTD": vovantis.unique().tolist()}   
dict_list.append(vovantis_dict)

#Replace with correct variation for vovantis
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("vovantis", case=False), "VOVANTIS LABORATORIES PVT LTD" , df["NAME OF MANUFACTURER"])

# %%
win = df[df["NAME OF MANUFACTURER"].str.contains("win-", na=False, case=False)]["NAME OF MANUFACTURER"]
win_dict = {"WIN-MEDICARE PVT LTD": win.unique().tolist()}   
dict_list.append(win_dict)

#Replace with correct variation for win
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("win-", case=False), "WIN-MEDICARE PVT LTD" , df["NAME OF MANUFACTURER"])

# %%
wintech = df[df["NAME OF MANUFACTURER"].str.contains("wintech", na=False, case=False)]["NAME OF MANUFACTURER"]
wintech_dict = {"WINTECH PHARMACEUTICALS": wintech.unique().tolist()}   
dict_list.append(wintech_dict)

#Replace with correct variation for wintech
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("wintech", case=False), "WINTECH PHARMACEUTICALS" , df["NAME OF MANUFACTURER"])

# %%
wockhard = df[df["NAME OF MANUFACTURER"].str.contains("wockhard", na=False, case=False)]["NAME OF MANUFACTURER"]
wockhard_dict = {"WOCKHARD LIMITED": wockhard.unique().tolist()}   
dict_list.append(wockhard_dict)

#Replace with correct variation for wockhard
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("wockhard", case=False), "WOCKHARD LIMITED" , df["NAME OF MANUFACTURER"])

# %%
world = df[df["NAME OF MANUFACTURER"].str.contains("world m", na=False, case=False)]["NAME OF MANUFACTURER"]
world_dict = {"WORLD MEDICINE LIAC SAN": world.unique().tolist()}   
dict_list.append(world_dict)

#Replace with correct variation for world
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("world m", case=False), "WORLD MEDICINE LIAC SAN" , df["NAME OF MANUFACTURER"])

# %%
wrapsa = df[df["NAME OF MANUFACTURER"].str.contains("wrapsa", na=False, case=False)]["NAME OF MANUFACTURER"]
wrapsa_dict = {"WRAPSA (PTY) LTD": wrapsa.unique().tolist()}   
dict_list.append(wrapsa_dict)

#Replace with correct variation for wrapsa
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("wrapsa", case=False), "WRAPSA (PTY) LTD" , df["NAME OF MANUFACTURER"])

# %%
wuhu = df[df["NAME OF MANUFACTURER"].str.contains("wuhu", na=False, case=False)]["NAME OF MANUFACTURER"]
wuhu_dict = {"WUHU KANGQI PHARMACEUTICAL COMPANY LIMITED": wuhu.unique().tolist()}   
dict_list.append(wuhu_dict)

#Replace with correct variation for wuhu
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("wuhu", case=False), "WUHU KANGQI PHARMACEUTICAL COMPANY LIMITED" , df["NAME OF MANUFACTURER"])

# %%
wyeth = df[df["NAME OF MANUFACTURER"].str.contains("wyeth", na=False, case=False)]["NAME OF MANUFACTURER"]
wyeth_dict = {"WYETH LEDERLE": wyeth.unique().tolist()}   
dict_list.append(wyeth_dict)

#Replace with correct variation for wyeth
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("wyeth", case=False), "WYETH LEDERLE" , df["NAME OF MANUFACTURER"])

# %%
yangzhou = df[df["NAME OF MANUFACTURER"].str.contains("yangzhou", na=False, case=False)]["NAME OF MANUFACTURER"]
yangzhou_dict = {"YANGZHOU PHARMACEUTICAL CO. LTD": yangzhou.unique().tolist()}   
dict_list.append(yangzhou_dict)

#Replace with correct variation for yangzhou
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("yangzhou", case=False), "YANGZHOU PHARMACEUTICAL CO. LTD" , df["NAME OF MANUFACTURER"])

# %%
yeluri = df[df["NAME OF MANUFACTURER"].str.contains("yeluri", na=False, case=False)]["NAME OF MANUFACTURER"]
yeluri_dict = {"YELURI FORMULATION PVT LTD": yeluri.unique().tolist()}   
dict_list.append(yeluri_dict)

#Replace with correct variation for yeluri
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("yeluri", case=False), "YELURI FORMULATION PVT LTD" , df["NAME OF MANUFACTURER"])

# %%
yuria = df[df["NAME OF MANUFACTURER"].str.contains("yuria", na=False, case=False)]["NAME OF MANUFACTURER"]
yuria_dict = {"YURIA PHARM LIMITED": yuria.unique().tolist()}   
dict_list.append(yuria_dict)

#Replace with correct variation for yuria
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("yuria", case=False), "YURIA PHARM LIMITED" , df["NAME OF MANUFACTURER"])

# %%
zee = df[df["NAME OF MANUFACTURER"].str.contains("zee", na=False, case=False)]["NAME OF MANUFACTURER"]
zee_dict = {"ZEE LABORATORIES LTD": zee.unique().tolist()}   
dict_list.append(zee_dict)

#Replace with correct variation for zee
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("zee", case=False), "ZEE LABORATORIES LTD" , df["NAME OF MANUFACTURER"])

# %%
zeiss = df[df["NAME OF MANUFACTURER"].str.contains("zeiss", na=False, case=False)]["NAME OF MANUFACTURER"]
zeiss_dict = {"ZEISS PHARMACEAUTICAL PVT. LTD.": zeiss.unique().tolist()}   
dict_list.append(zeiss_dict)

#Replace with correct variation for zeiss
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("zeiss", case=False), "ZEISS PHARMACEAUTICAL PVT. LTD." , df["NAME OF MANUFACTURER"])

# %%
zen = df[df["NAME OF MANUFACTURER"].str.contains("zen p", na=False, case=False)]["NAME OF MANUFACTURER"]
zen_dict = {"ZEN PHARMA (P) LTD": zen.unique().tolist()}   
dict_list.append(zen_dict)

#Replace with correct variation for zen
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("zen p", case=False), "ZEN PHARMA (P) LTD" , df["NAME OF MANUFACTURER"])

# %%
zenith = df[df["NAME OF MANUFACTURER"].str.contains("zenith", na=False, case=False)]["NAME OF MANUFACTURER"]
zenith_dict = {"ZENITH HEALTHCARE LTD": zenith.unique().tolist()}   
dict_list.append(zenith_dict)

#Replace with correct variation for zenith
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("zenith", case=False), "ZENITH HEALTHCARE LTD" , df["NAME OF MANUFACTURER"])

# %%
zest = df[df["NAME OF MANUFACTURER"].str.contains("zest", na=False, case=False)]["NAME OF MANUFACTURER"]
zest_dict = {"ZEST PHARMA LTD": zest.unique().tolist()}   
dict_list.append(zest_dict)

#Replace with correct variation for zest
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("zest", case=False), "ZEST PHARMA LTD" , df["NAME OF MANUFACTURER"])

# %%
zhejiang_jingwei = df[df["NAME OF MANUFACTURER"].str.contains("zhejiang jingwei", na=False, case=False)]["NAME OF MANUFACTURER"]
zhejiang_jingwei_dict = {"ZHEJIANG JINGWEI PHARM CO. LTD": zhejiang_jingwei.unique().tolist()}   
dict_list.append(zhejiang_jingwei_dict)

#Replace with correct variation for zhejiang_jingwei
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("zhejiang jingwei", case=False), "ZHEJIANG JINGWEI PHARM CO. LTD" , df["NAME OF MANUFACTURER"])

# %%
zhejiang_jingxin = df[df["NAME OF MANUFACTURER"].str.contains("zhejiang jingxin", na=False, case=False)]["NAME OF MANUFACTURER"]
zhejiang_jingxin_dict = {"ZHEJIANG JINGXIN PHARM CO. LTD": zhejiang_jingxin.unique().tolist()}   
dict_list.append(zhejiang_jingxin_dict)

#Replace with correct variation for zhejiang_jingxin
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("zhejiang jingxin", case=False), "ZHEJIANG JINGXIN PHARM CO. LTD" , df["NAME OF MANUFACTURER"])

# %%
zhejiang_kangle = df[df["NAME OF MANUFACTURER"].str.contains("zhejiang kangle", na=False, case=False)]["NAME OF MANUFACTURER"]
zhejiang_kangle_dict = {"ZHEJIANG KANGLE PHARMACEUTICALS CO. LTD": zhejiang_kangle.unique().tolist()}   
dict_list.append(zhejiang_kangle_dict)

#Replace with correct variation for zhejiang_kangle
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("zhejiang kangle", case=False), "ZHEJIANG KANGLE PHARMACEUTICALS CO. LTD" , df["NAME OF MANUFACTURER"])

# %%
zhongshan = df[df["NAME OF MANUFACTURER"].str.contains("zhongshan l", na=False, case=False)]["NAME OF MANUFACTURER"]
zhongshan_dict = {"ZHONGSHAN LEAN & LEAP PHARMACEUTICAL CO. LIMITED": zhongshan.unique().tolist()}   
dict_list.append(zhongshan_dict)

#Replace with correct variation for zhongshan
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("zhongshan l", case=False), "ZHONGSHAN LEAN & LEAP PHARMACEUTICAL CO. LIMITED" , df["NAME OF MANUFACTURER"])

# %%
zim = df[df["NAME OF MANUFACTURER"].str.contains("zim", na=False, case=False)]["NAME OF MANUFACTURER"]
zim_dict = {"ZIM LABORATORIES LTD": zim.unique().tolist()}   
dict_list.append(zim_dict)

#Replace with correct variation for zim
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("zim", case=False), "ZIM LABORATORIES LTD" , df["NAME OF MANUFACTURER"])

# %%
zuna = df[df["NAME OF MANUFACTURER"].str.contains("zuna", na=False, case=False)]["NAME OF MANUFACTURER"]
zuna_dict = {"ZUNAMEDIKS PHARMA LIMITED": zuna.unique().tolist()}   
dict_list.append(zuna_dict)

#Replace with correct variation for zuna
df["NAME OF MANUFACTURER"] = np.where(df["NAME OF MANUFACTURER"].str.contains("zuna", case=False), "ZUNAMEDIKS PHARMA LIMITED" , df["NAME OF MANUFACTURER"])

# %%
df["NAME OF MANUFACTURER"].nunique()
# Out:
# 594

# %%
dict_df = pd.DataFrame([(i, j) for a in dict_list for i, j in a.items()], 
                   columns=['Correct','Variations'])

# %%
dict_df.sort_values(ascending=True, by="Correct")
# Out:
#                                                         Correct  \
# 34   A & J PHARMACEUTICAL NIGERIA LIMITED
# 36   A. NATTERMAN & CIE
# 37   ABARIS HEALTHCARE PVT LTD
# 38   ABBOTT BIOLOGICALS
# 39   ABBVIE INC.
# 35   AC DRUGS LTD
# 40   ACCORD UK LTD
# 41   ACINO PHARMA AG
# 42   ACME FORMULATION PVT LTD
# 43   ACROMAX DOMINICANA S.A
# 44   ACULIFE HEALTHCARE PVT. LTD
# 45   ADLER PRODUCTS LTD.
# 46   ADLEY FORMULATIONS
# 47   ADMAC LIFESCIENCE
# 48   ADORE PHARMACEUTICAL PVT LTD
# 49   ADVANCE PHARMA GMBH & CO
# 50   ADVANCED CHEMICAL  INDUSTRIES LIMITED
# 51   AEROPHARM GMBH
# 52   AESICA QUEENBOROUGH LTD
# 53   AFRAB CHEM LTD
# 54   AFROMED INDUSTRIES LTD.
# 55   AGARY PHARMACEUTICAL LIMITED
# 56   AGLOWMED LIMITED
# 57   AHLCON PARENTERALS (INDIA) LIMITED
# 58   AISHWARYA LIFESCIENCES
# 59   AJANTA PHARMA LIMITED
# 60   AKORN INC.
# 61   AKRITI PHARMACEUTICALS PVT LTD.
# 6    AKUMS DRUGS & PHARMACEUTICALS LTD
# 62   ALBEN HEALTHCARE INDUSTRIES LIMITED
# ...
